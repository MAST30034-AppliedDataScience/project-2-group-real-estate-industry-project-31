# %% [markdown]
# JUST EXPERIMENTING WITH THE DATASCRAPING THEY GAVE US

# %%
import pandas as pd
import json

# %%
# JUST LOOKING AT THE EXAMPLE OF THE RAW DATA THEY  GAVE US- L
with open('../data/raw/example.json', 'r') as file:
    data = json.load(file)

print(data)
# Out:
# {'https://www.domain.com.au/667-glenhuntly-road-caulfield-vic-3162-11598047': {'name': '667 Glenhuntly Road, Caulfield VIC 3162', 'cost_text': '$38,000 p.a. Incl. Outgoings + GST', 'rooms': [], 'parking': [], 'desc': 'Can you hear it? Opportunity knocking!! '}, 'https://www.domain.com.au/6501-35-queensbridge-street-southbank-vic-3006-16869807': {'name': '6501/35 Queensbridge Street, Southbank VIC 3006', 'cost_text': '$12,500 pw', 'rooms': ['4 Beds', '4 Baths'], 'parking': ['2 Parking'], 'desc': 'Unparalleled space and bathed in natural light welcome to Penthouse 6501, a study in luxury and design of incomparable measure.'}, 'https://www.domain.com.au/7-jeffcott-street-west-melbourne-vic-3003-17038576': {'name': '7 Jeffcott Street, West Melbourne VIC 3003', 'cost_text': '$9,999 pw', 'rooms': ['5 Beds', '5 Baths'], 'parking': ['5 Parking'], 'desc': 'This ad is for Off - Market Property Application only. '}, 'https://www.domain.com.au/5604-1-queensbridge-square-southbank-vic-3006-168963
# ...

# %%
# FIGURE OUT WHAT COLUMNS THEYVE GIVEN US: 
first_item = next(iter(data.values()))
headings = list(first_item.keys())

print(headings)
# Out:
# ['name', 'cost_text', 'rooms', 'parking', 'desc']
