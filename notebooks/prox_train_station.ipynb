# %% [markdown]
# # Computing Proximity to the Closest Train Station for all Rental Properties

# %%
import requests
import zipfile
import io
import geopandas as gpd
from openrouteservice import Client
import json
import pandas as pd
from shapely.geometry import Point
import ast
import time
import os
import sys
sys.path.append('../')
from scripts.utils import download_file, extract_zip

# %% [markdown]
# ## Loading Train Station Data

# %%
url = 'https://s3.ap-southeast-2.amazonaws.com/cl-isd-prd-datashare-s3-delivery/Order_FYXPQM.zip'
output_dir = '../data/landing/train_stations'

# Checks to see if the directory exists and creates it if not
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
    print(f"Created directory: {output_dir}")

# Defining the file directories
zip_path = f'{output_dir}/train_stations.zip'
extract_to = '../data/landing/train_stations/extracted'

# Download the ZIP file
download_file(url, zip_path)
    
# Extract the ZIP file
extract_zip(zip_path, extract_to)

# List files in the extracted directory
extracted_files = os.listdir(extract_to)
print("Files in extracted directory:", extracted_files)
# Out:
# Created directory: ../data/landing/train_stations
# Files in extracted directory: ['Creative Commons Licence.html', 'll_gda94', 'PTV_METRO_TRAIN_STATION_b6722101-8db5-51f0-8a6f-d1e4fe805b73.html']

# %%
# Path to the shapefile
shapefile_path = '../data/landing/train_stations/extracted/ll_gda94/esrishape/whole_of_dataset/victoria/PTV/PTV_METRO_TRAIN_STATION.shp'

# Read the shapefile into a GeoDataFrame
train_gdf = gpd.read_file(shapefile_path)

# Display the first few rows of the GeoDataFrame
print(train_gdf.head())

# Display the columns of the GeoDataFrame
train_gdf.columns
# Out:
#   STOP_ID   LATITUDE                                          STOP_NAME  \
# 0   19970 -37.781193             Royal Park Railway Station (Parkville)
# 1   19971 -37.788140  Flemington Bridge Railway Station (North Melbo...
# 2   19972 -37.794267         Macaulay Railway Station (North Melbourne)
# 3   19973 -37.807419   North Melbourne Railway Station (West Melbourne)
# 4   19974 -37.788657        Clifton Hill Railway Station (Clifton Hill)
#
#     LONGITUDE TICKETZONE                                          ROUTEUSSP  \
# 0  144.952301          1                                            Upfield
# 1  144.939323          1                                            Upfield
# 2  144.936166          1                                            Upfield
# 3  144.942570          1  Flemington,Sunbury,Upfield,Werribee,Williamsto...
# 4  144.995417          1                                 Mernda,Hurstbridge
#
#                       geometry
# 0  POINT (144.95230 -37.78119)
# 1  POINT (144.93932 -37.78814)
# 2  POINT (144.93617 -37.79427)
# 3  POINT (144.94257 -37.80742)
# 4  POINT (144.99542 -37.78866)
# Index(['STOP_ID', 'LATITUDE', 'STOP_NAME', 'LONGITUDE', 'TICKETZONE',
#        'ROUTEUSSP', 'geometry'],
#       dtype='object')

# %%
# Convert column names to lowercase
train_gdf.columns = [col.lower() for col in train_gdf.columns]

# Display the updated GeoDataFrame
train_gdf.head()
# Out:
#   stop_id   latitude                                          stop_name  \
# 0   19970 -37.781193             Royal Park Railway Station (Parkville)
# 1   19971 -37.788140  Flemington Bridge Railway Station (North Melbo...
# 2   19972 -37.794267         Macaulay Railway Station (North Melbourne)
# 3   19973 -37.807419   North Melbourne Railway Station (West Melbourne)
# 4   19974 -37.788657        Clifton Hill Railway Station (Clifton Hill)
#
#     longitude ticketzone                                          routeussp  \
# 0  144.952301          1                                            Upfield
# 1  144.939323          1                                            Upfield
# 2  144.936166          1                                            Upfield
# 3  144.942570          1  Flemington,Sunbury,Upfield,Werribee,Williamsto...
# 4  144.995417          1                                 Mernda,Hurstbridge
#
#                       geometry
# 0  POINT (144.95230 -37.78119)
# 1  POINT (144.93932 -37.78814)
# 2  POINT (144.93617 -37.79427)
# 3  POINT (144.94257 -37.80742)
# 4  POINT (144.99542 -37.78866)

# %%
# Checking longitude and latitude are within the reasonable limits for Victoria

# Latitude: Approx [-39, -34]
# Longitude: Approx [140, 150]

train_gdf.describe()
# Out:
#          latitude   longitude
# count  220.000000  220.000000
# mean   -37.852378  145.045691
# std      0.140332    0.139902
# min    -38.374235  144.661118
# 25%    -37.899626  144.961156
# 50%    -37.826147  145.036588
# 75%    -37.769623  145.121451
# max    -37.579091  145.486379

# %% [markdown]
# ## Loading Rental Data

# %%
# Path to your JSON file
json_file_path = '../data/landing/all_properties_metadata.json'

# Open and read the JSON file
with open(json_file_path, 'r') as file:
    rental_data = json.load(file)

# Convert the JSON data to a DataFrame
rental_df = pd.DataFrame.from_dict(rental_data, orient='index')
rental_df.head()
# Out:
#                                                                                           name  \
# https://www.domain.com.au/72a-argus-street-chel...       72A Argus Street, Cheltenham VIC 3192
# https://www.domain.com.au/8-42-wright-street-mc...       8/42 Wright Street, McKinnon VIC 3204
# https://www.domain.com.au/802-1-ascot-vale-road...  802/1 Ascot Vale Road, Flemington VIC 3031
# https://www.domain.com.au/2209-22-dorcas-street...   2209/22 Dorcas Street, Southbank VIC 3006
# https://www.domain.com.au/511-228-a-beckett-st-...    511/228 A'Beckett St, Melbourne VIC 3000
#
#                                                            cost_text  \
# https://www.domain.com.au/72a-argus-street-chel...   $1,050 Per Week
# https://www.domain.com.au/8-42-wright-street-mc...              $800
# https://www.domain.com.au/802-1-ascot-vale-road...  $500.00 per week
# https://www.domain.com.au/2209-22-dorcas-street...     $580 per week
# https://www.domain.com.au/511-228-a-beckett-st-...       $480 weekly
#
#                                                                 rooms  \
# https://www.domain.com.au/72a-argus-street-chel...  [4 Beds, 3 Baths]
# https://www.domain.com.au/8-42-wright-street-mc...  [3 Beds, 2 Baths]
# https://www.domain.com.au/802-1-ascot-vale-road...    [1 Bed, 1 Bath]
# https://www.domain.com.au/2209-22-dorcas-street...    [1 Bed, 1 Bath]
# https://www.domain.com.au/511-228-a-beckett-st-...    [1 Bed, 1 Bath]
#
#                                                         parking  \
# https://www.domain.com.au/72a-argus-street-chel...  [2 Parking]
# https://www.domain.com.au/8-42-wright-street-mc...  [1 Parking]
# https://www.domain.com.au/802-1-ascot-vale-road...  [1 Parking]
# https://www.domain.com.au/2209-22-dorcas-street...  [1 Parking]
# https://www.domain.com.au/511-228-a-beckett-st-...  [− Parking]
#
#                                                                                                  desc  \
# https://www.domain.com.au/72a-argus-street-chel...  Brand new and with a commanding street presenc...
# https://www.domain.com.au/8-42-wright-street-mc...  Nestling into the manicured gardens of Allnutt...
# https://www.domain.com.au/802-1-ascot-vale-road...  Positioned for absolute convenience, close to ...
# https://www.domain.com.au/2209-22-dorcas-street...                               * Unverified feature
# https://www.domain.com.au/511-228-a-beckett-st-...                               * Unverified feature
#
#                                                               property_type  \
# https://www.domain.com.au/72a-argus-street-chel...                Townhouse
# https://www.domain.com.au/8-42-wright-street-mc...                Townhouse
# https://www.domain.com.au/802-1-ascot-vale-road...  Apartment / Unit / Flat
# https://www.domain.com.au/2209-22-dorcas-street...  Apartment / Unit / Flat
# https://www.domain.com.au/511-228-a-beckett-st-...  Apartment / Unit / Flat
#
#                                                    date_available   bond  \
# https://www.domain.com.au/72a-argus-street-chel...  Available Now  $6300
# https://www.domain.com.au/8-42-wright-street-mc...  Available Now  $3476
# https://www.domain.com.au/802-1-ascot-vale-road...  Available Now  $2173
# https://www.domain.com.au/2209-22-dorcas-street...  Available Now  $2520
# https://www.domain.com.au/511-228-a-beckett-st-...  Available Now  $2086
#
#                                                                                     property_features  \
# https://www.domain.com.au/72a-argus-street-chel...  [Split System Air Con, Split System Heating, O...
# https://www.domain.com.au/8-42-wright-street-mc...  [Floorboards, Built in wardrobes, Dishwasher, ...
# https://www.domain.com.au/802-1-ascot-vale-road...  [Car Accom: Basement Carspace, Heating: Revers...
# https://www.domain.com.au/2209-22-dorcas-street...  [Internal Laundry*, Furnished*, Built in wardr...
# https://www.domain.com.au/511-228-a-beckett-st-...  [Heating*, Air conditioning, Alarm System, Int...
#
#                                                                    coordinates
# https://www.domain.com.au/72a-argus-street-chel...  [-37.9592116, 145.0649156]
# https://www.domain.com.au/8-42-wright-street-mc...  [-37.9134094, 145.0308476]
# https://www.domain.com.au/802-1-ascot-vale-road...  [-37.7867825, 144.9213168]
# https://www.domain.com.au/2209-22-dorcas-street...  [-37.8301483, 144.9696742]
# https://www.domain.com.au/511-228-a-beckett-st-...  [-37.8102641, 144.9566396]

# %%
# Checking longitude and latitude are within the reasonable limits for Victoria

# Latitude: Approx [-39, -34]
# Longitude: Approx [140, 150]
rental_df.describe()
# Out:
#                      name cost_text             rooms      parking  \
# count               13515     13515             13515        13515
# unique              13352      3077                44           16
# top     Brighton VIC 3186      $550  [2 Beds, 1 Bath]  [1 Parking]
# freq                    8       189              2662         5380
#
#                         desc property_type date_available   bond  \
# count                  13515         13515           8446  12543
# unique                  3331            16              1    991
# top     * Unverified feature         House  Available Now  $2390
# freq                    8817          6599           8446    583
#
#        property_features                 coordinates
# count              13510                       13510
# unique              7691                       11569
# top                   []  [-37.8183759, 144.9554361]
# freq                1808                          21

# %% [markdown]
# ## The following Code should be done in Earlier Preprocessing Steps

# %%
# Create two new columns for latitude and longitude, but handle cases where coordinates might not be a valid list
def extract_latitude(coordinate):
    if isinstance(coordinate, list) and len(coordinate) == 2:
        return coordinate[0]  # Latitude is the first element
    else:
        return None  # Return None if coordinates are invalid

def extract_longitude(coordinate):
    if isinstance(coordinate, list) and len(coordinate) == 2:
        return coordinate[1]  # Longitude is the second element
    else:
        return None  # Return None if coordinates are invalid

# Apply the functions to extract latitude and longitude
rental_df['latitude'] = rental_df['coordinates'].apply(extract_latitude)
rental_df['longitude'] = rental_df['coordinates'].apply(extract_longitude)

# Convert latitude and longitude columns to numeric, coercing errors to NaN
rental_df['latitude'] = pd.to_numeric(rental_df['latitude'], errors='coerce')
rental_df['longitude'] = pd.to_numeric(rental_df['longitude'], errors='coerce')

# Now you can filter based on latitude and longitude
lat_less_than_140 = rental_df[rental_df['latitude'] < 140]
long_greater_than_neg34 = rental_df[rental_df['longitude'] > -34]

# %%
# Display the results
print("Entries with latitude less than 140:")
lat_less_than_140
# Out:
# Entries with latitude less than 140:
#                                                                                       name  \
# https://www.domain.com.au/16-rodney-court-skye-...          16 Rodney Court, Skye VIC 3977
# https://www.domain.com.au/1510-5-joseph-road-fo...  1510/5 Joseph Road, Footscray VIC 3011
#
#                                                    cost_text  \
# https://www.domain.com.au/16-rodney-court-skye-...   $530 pw
# https://www.domain.com.au/1510-5-joseph-road-fo...      $475
#
#                                                                 rooms  \
# https://www.domain.com.au/16-rodney-court-skye-...  [4 Beds, 2 Baths]
# https://www.domain.com.au/1510-5-joseph-road-fo...    [1 Bed, 1 Bath]
#
#                                                         parking  \
# https://www.domain.com.au/16-rodney-court-skye-...  [1 Parking]
# https://www.domain.com.au/1510-5-joseph-road-fo...  [− Parking]
#
#                                                                                                  desc  \
# https://www.domain.com.au/16-rodney-court-skye-...                               * Unverified feature
# https://www.domain.com.au/1510-5-joseph-road-fo...  This apartment offers a contemporary, stylish ...
#
#                                                               property_type  \
# https://www.domain.com.au/16-rodney-court-skye-...                    House
# https://www.domain.com.au/1510-5-joseph-road-fo...  Apartment / Unit / Flat
#
#                                                    date_available   bond  \
# https://www.domain.com.au/16-rodney-court-skye-...            NaN  $2303
# https://www.domain.com.au/1510-5-joseph-road-fo...  Available Now  $2064
#
#                                                                                     property_features  \
# https://www.domain.com.au/16-rodney-court-skye-...                                         [Heating*]
# https://www.domain.com.au/1510-5-joseph-road-fo...  [Gym, Intercom, Study, Floorboards, Built in w...
#
#                                                    coordinates  longitude  \
# https://www.domain.com.au/16-rodney-court-skye-...      [0, 0]        0.0
# https://www.domain.com.au/1510-5-joseph-road-fo...      [0, 0]        0.0
#
#                                                     latitude
# https://www.domain.com.au/16-rodney-court-skye-...       0.0
# https://www.domain.com.au/1510-5-joseph-road-fo...       0.0

# %%
print("\nEntries with longitude greater than -34:")
long_greater_than_neg34
# Out:
# Entries with longitude greater than -34:
#                                                                                       name  \
# https://www.domain.com.au/16-rodney-court-skye-...          16 Rodney Court, Skye VIC 3977
# https://www.domain.com.au/1510-5-joseph-road-fo...  1510/5 Joseph Road, Footscray VIC 3011
#
#                                                    cost_text  \
# https://www.domain.com.au/16-rodney-court-skye-...   $530 pw
# https://www.domain.com.au/1510-5-joseph-road-fo...      $475
#
#                                                                 rooms  \
# https://www.domain.com.au/16-rodney-court-skye-...  [4 Beds, 2 Baths]
# https://www.domain.com.au/1510-5-joseph-road-fo...    [1 Bed, 1 Bath]
#
#                                                         parking  \
# https://www.domain.com.au/16-rodney-court-skye-...  [1 Parking]
# https://www.domain.com.au/1510-5-joseph-road-fo...  [− Parking]
#
#                                                                                                  desc  \
# https://www.domain.com.au/16-rodney-court-skye-...                               * Unverified feature
# https://www.domain.com.au/1510-5-joseph-road-fo...  This apartment offers a contemporary, stylish ...
#
#                                                               property_type  \
# https://www.domain.com.au/16-rodney-court-skye-...                    House
# https://www.domain.com.au/1510-5-joseph-road-fo...  Apartment / Unit / Flat
#
#                                                    date_available   bond  \
# https://www.domain.com.au/16-rodney-court-skye-...            NaN  $2303
# https://www.domain.com.au/1510-5-joseph-road-fo...  Available Now  $2064
#
#                                                                                     property_features  \
# https://www.domain.com.au/16-rodney-court-skye-...                                         [Heating*]
# https://www.domain.com.au/1510-5-joseph-road-fo...  [Gym, Intercom, Study, Floorboards, Built in w...
#
#                                                    coordinates  longitude  \
# https://www.domain.com.au/16-rodney-court-skye-...      [0, 0]        0.0
# https://www.domain.com.au/1510-5-joseph-road-fo...      [0, 0]        0.0
#
#                                                     latitude
# https://www.domain.com.au/16-rodney-court-skye-...       0.0
# https://www.domain.com.au/1510-5-joseph-road-fo...       0.0

# %% [markdown]
# - 2 properties which have [0, 0] coordinates
# - I think these should have already been removed via earlier preprocessing (will talk to Laura)

# %% [markdown]
# ## Converting Rental Dataframe to Geopandas dataframe

# %%
# Convert string representations of lists to actual lists
rental_df['coordinates'] = rental_df['coordinates'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# Extract longitude and latitude from list
rental_df['latitude'] = rental_df['coordinates'].apply(lambda x: float(x[0]) if isinstance(x, (list, tuple)) and len(x) > 0 else None)
rental_df['longitude'] = rental_df['coordinates'].apply(lambda x: float(x[1]) if isinstance(x, (list, tuple)) and len(x) > 1 else None)

# %%
rental_df.head()
# Out:
#                                                                                           name  \
# https://www.domain.com.au/72a-argus-street-chel...       72A Argus Street, Cheltenham VIC 3192
# https://www.domain.com.au/8-42-wright-street-mc...       8/42 Wright Street, McKinnon VIC 3204
# https://www.domain.com.au/802-1-ascot-vale-road...  802/1 Ascot Vale Road, Flemington VIC 3031
# https://www.domain.com.au/2209-22-dorcas-street...   2209/22 Dorcas Street, Southbank VIC 3006
# https://www.domain.com.au/511-228-a-beckett-st-...    511/228 A'Beckett St, Melbourne VIC 3000
#
#                                                            cost_text  \
# https://www.domain.com.au/72a-argus-street-chel...   $1,050 Per Week
# https://www.domain.com.au/8-42-wright-street-mc...              $800
# https://www.domain.com.au/802-1-ascot-vale-road...  $500.00 per week
# https://www.domain.com.au/2209-22-dorcas-street...     $580 per week
# https://www.domain.com.au/511-228-a-beckett-st-...       $480 weekly
#
#                                                                 rooms  \
# https://www.domain.com.au/72a-argus-street-chel...  [4 Beds, 3 Baths]
# https://www.domain.com.au/8-42-wright-street-mc...  [3 Beds, 2 Baths]
# https://www.domain.com.au/802-1-ascot-vale-road...    [1 Bed, 1 Bath]
# https://www.domain.com.au/2209-22-dorcas-street...    [1 Bed, 1 Bath]
# https://www.domain.com.au/511-228-a-beckett-st-...    [1 Bed, 1 Bath]
#
#                                                         parking  \
# https://www.domain.com.au/72a-argus-street-chel...  [2 Parking]
# https://www.domain.com.au/8-42-wright-street-mc...  [1 Parking]
# https://www.domain.com.au/802-1-ascot-vale-road...  [1 Parking]
# https://www.domain.com.au/2209-22-dorcas-street...  [1 Parking]
# https://www.domain.com.au/511-228-a-beckett-st-...  [− Parking]
#
#                                                                                                  desc  \
# https://www.domain.com.au/72a-argus-street-chel...  Brand new and with a commanding street presenc...
# https://www.domain.com.au/8-42-wright-street-mc...  Nestling into the manicured gardens of Allnutt...
# https://www.domain.com.au/802-1-ascot-vale-road...  Positioned for absolute convenience, close to ...
# https://www.domain.com.au/2209-22-dorcas-street...                               * Unverified feature
# https://www.domain.com.au/511-228-a-beckett-st-...                               * Unverified feature
#
#                                                               property_type  \
# https://www.domain.com.au/72a-argus-street-chel...                Townhouse
# https://www.domain.com.au/8-42-wright-street-mc...                Townhouse
# https://www.domain.com.au/802-1-ascot-vale-road...  Apartment / Unit / Flat
# https://www.domain.com.au/2209-22-dorcas-street...  Apartment / Unit / Flat
# https://www.domain.com.au/511-228-a-beckett-st-...  Apartment / Unit / Flat
#
#                                                    date_available   bond  \
# https://www.domain.com.au/72a-argus-street-chel...  Available Now  $6300
# https://www.domain.com.au/8-42-wright-street-mc...  Available Now  $3476
# https://www.domain.com.au/802-1-ascot-vale-road...  Available Now  $2173
# https://www.domain.com.au/2209-22-dorcas-street...  Available Now  $2520
# https://www.domain.com.au/511-228-a-beckett-st-...  Available Now  $2086
#
#                                                                                     property_features  \
# https://www.domain.com.au/72a-argus-street-chel...  [Split System Air Con, Split System Heating, O...
# https://www.domain.com.au/8-42-wright-street-mc...  [Floorboards, Built in wardrobes, Dishwasher, ...
# https://www.domain.com.au/802-1-ascot-vale-road...  [Car Accom: Basement Carspace, Heating: Revers...
# https://www.domain.com.au/2209-22-dorcas-street...  [Internal Laundry*, Furnished*, Built in wardr...
# https://www.domain.com.au/511-228-a-beckett-st-...  [Heating*, Air conditioning, Alarm System, Int...
#
#                                                                    coordinates  \
# https://www.domain.com.au/72a-argus-street-chel...  [-37.9592116, 145.0649156]
# https://www.domain.com.au/8-42-wright-street-mc...  [-37.9134094, 145.0308476]
# https://www.domain.com.au/802-1-ascot-vale-road...  [-37.7867825, 144.9213168]
# https://www.domain.com.au/2209-22-dorcas-street...  [-37.8301483, 144.9696742]
# https://www.domain.com.au/511-228-a-beckett-st-...  [-37.8102641, 144.9566396]
#
#                                                      latitude   longitude
# https://www.domain.com.au/72a-argus-street-chel... -37.959212  145.064916
# https://www.domain.com.au/8-42-wright-street-mc... -37.913409  145.030848
# https://www.domain.com.au/802-1-ascot-vale-road... -37.786783  144.921317
# https://www.domain.com.au/2209-22-dorcas-street... -37.830148  144.969674
# https://www.domain.com.au/511-228-a-beckett-st-... -37.810264  144.956640

# %%
# Create a GeoDataFrame
geometry = [Point(xy) for xy in zip(rental_df['longitude'], rental_df['latitude'])]
rental_gdf = gpd.GeoDataFrame(rental_df, geometry=geometry)

# Set the Coordinate Reference System (CRS) if known, e.g., EPSG:4326 for WGS84
rental_gdf.set_crs(epsg=4326, inplace=True)

# Display the first few rows of the GeoDataFrame
rental_gdf.head()
# Out:
#                                                                                           name  \
# https://www.domain.com.au/72a-argus-street-chel...       72A Argus Street, Cheltenham VIC 3192
# https://www.domain.com.au/8-42-wright-street-mc...       8/42 Wright Street, McKinnon VIC 3204
# https://www.domain.com.au/802-1-ascot-vale-road...  802/1 Ascot Vale Road, Flemington VIC 3031
# https://www.domain.com.au/2209-22-dorcas-street...   2209/22 Dorcas Street, Southbank VIC 3006
# https://www.domain.com.au/511-228-a-beckett-st-...    511/228 A'Beckett St, Melbourne VIC 3000
#
#                                                            cost_text  \
# https://www.domain.com.au/72a-argus-street-chel...   $1,050 Per Week
# https://www.domain.com.au/8-42-wright-street-mc...              $800
# https://www.domain.com.au/802-1-ascot-vale-road...  $500.00 per week
# https://www.domain.com.au/2209-22-dorcas-street...     $580 per week
# https://www.domain.com.au/511-228-a-beckett-st-...       $480 weekly
#
#                                                                 rooms  \
# https://www.domain.com.au/72a-argus-street-chel...  [4 Beds, 3 Baths]
# https://www.domain.com.au/8-42-wright-street-mc...  [3 Beds, 2 Baths]
# https://www.domain.com.au/802-1-ascot-vale-road...    [1 Bed, 1 Bath]
# https://www.domain.com.au/2209-22-dorcas-street...    [1 Bed, 1 Bath]
# https://www.domain.com.au/511-228-a-beckett-st-...    [1 Bed, 1 Bath]
#
#                                                         parking  \
# https://www.domain.com.au/72a-argus-street-chel...  [2 Parking]
# https://www.domain.com.au/8-42-wright-street-mc...  [1 Parking]
# https://www.domain.com.au/802-1-ascot-vale-road...  [1 Parking]
# https://www.domain.com.au/2209-22-dorcas-street...  [1 Parking]
# https://www.domain.com.au/511-228-a-beckett-st-...  [− Parking]
#
#                                                                                                  desc  \
# https://www.domain.com.au/72a-argus-street-chel...  Brand new and with a commanding street presenc...
# https://www.domain.com.au/8-42-wright-street-mc...  Nestling into the manicured gardens of Allnutt...
# https://www.domain.com.au/802-1-ascot-vale-road...  Positioned for absolute convenience, close to ...
# https://www.domain.com.au/2209-22-dorcas-street...                               * Unverified feature
# https://www.domain.com.au/511-228-a-beckett-st-...                               * Unverified feature
#
#                                                               property_type  \
# https://www.domain.com.au/72a-argus-street-chel...                Townhouse
# https://www.domain.com.au/8-42-wright-street-mc...                Townhouse
# https://www.domain.com.au/802-1-ascot-vale-road...  Apartment / Unit / Flat
# https://www.domain.com.au/2209-22-dorcas-street...  Apartment / Unit / Flat
# https://www.domain.com.au/511-228-a-beckett-st-...  Apartment / Unit / Flat
#
#                                                    date_available   bond  \
# https://www.domain.com.au/72a-argus-street-chel...  Available Now  $6300
# https://www.domain.com.au/8-42-wright-street-mc...  Available Now  $3476
# https://www.domain.com.au/802-1-ascot-vale-road...  Available Now  $2173
# https://www.domain.com.au/2209-22-dorcas-street...  Available Now  $2520
# https://www.domain.com.au/511-228-a-beckett-st-...  Available Now  $2086
#
#                                                                                     property_features  \
# https://www.domain.com.au/72a-argus-street-chel...  [Split System Air Con, Split System Heating, O...
# https://www.domain.com.au/8-42-wright-street-mc...  [Floorboards, Built in wardrobes, Dishwasher, ...
# https://www.domain.com.au/802-1-ascot-vale-road...  [Car Accom: Basement Carspace, Heating: Revers...
# https://www.domain.com.au/2209-22-dorcas-street...  [Internal Laundry*, Furnished*, Built in wardr...
# https://www.domain.com.au/511-228-a-beckett-st-...  [Heating*, Air conditioning, Alarm System, Int...
#
#                                                                    coordinates  \
# https://www.domain.com.au/72a-argus-street-chel...  [-37.9592116, 145.0649156]
# https://www.domain.com.au/8-42-wright-street-mc...  [-37.9134094, 145.0308476]
# https://www.domain.com.au/802-1-ascot-vale-road...  [-37.7867825, 144.9213168]
# https://www.domain.com.au/2209-22-dorcas-street...  [-37.8301483, 144.9696742]
# https://www.domain.com.au/511-228-a-beckett-st-...  [-37.8102641, 144.9566396]
#
#                                                      latitude   longitude  \
# https://www.domain.com.au/72a-argus-street-chel... -37.959212  145.064916
# https://www.domain.com.au/8-42-wright-street-mc... -37.913409  145.030848
# https://www.domain.com.au/802-1-ascot-vale-road... -37.786783  144.921317
# https://www.domain.com.au/2209-22-dorcas-street... -37.830148  144.969674
# https://www.domain.com.au/511-228-a-beckett-st-... -37.810264  144.956640
#
#                                                                        geometry
# https://www.domain.com.au/72a-argus-street-chel...  POINT (145.06492 -37.95921)
# https://www.domain.com.au/8-42-wright-street-mc...  POINT (145.03085 -37.91341)
# https://www.domain.com.au/802-1-ascot-vale-road...  POINT (144.92132 -37.78678)
# https://www.domain.com.au/2209-22-dorcas-street...  POINT (144.96967 -37.83015)
# https://www.domain.com.au/511-228-a-beckett-st-...  POINT (144.95664 -37.81026)

# %% [markdown]
# ## Calculating distances to closest train station

# %%
# Make sure CRS is EPSG 4326 for Rental Data
rental_gdf = rental_gdf.to_crs(epsg=4326)
print(rental_gdf.crs)
# Out:
# EPSG:4326

# %%
# Make sure CRS is EPSG 4326 for Train Data
train_gdf = train_gdf.to_crs(epsg=4326)
print(train_gdf.crs)
# Out:
# EPSG:4326

# %%
# Initialize OpenRouteService client with your API key
api_key = '5b3ce3597851110001cf62483425e548d4ed4c2ca4a6b5814be96094'
client = Client(key=api_key)

# %% [markdown]
# ## Creating Train Station Isochrones

# %%
# THIS TAKES A WHILE. EXPECT IT TO BE ABOUT 13 MINUTES

def generate_isochrones(train_gdf, client, processed_stations, output_file, interval=600):  # 600 seconds = 10 minutes
    isochrone_features = []  # To store all isochrone features
    
    for index, train_station in train_gdf.iterrows():
        station_id = train_station['stop_id']  # Use STOP_ID
        station_name = train_station['stop_name']  # Use STOP_NAME
        lat, lon = train_station.geometry.y, train_station.geometry.x
        
        # Skip if station already processed
        if station_id in processed_stations:
            continue
        
        print(f"Processing: {station_id} - {station_name} (Lat: {lat}, Lon: {lon})")
        
        # Isochrone parameters for 10 minutes (600 seconds) driving time
        params_iso = {
            'profile': 'driving-car',
            'intervals': [interval],  # Single interval of 10 minutes
            'locations': [[lon, lat]],
        }
        
        try:
            # Fetch isochrones
            isochrones = client.isochrones(**params_iso)
            
            # Convert the isochrone to a GeoJSON Feature
            for feature in isochrones['features']:
                isochrone_feature = {
                    'type': 'Feature',
                    'geometry': feature['geometry'],  # Isochrone geometry
                    'properties': {
                        'station_id': station_id,  # Use STOP_ID
                        'station_name': station_name,  # Use STOP_NAME
                        'interval': interval,  # 10-minute interval
                        'latitude': lat,
                        'longitude': lon
                    }
                }
                isochrone_features.append(isochrone_feature)
            
            # Mark station as processed
            processed_stations.append(station_id)

            # Delay to prevent hitting the rate limit
            delay = 3
            time.sleep(delay)
            
        except Exception as e:
            print(f"Error processing station {station_id} - {station_name}: {e}")
    
    # Print the count and sample of isochrone features
    print(f"Isochrone features count: {len(isochrone_features)}")
    print("Sample isochrone features:", json.dumps(isochrone_features[:1], indent=2))
    
    # Create a GeoJSON structure to hold all isochrones
    isochrone_collection = {
        'type': 'FeatureCollection',
        'features': isochrone_features
    }
    
    # Ensure the directory exists
    output_directory = os.path.dirname(output_file)
    os.makedirs(output_directory, exist_ok=True)
    
    # Save the entire collection to a single GeoJSON file
    with open(output_file, 'w') as f:
        json.dump(isochrone_collection, f, indent=2)
    
    print(f"All isochrones saved to {output_file}")

# Prepare test parameters
processed_stations = []

# Run the test
generate_isochrones(
    train_gdf, 
    client, 
    processed_stations, 
    '../data/curated/isochrones/isochrones.geojson',
    interval=600
)
# Out:
# Processing: 19970 - Royal Park Railway Station (Parkville) (Lat: -37.7811929725527, Lon: 144.95230120580877)
# Processing: 19971 - Flemington Bridge Railway Station (North Melbourne) (Lat: -37.788139984393844, Lon: 144.93932321237276)
# Processing: 19972 - Macaulay Railway Station (North Melbourne) (Lat: -37.79426700459872, Lon: 144.93616600406753)
# Processing: 19973 - North Melbourne Railway Station (West Melbourne) (Lat: -37.80741897361899, Lon: 144.94257002890663)
# Processing: 19974 - Clifton Hill Railway Station (Clifton Hill) (Lat: -37.78865703363607, Lon: 144.9954169601631)
# Processing: 19975 - Victoria Park Railway Station (Abbotsford) (Lat: -37.79915796626723, Lon: 144.9944510689111)
# Processing: 19976 - Collingwood Railway Station (Abbotsford) (Lat: -37.80452601640281, Lon: 144.99375014165992)
# Processing: 19977 - North Richmond Railway Station (Richmond) (Lat: -37.8103979761548, Lon: 144.9924998535909)
# Processing: 19978 - West Richmond Railway Station (Richmond) (Lat: -37.81494900584843, Lon: 144.991423087592)
# Processing: 19979 - Jolimont-MCG Railway Station (East Melbourne) (Lat: -37.816526974237526, Lon: 144.9840981689869)
# Processing: 19983 - Macleod Railway Station (Macleod) (Lat: -37.72601198852847, Lon: 145.06914313196347)
# Processing: 19984 - Watsonia Railway Station (Watsonia) (Lat: -37.71095796058549, Lon: 145.08379299256393)
# Processing: 19985 - Greensborough Railway Station (Greensborough) (Lat: -37.703953978517774, Lon: 145.10824705206068)
# Processing: 19986 - Montmorency Railway Station (Montmorency) (Lat: -37.715295960542775, Lon: 145.121515927139)
# Processing: 19987 - Eltham Railway Station (Eltham) (Lat: -37.71354996061303, Lon: 145.14782184864805)
# Processing: 19988 - Diamond Creek Railway Station (Diamond Creek) (Lat: -37.67329701063555, Lon: 145.1585059320563)
# Processing: 19989 - Wattle Glen Railway Station (Wattle Glen) (Lat: -37.66396797039701, Lon: 145.18161506467828)
# Processing: 19990 - Hurstbridge Railway Station (Hurstbridge) (Lat: -37.639397969862365, Lon: 145.1920168942208)
# Processing: 19991 - Williamstown Railway Station (Williamstown) (Lat: -37.867752990404725, Lon: 144.90532295721854)
# Processing: 19992 - Williamstown Beach Railway Station (Williamstown) (Lat: -37.86398198938481, Lon: 144.89448409561462)
# Processing: 19993 - North Williamstown Railway Station (Williamstown) (Lat: -37.85733296977821, Lon: 144.88906897782545)
# Processing: 19994 - Newport Railway Station (Newport) (Lat: -37.84271796018809, Lon: 144.88359986187862)
# Processing: 19995 - Spotswood Railway Station (Spotswood) (Lat: -37.83063897072853, Lon: 144.8859330113764)
# Processing: 19996 - Yarraville Railway Station (Yarraville) (Lat: -37.815849989791694, Lon: 144.8899340507632)
# Processing: 19997 - Seddon Railway Station (Seddon) (Lat: -37.809005040754464, Lon: 144.89567208120746)
# Processing: 20000 - Watergardens Railway Station (Sydenham) (Lat: -37.70112896819069, Lon: 144.77418001840798)
# Processing: 20001 - Keilor Plains Railway Station (St Albans) (Lat: -37.72927898714574, Lon: 144.79373809136527)
# Processing: 20002 - St Albans Railway Station (St Albans) (Lat: -37.74486095681743, Lon: 144.8000499727449)
# Processing: 20003 - Ginifer Railway Station (St Albans) (Lat: -37.76006699999778, Lon: 144.81134785114367)
# Processing: 20004 - Albion Railway Station (Sunshine North) (Lat: -37.77765299958764, Lon: 144.82470386247024)
# Processing: 20005 - Epping Railway Station (Epping) (Lat: -37.65218696812649, Lon: 145.03106807483192)
# Processing: 20006 - Lalor Railway Station (Lalor) (Lat: -37.665851039818996, Lon: 145.01719296110826)
# Processing: 20007 - Thomastown Railway Station (Thomastown) (Lat: -37.680337978698795, Lon: 145.01427914567134)
# Processing: 20008 - Keon Park Railway Station (Thomastown) (Lat: -37.6948700083548, Lon: 145.01188405834273)
# Processing: 20009 - Ruthven Railway Station (Reservoir) (Lat: -37.707897956372506, Lon: 145.00951704207858)
# Processing: 20010 - Reservoir Railway Station (Reservoir) (Lat: -37.71688499694048, Lon: 145.00699596597707)
# Processing: 20011 - Regent Railway Station (Reservoir) (Lat: -37.728403018220824, Lon: 145.00277316312736)
# Processing: 20012 - Preston Railway Station (Preston) (Lat: -37.738673997291826, Lon: 145.00052208049493)
# Processing: 20013 - Bell Railway Station (Preston) (Lat: -37.74556196740014, Lon: 145.00015487669162)
# Processing: 20014 - Thornbury Railway Station (Thornbury) (Lat: -37.75505201755157, Lon: 144.99857195554867)
# Processing: 20015 - Croxton Railway Station (Northcote) (Lat: -37.764100977920975, Lon: 144.99705601149938)
# Processing: 20016 - Northcote Railway Station (Northcote) (Lat: -37.7698650286647, Lon: 144.99527690393882)
# Processing: 20017 - Merri Railway Station (Northcote) (Lat: -37.77784704042674, Lon: 144.9929721934344)
# Processing: 20019 - Rushall Railway Station (Fitzroy North) (Lat: -37.783216981751494, Lon: 144.99240699877623)
# Processing: 20021 - Sunshine Railway Station (Sunshine) (Lat: -37.78853598103241, Lon: 144.83287803702032)
# Processing: 20022 - Tottenham Railway Station (West Footscray) (Lat: -37.79925101953307, Lon: 144.86294482805647)
# Processing: 20023 - West Footscray Railway Station (West Footscray) (Lat: -37.80180296938542, Lon: 144.88398504854027)
# Processing: 20024 - Middle Footscray Railway Station (Footscray) (Lat: -37.802504970278676, Lon: 144.8914719665355)
# Processing: 20025 - Footscray Railway Station (Footscray) (Lat: -37.80108297392747, Lon: 144.90319893797937)
# Processing: 20026 - South Kensington Railway Station (Kensington) (Lat: -37.799531010135645, Lon: 144.92546896739066)
# Processing: 20030 - Broadmeadows Railway Station (Broadmeadows) (Lat: -37.68304895729302, Lon: 144.91961320131395)
# Processing: 20031 - Jacana Railway Station (Glenroy) (Lat: -37.695131010164516, Lon: 144.9158511944258)
# Processing: 20032 - Glenroy Railway Station (Glenroy) (Lat: -37.70453600891375, Lon: 144.91721989592028)
# Processing: 20033 - Oak Park Railway Station (Oak Park) (Lat: -37.71794996733691, Lon: 144.9215190050332)
# Processing: 20034 - Pascoe Vale Railway Station (Pascoe Vale) (Lat: -37.73075597710179, Lon: 144.92819593517615)
# Processing: 20035 - Strathmore Railway Station (Strathmore) (Lat: -37.74359096751782, Lon: 144.92731609110757)
# Processing: 20036 - Glenbervie Railway Station (Essendon) (Lat: -37.74720995793417, Lon: 144.9209390576499)
# Processing: 20037 - Essendon Railway Station (Essendon) (Lat: -37.75601195980886, Lon: 144.91619785779378)
# Processing: 20038 - Moonee Ponds Railway Station (Moonee Ponds) (Lat: -37.765707029872225, Lon: 144.91916101804085)
# Processing: 20039 - Ascot Vale Railway Station (Ascot Vale) (Lat: -37.775305978752286, Lon: 144.92182105511844)
# Processing: 20040 - Newmarket Railway Station (Flemington) (Lat: -37.78732800123391, Lon: 144.9289778791842)
# Processing: 20041 - Kensington Railway Station (Kensington) (Lat: -37.79378001234484, Lon: 144.93052408229383)
# Processing: 20042 - Box Hill Railway Station (Box Hill) (Lat: -37.819222033091656, Lon: 145.1214291542125)
# Processing: 22180 - Southern Cross Railway Station (Melbourne City) (Lat: -37.81793601351573, Lon: 144.9514108850503)
# Processing: 40220 - Roxburgh Park Railway Station (Roxburgh Park) (Lat: -37.63823102879973, Lon: 144.9354038580987)
# Processing: 40221 - Craigieburn Railway Station (Craigieburn) (Lat: -37.6018170275946, Lon: 144.94331989483877)
# Processing: 44817 - Coolaroo Railway Station (Coolaroo) (Lat: -37.6610030113571, Lon: 144.92605609416944)
# Processing: 45793 - Lynbrook Railway Station (Lynbrook) (Lat: -38.057340961642154, Lon: 145.24927487781102)
# Processing: 45794 - Cardinia Road Railway Station (Pakenham) (Lat: -38.071289971320894, Lon: 145.43779105694023)
# Processing: 45795 - South Morang Railway Station (South Morang) (Lat: -37.64915901306895, Lon: 145.0670320966615)
# Processing: 46468 - Williams Landing Railway Station (Williams Landing) (Lat: -37.8698650235294, Lon: 144.74744497619167)
# Processing: 52095 - Southland Railway Station (Cheltenham) (Lat: -37.95875605115335, Lon: 145.0491210080803)
# Processing: 52159 - Middle Gorge Railway Station (South Morang) (Lat: -37.644060959065094, Lon: 145.09214389829435)
# Processing: 52160 - Hawkstowe Railway Station (South Morang) (Lat: -37.62299502042986, Lon: 145.0973959520007)
# Processing: 52161 - Mernda Railway Station (Mernda) (Lat: -37.602548008693105, Lon: 145.1008850816138)
# Processing: 15351 - Sunbury Railway Station (Sunbury) (Lat: -37.579091041919106, Lon: 144.7273191965987)
# Processing: 15353 - Diggers Rest Railway Station (Diggers Rest) (Lat: -37.62701703098356, Lon: 144.719921894289)
# Processing: 19827 - Stony Point Railway Station (Crib Point) (Lat: -38.37423501463105, Lon: 145.2218371303087)
# Processing: 19828 - Crib Point Railway Station (Crib Point) (Lat: -38.366123042492156, Lon: 145.20404302458843)
# Processing: 19829 - Morradoo Railway Station (Crib Point) (Lat: -38.35403298231219, Lon: 145.18960200468328)
# Processing: 19830 - Bittern Railway Station (Bittern) (Lat: -38.33739000410354, Lon: 145.17802694776515)
# Processing: 19831 - Hastings Railway Station (Hastings) (Lat: -38.30565897380473, Lon: 145.18598004542605)
# Processing: 19832 - Tyabb Railway Station (Tyabb) (Lat: -38.25981504276969, Lon: 145.18640091121645)
# Processing: 19833 - Somerville Railway Station (Somerville) (Lat: -38.22534198465516, Lon: 145.17624495783332)
# Processing: 19834 - Baxter Railway Station (Baxter) (Lat: -38.194043042101164, Lon: 145.1605259068461)
# Processing: 19835 - Glen Iris Railway Station (Glen Iris) (Lat: -37.85930802724669, Lon: 145.0582250497741)
# Processing: 19836 - Leawarra Railway Station (Frankston) (Lat: -38.152034013128976, Lon: 145.1395339285365)
# Processing: 19837 - Darling Railway Station (Malvern East) (Lat: -37.86895701673703, Lon: 145.06295114201313)
# Processing: 19838 - East Malvern Railway Station (Malvern East) (Lat: -37.87693002547972, Lon: 145.06939298848198)
# Processing: 19839 - Holmesglen Railway Station (Malvern East) (Lat: -37.874402019247384, Lon: 145.09066211307118)
# Processing: 19840 - Jordanville Railway Station (Mount Waverley) (Lat: -37.87360300336732, Lon: 145.11209003619842)
# Processing: 19841 - Flagstaff Railway Station (Melbourne City) (Lat: -37.811980983068906, Lon: 144.95565385897856)
# Processing: 19842 - Melbourne Central Railway Station (Melbourne City) (Lat: -37.80993897219737, Lon: 144.9625939477722)
# Processing: 19843 - Parliament Railway Station (Melbourne City) (Lat: -37.81105398311787, Lon: 144.9729111811868)
# Processing: 19844 - Belgrave Railway Station (Belgrave) (Lat: -37.90910196303172, Lon: 145.35529094228033)
# Processing: 19845 - Tecoma Railway Station (Tecoma) (Lat: -37.90811799418759, Lon: 145.3429951499282)
# Processing: 19846 - Upwey Railway Station (Upwey) (Lat: -37.903690983475485, Lon: 145.33133294736945)
# Processing: 19847 - Alamein Railway Station (Ashburton) (Lat: -37.86831999881286, Lon: 145.0796558510017)
# Processing: 19848 - Ashburton Railway Station (Ashburton) (Lat: -37.86196798070856, Lon: 145.08134389547052)
# Processing: 19849 - Burwood Railway Station (Glen Iris) (Lat: -37.851562991336685, Lon: 145.08051084427572)
# Processing: 19850 - Hartwell Railway Station (Camberwell) (Lat: -37.843984988466225, Lon: 145.0755601197322)
# Processing: 19851 - Willison Railway Station (Camberwell) (Lat: -37.835715965394016, Lon: 145.07029800484113)
# Processing: 19852 - Riversdale Railway Station (Camberwell) (Lat: -37.831505045420805, Lon: 145.0696460448304)
# Processing: 19853 - Camberwell Railway Station (Camberwell) (Lat: -37.826567020894245, Lon: 145.05869701396765)
# Processing: 19854 - Flinders Street Railway Station (Melbourne City) (Lat: -37.81830501305625, Lon: 144.96696399665555)
# Processing: 19855 - Frankston Railway Station (Frankston) (Lat: -38.14299000537099, Lon: 145.12616208447614)
# Processing: 19856 - Kananook Railway Station (Seaford) (Lat: -38.12174199466812, Lon: 145.13529493934251)
# Processing: 19857 - Seaford Railway Station (Seaford) (Lat: -38.10402099378123, Lon: 145.12822994038072)
# Processing: 19858 - Carrum Railway Station (Carrum) (Lat: -38.076504033265415, Lon: 145.1228331806026)
# Processing: 19859 - Bonbeach Railway Station (Bonbeach) (Lat: -38.06294499455282, Lon: 145.11967993833284)
# Processing: 19860 - Chelsea Railway Station (Chelsea) (Lat: -38.05195500582945, Lon: 145.1160410561567)
# Processing: 19861 - Edithvale Railway Station (Edithvale) (Lat: -38.03805603411457, Lon: 145.10853614659555)
# Processing: 19862 - Aspendale Railway Station (Aspendale) (Lat: -38.02722003428127, Lon: 145.10215009763107)
# Processing: 19863 - Mordialloc Railway Station (Mordialloc) (Lat: -38.006583036530465, Lon: 145.08765900709295)
# Processing: 19864 - Parkdale Railway Station (Parkdale) (Lat: -37.993078985669186, Lon: 145.0763269243707)
# Processing: 19865 - Mentone Railway Station (Mentone) (Lat: -37.98186498543101, Lon: 145.06516585321697)
# Processing: 19866 - Cheltenham Railway Station (Cheltenham) (Lat: -37.96665004267008, Lon: 145.05455809320318)
# Processing: 19867 - Upper Ferntree Gully Railway Station (Upper Ferntree Gully) (Lat: -37.89267201519074, Lon: 145.30753010573622)
# Processing: 19868 - Ferntree Gully Railway Station (Ferntree Gully) (Lat: -37.88169804430563, Lon: 145.2952508595173)
# Processing: 19869 - Boronia Railway Station (Boronia) (Lat: -37.86045201284621, Lon: 145.28438498378276)
# Processing: 19870 - Bayswater Railway Station (Bayswater) (Lat: -37.84173003269863, Lon: 145.26813602050083)
# Processing: 19871 - Heathmont Railway Station (Heathmont) (Lat: -37.828322013500426, Lon: 145.24455493593294)
# Processing: 19872 - Highett Railway Station (Highett) (Lat: -37.948425037176236, Lon: 145.04187207003986)
# Processing: 19873 - Glen Waverley Railway Station (Glen Waverley) (Lat: -37.87950402884809, Lon: 145.16205804677077)
# Processing: 19874 - Syndal Railway Station (Glen Waverley) (Lat: -37.87623001198126, Lon: 145.14977988400065)
# Processing: 19875 - Mount Waverley Railway Station (Mount Waverley) (Lat: -37.87525504140691, Lon: 145.1280560390715)
# Processing: 19876 - Lilydale Railway Station (Lilydale) (Lat: -37.75551804148801, Lon: 145.34771006372208)
# Processing: 19877 - Mooroolbark Railway Station (Mooroolbark) (Lat: -37.78474896242301, Lon: 145.312401980717)
# Processing: 19878 - Croydon Railway Station (Croydon) (Lat: -37.795437003004096, Lon: 145.28059813649503)
# Processing: 19879 - Ringwood East Railway Station (Ringwood East) (Lat: -37.811968020901645, Lon: 145.25019111735213)
# Processing: 19880 - Pakenham Railway Station (Pakenham) (Lat: -38.080613971994666, Lon: 145.4863791670269)
# Processing: 19881 - Officer Railway Station (Officer) (Lat: -38.06614602358953, Lon: 145.41098691161596)
# Processing: 19882 - Beaconsfield Railway Station (Beaconsfield) (Lat: -38.05083099268969, Lon: 145.36607402041432)
# Processing: 19883 - Berwick Railway Station (Berwick) (Lat: -38.04040800417337, Lon: 145.345726106732)
# Processing: 19884 - Narre Warren Railway Station (Narre Warren) (Lat: -38.02780899067889, Lon: 145.30396899348813)
# Processing: 19885 - Hallam Railway Station (Hallam) (Lat: -38.0177399723026, Lon: 145.26977691372707)
# Processing: 19886 - Cranbourne Railway Station (Cranbourne) (Lat: -38.099537015167755, Lon: 145.2805988876704)
# Processing: 19887 - Merinda Park Railway Station (Cranbourne North) (Lat: -38.07900000428343, Lon: 145.26351110606686)
# Processing: 19888 - Dandenong Railway Station (Dandenong) (Lat: -37.98996804320864, Lon: 145.20972494168106)
# Processing: 19889 - Yarraman Railway Station (Noble Park) (Lat: -37.97825499531765, Lon: 145.19160002133484)
# Processing: 19890 - Noble Park Railway Station (Noble Park) (Lat: -37.96662798649904, Lon: 145.17632485727145)
# Processing: 19891 - Sandown Park Railway Station (Springvale) (Lat: -37.9565049634813, Lon: 145.16282594045538)
# Processing: 19892 - East Camberwell Railway Station (Camberwell) (Lat: -37.82589399751228, Lon: 145.06818984612514)
# Processing: 19893 - Canterbury Railway Station (Canterbury) (Lat: -37.824485052015234, Lon: 145.08122400522683)
# Processing: 19894 - Chatham Railway Station (Surrey Hills) (Lat: -37.824300013259794, Lon: 145.08864792992347)
# Processing: 19895 - Surrey Hills Railway Station (Surrey Hills) (Lat: -37.82414800244947, Lon: 145.09877510312708)
# Processing: 19896 - Mont Albert Railway Station (Mont Albert) (Lat: -37.819427052222316, Lon: 145.1055301411415)
# Processing: 19897 - Laburnum Railway Station (Blackburn) (Lat: -37.82078002325073, Lon: 145.1407028348687)
# Processing: 19898 - Blackburn Railway Station (Blackburn) (Lat: -37.820071002378896, Lon: 145.1500138764687)
# Processing: 19899 - Nunawading Railway Station (Nunawading) (Lat: -37.82042802941446, Lon: 145.1752369288804)
# Processing: 19900 - Mitcham Railway Station (Mitcham) (Lat: -37.818087035153475, Lon: 145.1928920581536)
# Processing: 19901 - Heatherdale Railway Station (Ringwood) (Lat: -37.81883502338564, Lon: 145.21354994696432)
# Processing: 19902 - Ringwood Railway Station (Ringwood) (Lat: -37.81566000007894, Lon: 145.2294741698739)
# Processing: 19903 - Auburn Railway Station (Hawthorn East) (Lat: -37.82239804230204, Lon: 145.04584392844583)
# Processing: 19904 - Glenferrie Railway Station (Hawthorn) (Lat: -37.821466991314885, Lon: 145.03643891857303)
# Processing: 19905 - Hawthorn Railway Station (Hawthorn) (Lat: -37.821825996611395, Lon: 145.02289894827368)
# Processing: 19906 - Burnley Railway Station (Burnley) (Lat: -37.82755998022155, Lon: 145.0075550556105)
# Processing: 19907 - East Richmond Railway Station (Richmond) (Lat: -37.82639997289394, Lon: 144.9970661029343)
# Processing: 19908 - Richmond Railway Station (Richmond) (Lat: -37.82407401385715, Lon: 144.9901641806745)
# Processing: 19909 - Heyington Railway Station (Toorak) (Lat: -37.834671965373985, Lon: 145.02263508424622)
# Processing: 19910 - Kooyong Railway Station (Kooyong) (Lat: -37.839929048366116, Lon: 145.03355208421473)
# Processing: 19911 - Tooronga Railway Station (Malvern) (Lat: -37.84936599739654, Lon: 145.04173415478712)
# Processing: 19912 - Gardiner Railway Station (Glen Iris) (Lat: -37.85327901773509, Lon: 145.05165504987352)
# Processing: 19913 - Springvale Railway Station (Springvale) (Lat: -37.94950899259216, Lon: 145.1534518921023)
# Processing: 19914 - Westall Railway Station (Clayton South) (Lat: -37.938491011333234, Lon: 145.13883302874603)
# Processing: 19915 - Clayton Railway Station (Clayton) (Lat: -37.92468303486988, Lon: 145.12053387025009)
# Processing: 19916 - Huntingdale Railway Station (Oakleigh) (Lat: -37.911016990825836, Lon: 145.10236393324308)
# Processing: 19917 - Oakleigh Railway Station (Oakleigh) (Lat: -37.90037196749365, Lon: 145.0883080921356)
# Processing: 19918 - Hughesdale Railway Station (Hughesdale) (Lat: -37.89488097733909, Lon: 145.07763518406495)
# Processing: 19919 - Murrumbeena Railway Station (Murrumbeena) (Lat: -37.89019800833117, Lon: 145.0673751866043)
# Processing: 19920 - Carnegie Railway Station (Carnegie) (Lat: -37.886240976370786, Lon: 145.05857497723898)
# Processing: 19921 - Werribee Railway Station (Werribee) (Lat: -37.89937800378759, Lon: 144.66111806209827)
# Processing: 19922 - Hoppers Crossing Railway Station (Hoppers Crossing) (Lat: -37.88327601324334, Lon: 144.7009549451706)
# Processing: 19923 - Laverton Railway Station (Laverton) (Lat: -37.863693995393945, Lon: 144.77261691069953)
# Processing: 19924 - Aircraft Railway Station (Laverton) (Lat: -37.866606032750546, Lon: 144.7608088985207)
# Processing: 19925 - Westona Railway Station (Altona) (Lat: -37.8651629765648, Lon: 144.81349417315855)
# Processing: 19926 - Altona Railway Station (Altona) (Lat: -37.86714801409339, Lon: 144.82964484849458)
# Processing: 19927 - Seaholme Railway Station (Seaholme) (Lat: -37.86784200270676, Lon: 144.84095784803088)
# Processing: 19928 - Westgarth Railway Station (Northcote) (Lat: -37.780621021498604, Lon: 144.9992329526931)
# Processing: 19929 - Dennis Railway Station (Northcote) (Lat: -37.779186960703825, Lon: 145.00824193502052)
# Processing: 19930 - Fairfield Railway Station (Fairfield) (Lat: -37.77917103027729, Lon: 145.01690497413267)
# Processing: 19931 - Alphington Railway Station (Alphington) (Lat: -37.778393970184325, Lon: 145.0312549420362)
# Processing: 19932 - Darebin Railway Station (Ivanhoe) (Lat: -37.774962990239736, Lon: 145.0384761897359)
# Processing: 19933 - Ivanhoe Railway Station (Ivanhoe) (Lat: -37.76889698950453, Lon: 145.0454249007254)
# Processing: 19934 - Eaglemont Railway Station (Eaglemont) (Lat: -37.76358600115558, Lon: 145.0539428530202)
# Processing: 19935 - Heidelberg Railway Station (Heidelberg) (Lat: -37.75707297186314, Lon: 145.06068602994233)
# Processing: 19936 - Rosanna Railway Station (Rosanna) (Lat: -37.74287898170107, Lon: 145.06614004306664)
# Processing: 19937 - Moorabbin Railway Station (Moorabbin) (Lat: -37.934352997334734, Lon: 145.0367381151247)
# Processing: 19938 - Patterson Railway Station (Bentleigh) (Lat: -37.9251489679829, Lon: 145.03547018698544)
# Processing: 19939 - Bentleigh Railway Station (Bentleigh) (Lat: -37.917424987593655, Lon: 145.0369951450514)
# Processing: 19940 - McKinnon Railway Station (Mckinnon) (Lat: -37.9103090471004, Lon: 145.03829905678242)
# Processing: 19941 - Ormond Railway Station (Ormond) (Lat: -37.903212006932286, Lon: 145.0396130453646)
# Processing: 19942 - Glenhuntly Railway Station (Glen Huntly) (Lat: -37.889719026839934, Lon: 145.04222302981012)
# Processing: 19943 - Caulfield Railway Station (Caulfield East) (Lat: -37.87745904950535, Lon: 145.04252511062438)
# Processing: 19944 - Malvern Railway Station (Malvern) (Lat: -37.86625296743994, Lon: 145.02929401539313)
# Processing: 19945 - Armadale Railway Station (Armadale) (Lat: -37.85645196640077, Lon: 145.0193259624038)
# Processing: 19946 - Toorak Railway Station (Armadale) (Lat: -37.85077404613171, Lon: 145.01390904858653)
# Processing: 19947 - Hawksburn Railway Station (South Yarra) (Lat: -37.84459104465304, Lon: 145.00214211386543)
# Processing: 19948 - Sandringham Railway Station (Sandringham) (Lat: -37.95032997678135, Lon: 145.00456092996131)
# Processing: 19949 - Hampton Railway Station (Hampton) (Lat: -37.93797702778554, Lon: 145.0014710475163)
# Processing: 19950 - Brighton Beach Railway Station (Brighton) (Lat: -37.92648402636408, Lon: 144.98915400748288)
# Processing: 19951 - Middle Brighton Railway Station (Brighton) (Lat: -37.91513403726259, Lon: 144.99629892106807)
# Processing: 19952 - North Brighton Railway Station (Brighton) (Lat: -37.904886999374064, Lon: 145.00260504023572)
# Processing: 19953 - Gardenvale Railway Station (Brighton) (Lat: -37.89669501891709, Lon: 145.0041681594568)
# Processing: 19954 - Elsternwick Railway Station (Elsternwick) (Lat: -37.88475300849933, Lon: 145.00089792626244)
# Processing: 19955 - Ripponlea Railway Station (Ripponlea) (Lat: -37.875906008374365, Lon: 144.99523695425376)
# Processing: 19956 - Balaclava Railway Station (Balaclava) (Lat: -37.869488016261954, Lon: 144.99351218235657)
# Processing: 19957 - Windsor Railway Station (Windsor) (Lat: -37.85605299340357, Lon: 144.99203509329004)
# Processing: 19958 - Prahran Railway Station (Prahran) (Lat: -37.849518003492406, Lon: 144.98985999271946)
# Processing: 19959 - South Yarra Railway Station (South Yarra) (Lat: -37.83844899324962, Lon: 144.99234219972408)
# Processing: 19960 - Upfield Railway Station (Coolaroo) (Lat: -37.66607802131612, Lon: 144.94673986754253)
# Processing: 19961 - Gowrie Railway Station (Glenroy) (Lat: -37.700677977421826, Lon: 144.95887403782967)
# Processing: 19962 - Fawkner Railway Station (Fawkner) (Lat: -37.71462095840933, Lon: 144.96054517607726)
# Processing: 19963 - Merlynston Railway Station (Coburg North) (Lat: -37.72093400681235, Lon: 144.96131413229386)
# Processing: 19964 - Batman Railway Station (Coburg North) (Lat: -37.7335230271606, Lon: 144.96284088444295)
# Processing: 19965 - Coburg Railway Station (Coburg) (Lat: -37.74234500853543, Lon: 144.96333587826746)
# Processing: 19966 - Moreland Railway Station (Coburg) (Lat: -37.7544850178849, Lon: 144.96182315245065)
# Processing: 19967 - Anstey Railway Station (Brunswick) (Lat: -37.761242037577134, Lon: 144.96068412503988)
# Processing: 19968 - Brunswick Railway Station (Brunswick) (Lat: -37.767720957795504, Lon: 144.95958686111737)
# Processing: 19969 - Jewell Railway Station (Brunswick) (Lat: -37.7749870197818, Lon: 144.95871710696892)
# Isochrone features count: 220
# Sample isochrone features: [
#   {
#     "type": "Feature",
#     "geometry": {
#       "coordinates": [
#         [
#           [
#             144.897211,
#             -37.769377
#           ],
#           [
#             144.898317,
#             -37.771499
#           ],
#           [
#             144.902936,
#             -37.775505
#           ],
#           [
#             144.908501,
#             -37.780303
#           ],
#           [
#             144.908868,
#             -37.782626
#           ],
#           [
#             144.909098,
#             -37.782875
#           ],
#           [
#             144.910307,
#             -37.783416
#           ],
#           [
#             144.914767,
#             -37.785016
#           ],
#           [
#             144.918,
#             -37.791442
#           ],
#           [
#             144.917991,
#             -37.794272
#           ],
#           [
#             144.917908,
#             -37.794854
#           ],
#           [
#             144.916556,
#             -37.79846
#           ],
#           [
#             144.916483,
#             -37.800895
#           ],
#           [
#             144.916519,
#             -37.801219
#           ],
#           [
#             144.917195,
#             -37.801556
#           ],
#           [
#             144.92138,
#             -37.80653
#           ],
#           [
#             144.921009,
#             -37.810111
#           ],
#           [
#             144.923194,
#             -37.810337
#           ],
#           [
#             144.925741,
#             -37.811022
#           ],
#           [
#             144.930852,
#             -37.818239
#           ],
#           [
#             144.929039,
#             -37.823359
#           ],
#           [
#             144.928995,
#             -37.823573
#           ],
#           [
#             144.929056,
#             -37.82441
#           ],
#           [
#             144.932656,
#             -37.824439
#           ],
#           [
#             144.932708,
#             -37.823917
#           ],
#           [
#             144.937908,
#             -37.816718
#           ],
#           [
#             144.938136,
#             -37.816632
#           ],
#           [
#             144.939236,
#             -37.816262
#           ],
#           [
#             144.945525,
#             -37.816675
#           ],
#           [
#             144.954131,
#             -37.817086
#           ],
#           [
#             144.956259,
#             -37.818037
#           ],
#           [
#             144.961264,
#             -37.818925
#           ],
#           [
#             144.962424,
#             -37.819147
#           ],
#           [
#             144.965091,
#             -37.8189
#           ],
#           [
#             144.965102,
#             -37.818897
#           ],
#           [
#             144.969763,
#             -37.816817
#           ],
#           [
#             144.971219,
#             -37.81585
#           ],
#           [
#             144.973647,
#             -37.813126
#           ],
#           [
#             144.978366,
#             -37.810084
#           ],
#           [
#             144.981142,
#             -37.807973
#           ],
#           [
#             144.982308,
#             -37.806794
#           ],
#           [
#             144.987294,
#             -37.800356
#           ],
#           [
#             144.988088,
#             -37.799737
#           ],
#           [
#             144.995554,
#             -37.797055
#           ],
#           [
#             144.997038,
#             -37.797163
#           ],
#           [
#             144.997572,
#             -37.797187
#           ],
#           [
#             144.998456,
#             -37.7972
#           ],
#           [
#             144.999136,
#             -37.797187
#           ],
#           [
#             144.999962,
#             -37.797115
#           ],
#           [
#             145.000998,
#             -37.796965
#           ],
#           [
#             145.000482,
#             -37.793402
#           ],
#           [
#             144.993764,
#             -37.788783
#           ],
#           [
#             144.993212,
#             -37.786119
#           ],
#           [
#             144.991,
#             -37.777624
#           ],
#           [
#             144.989525,
#             -37.776007
#           ],
#           [
#             144.989196,
#             -37.768193
#           ],
#           [
#             144.989309,
#             -37.767565
#           ],
#           [
#             144.988617,
#             -37.766219
#           ],
#           [
#             144.982974,
#             -37.762913
#           ],
#           [
#             144.98094,
#             -37.757473
#           ],
#           [
#             144.978726,
#             -37.751594
#           ],
#           [
#             144.976897,
#             -37.749755
#           ],
#           [
#             144.976761,
#             -37.74974
#           ],
#           [
#             144.976704,
#             -37.749734
#           ],
#           [
#             144.976533,
#             -37.74972
#           ],
#           [
#             144.974037,
#             -37.751039
#           ],
#           [
#             144.965616,
#             -37.752002
#           ],
#           [
#             144.96522,
#             -37.751957
#           ],
#           [
#             144.96166,
#             -37.751227
#           ],
#           [
#             144.955948,
#             -37.748548
#           ],
#           [
#             144.95313,
#             -37.745643
#           ],
#           [
#             144.948631,
#             -37.74135
#           ],
#           [
#             144.947333,
#             -37.739999
#           ],
#           [
#             144.943774,
#             -37.739457
#           ],
#           [
#             144.942555,
#             -37.740671
#           ],
#           [
#             144.933663,
#             -37.740919
#           ],
#           [
#             144.932317,
#             -37.738565
#           ],
#           [
#             144.932143,
#             -37.737954
#           ],
#           [
#             144.931778,
#             -37.737
#           ],
#           [
#             144.931257,
#             -37.736175
#           ],
#           [
#             144.930736,
#             -37.735534
#           ],
#           [
#             144.930432,
#             -37.735225
#           ],
#           [
#             144.930161,
#             -37.734976
#           ],
#           [
#             144.927726,
#             -37.737627
#           ],
#           [
#             144.928134,
#             -37.738579
#           ],
#           [
#             144.928989,
#             -37.740155
#           ],
#           [
#             144.925155,
#             -37.747719
#           ],
#           [
#             144.923786,
#             -37.748825
#           ],
#           [
#             144.923371,
#             -37.749341
#           ],
#           [
#             144.91878,
#             -37.755456
#           ],
#           [
#             144.911735,
#             -37.759361
#           ],
#           [
#             144.9062,
#             -37.761897
#           ],
#           [
#             144.904469,
#             -37.763166
#           ],
#           [
#             144.898732,
#             -37.767923
#           ],
#           [
#             144.897254,
#             -37.769182
#           ],
#           [
#             144.897211,
#             -37.769377
#           ]
#         ]
#       ],
#       "type": "Polygon"
#     },
#     "properties": {
#       "station_id": "19970",
#       "station_name": "Royal Park Railway Station (Parkville)",
#       "interval": 600,
#       "latitude": -37.7811929725527,
#       "longitude": 144.95230120580877
#     }
#   }
# ]
# All isochrones saved to ../data/curated/isochrones/isochrones.geojson

# %% [markdown]
# ## Creating Dataframe with only 5 Rental Properties for Testing

# %%
# Get the first 5 rows of the GeoDataFrame
test_rental_gdf = rental_gdf.head(5)

# Display the result
test_rental_gdf.head()
# Out:
#                                                                                           name  \
# https://www.domain.com.au/72a-argus-street-chel...       72A Argus Street, Cheltenham VIC 3192
# https://www.domain.com.au/8-42-wright-street-mc...       8/42 Wright Street, McKinnon VIC 3204
# https://www.domain.com.au/802-1-ascot-vale-road...  802/1 Ascot Vale Road, Flemington VIC 3031
# https://www.domain.com.au/2209-22-dorcas-street...   2209/22 Dorcas Street, Southbank VIC 3006
# https://www.domain.com.au/511-228-a-beckett-st-...    511/228 A'Beckett St, Melbourne VIC 3000
#
#                                                            cost_text  \
# https://www.domain.com.au/72a-argus-street-chel...   $1,050 Per Week
# https://www.domain.com.au/8-42-wright-street-mc...              $800
# https://www.domain.com.au/802-1-ascot-vale-road...  $500.00 per week
# https://www.domain.com.au/2209-22-dorcas-street...     $580 per week
# https://www.domain.com.au/511-228-a-beckett-st-...       $480 weekly
#
#                                                                 rooms  \
# https://www.domain.com.au/72a-argus-street-chel...  [4 Beds, 3 Baths]
# https://www.domain.com.au/8-42-wright-street-mc...  [3 Beds, 2 Baths]
# https://www.domain.com.au/802-1-ascot-vale-road...    [1 Bed, 1 Bath]
# https://www.domain.com.au/2209-22-dorcas-street...    [1 Bed, 1 Bath]
# https://www.domain.com.au/511-228-a-beckett-st-...    [1 Bed, 1 Bath]
#
#                                                         parking  \
# https://www.domain.com.au/72a-argus-street-chel...  [2 Parking]
# https://www.domain.com.au/8-42-wright-street-mc...  [1 Parking]
# https://www.domain.com.au/802-1-ascot-vale-road...  [1 Parking]
# https://www.domain.com.au/2209-22-dorcas-street...  [1 Parking]
# https://www.domain.com.au/511-228-a-beckett-st-...  [− Parking]
#
#                                                                                                  desc  \
# https://www.domain.com.au/72a-argus-street-chel...  Brand new and with a commanding street presenc...
# https://www.domain.com.au/8-42-wright-street-mc...  Nestling into the manicured gardens of Allnutt...
# https://www.domain.com.au/802-1-ascot-vale-road...  Positioned for absolute convenience, close to ...
# https://www.domain.com.au/2209-22-dorcas-street...                               * Unverified feature
# https://www.domain.com.au/511-228-a-beckett-st-...                               * Unverified feature
#
#                                                               property_type  \
# https://www.domain.com.au/72a-argus-street-chel...                Townhouse
# https://www.domain.com.au/8-42-wright-street-mc...                Townhouse
# https://www.domain.com.au/802-1-ascot-vale-road...  Apartment / Unit / Flat
# https://www.domain.com.au/2209-22-dorcas-street...  Apartment / Unit / Flat
# https://www.domain.com.au/511-228-a-beckett-st-...  Apartment / Unit / Flat
#
#                                                    date_available   bond  \
# https://www.domain.com.au/72a-argus-street-chel...  Available Now  $6300
# https://www.domain.com.au/8-42-wright-street-mc...  Available Now  $3476
# https://www.domain.com.au/802-1-ascot-vale-road...  Available Now  $2173
# https://www.domain.com.au/2209-22-dorcas-street...  Available Now  $2520
# https://www.domain.com.au/511-228-a-beckett-st-...  Available Now  $2086
#
#                                                                                     property_features  \
# https://www.domain.com.au/72a-argus-street-chel...  [Split System Air Con, Split System Heating, O...
# https://www.domain.com.au/8-42-wright-street-mc...  [Floorboards, Built in wardrobes, Dishwasher, ...
# https://www.domain.com.au/802-1-ascot-vale-road...  [Car Accom: Basement Carspace, Heating: Revers...
# https://www.domain.com.au/2209-22-dorcas-street...  [Internal Laundry*, Furnished*, Built in wardr...
# https://www.domain.com.au/511-228-a-beckett-st-...  [Heating*, Air conditioning, Alarm System, Int...
#
#                                                                    coordinates  \
# https://www.domain.com.au/72a-argus-street-chel...  [145.0649156, -37.9592116]
# https://www.domain.com.au/8-42-wright-street-mc...  [145.0308476, -37.9134094]
# https://www.domain.com.au/802-1-ascot-vale-road...  [144.9213168, -37.7867825]
# https://www.domain.com.au/2209-22-dorcas-street...  [144.9696742, -37.8301483]
# https://www.domain.com.au/511-228-a-beckett-st-...  [144.9566396, -37.8102641]
#
#                                                      longitude   latitude  \
# https://www.domain.com.au/72a-argus-street-chel...  145.064916 -37.959212
# https://www.domain.com.au/8-42-wright-street-mc...  145.030848 -37.913409
# https://www.domain.com.au/802-1-ascot-vale-road...  144.921317 -37.786783
# https://www.domain.com.au/2209-22-dorcas-street...  144.969674 -37.830148
# https://www.domain.com.au/511-228-a-beckett-st-...  144.956640 -37.810264
#
#                                                                        geometry
# https://www.domain.com.au/72a-argus-street-chel...  POINT (145.06492 -37.95921)
# https://www.domain.com.au/8-42-wright-street-mc...  POINT (145.03085 -37.91341)
# https://www.domain.com.au/802-1-ascot-vale-road...  POINT (144.92132 -37.78678)
# https://www.domain.com.au/2209-22-dorcas-street...  POINT (144.96967 -37.83015)
# https://www.domain.com.au/511-228-a-beckett-st-...  POINT (144.95664 -37.81026)

# %%
isochrone_gdf = gpd.read_file('../data/curated/isochrones/isochrones.geojson')

# Display the first few rows to verify
isochrone_gdf.head()
# Out:
#   station_id                                       station_name  interval  \
# 0      19970             Royal Park Railway Station (Parkville)       600
# 1      19971  Flemington Bridge Railway Station (North Melbo...       600
# 2      19972         Macaulay Railway Station (North Melbourne)       600
# 3      19973   North Melbourne Railway Station (West Melbourne)       600
# 4      19974        Clifton Hill Railway Station (Clifton Hill)       600
#
#     latitude   longitude                                           geometry
# 0 -37.781193  144.952301  POLYGON ((144.89721 -37.76938, 144.89832 -37.7...
# 1 -37.788140  144.939323  POLYGON ((144.8873 -37.77075, 144.8921 -37.774...
# 2 -37.794267  144.936166  POLYGON ((144.89347 -37.76897, 144.8941 -37.77...
# 3 -37.807419  144.942570  POLYGON ((144.90048 -37.79937, 144.89971 -37.8...
# 4 -37.788657  144.995417  POLYGON ((144.95551 -37.78951, 144.95568 -37.7...

# %%
# Perform Spatial join to find which isochrones each Rental Property falls in
joined_gdf = gpd.sjoin(test_rental_gdf, isochrone_gdf, how='inner', predicate='within')

# %%
joined_gdf
# Out:
#                                                                                         name  \
# https://www.domain.com.au/72a-argus-street-chel...     72A Argus Street, Cheltenham VIC 3192
# https://www.domain.com.au/72a-argus-street-chel...     72A Argus Street, Cheltenham VIC 3192
# https://www.domain.com.au/72a-argus-street-chel...     72A Argus Street, Cheltenham VIC 3192
# https://www.domain.com.au/72a-argus-street-chel...     72A Argus Street, Cheltenham VIC 3192
# https://www.domain.com.au/72a-argus-street-chel...     72A Argus Street, Cheltenham VIC 3192
# ...                                                                                      ...
# https://www.domain.com.au/511-228-a-beckett-st-...  511/228 A'Beckett St, Melbourne VIC 3000
# https://www.domain.com.au/511-228-a-beckett-st-...  511/228 A'Beckett St, Melbourne VIC 3000
# https://www.domain.com.au/511-228-a-beckett-st-...  511/228 A'Beckett St, Melbourne VIC 3000
# https://www.domain.com.au/511-228-a-beckett-st-...  511/228 A'Beckett St, Melbourne VIC 3000
# https://www.domain.com.au/511-228-a-beckett-st-...  511/228 A'Beckett St, Melbourne VIC 3000
#
#                                                           cost_text  \
# https://www.domain.com.au/72a-argus-street-chel...  $1,050 Per Week
# https://www.domain.com.au/72a-argus-street-chel...  $1,050 Per Week
# https://www.domain.com.au/72a-argus-street-chel...  $1,050 Per Week
# https://www.domain.com.au/72a-argus-street-chel...  $1,050 Per Week
# https://www.domain.com.au/72a-argus-street-chel...  $1,050 Per Week
# ...                                                             ...
# https://www.domain.com.au/511-228-a-beckett-st-...      $480 weekly
# https://www.domain.com.au/511-228-a-beckett-st-...      $480 weekly
# https://www.domain.com.au/511-228-a-beckett-st-...      $480 weekly
# https://www.domain.com.au/511-228-a-beckett-st-...      $480 weekly
# https://www.domain.com.au/511-228-a-beckett-st-...      $480 weekly
#
#                                                                 rooms  \
# https://www.domain.com.au/72a-argus-street-chel...  [4 Beds, 3 Baths]
# https://www.domain.com.au/72a-argus-street-chel...  [4 Beds, 3 Baths]
# https://www.domain.com.au/72a-argus-street-chel...  [4 Beds, 3 Baths]
# https://www.domain.com.au/72a-argus-street-chel...  [4 Beds, 3 Baths]
# https://www.domain.com.au/72a-argus-street-chel...  [4 Beds, 3 Baths]
# ...                                                               ...
# https://www.domain.com.au/511-228-a-beckett-st-...    [1 Bed, 1 Bath]
# https://www.domain.com.au/511-228-a-beckett-st-...    [1 Bed, 1 Bath]
# https://www.domain.com.au/511-228-a-beckett-st-...    [1 Bed, 1 Bath]
# https://www.domain.com.au/511-228-a-beckett-st-...    [1 Bed, 1 Bath]
# https://www.domain.com.au/511-228-a-beckett-st-...    [1 Bed, 1 Bath]
#
#                                                         parking  \
# https://www.domain.com.au/72a-argus-street-chel...  [2 Parking]
# https://www.domain.com.au/72a-argus-street-chel...  [2 Parking]
# https://www.domain.com.au/72a-argus-street-chel...  [2 Parking]
# https://www.domain.com.au/72a-argus-street-chel...  [2 Parking]
# https://www.domain.com.au/72a-argus-street-chel...  [2 Parking]
# ...                                                         ...
# https://www.domain.com.au/511-228-a-beckett-st-...  [− Parking]
# https://www.domain.com.au/511-228-a-beckett-st-...  [− Parking]
# https://www.domain.com.au/511-228-a-beckett-st-...  [− Parking]
# https://www.domain.com.au/511-228-a-beckett-st-...  [− Parking]
# https://www.domain.com.au/511-228-a-beckett-st-...  [− Parking]
#
#                                                                                                  desc  \
# https://www.domain.com.au/72a-argus-street-chel...  Brand new and with a commanding street presenc...
# https://www.domain.com.au/72a-argus-street-chel...  Brand new and with a commanding street presenc...
# https://www.domain.com.au/72a-argus-street-chel...  Brand new and with a commanding street presenc...
# https://www.domain.com.au/72a-argus-street-chel...  Brand new and with a commanding street presenc...
# https://www.domain.com.au/72a-argus-street-chel...  Brand new and with a commanding street presenc...
# ...                                                                                               ...
# https://www.domain.com.au/511-228-a-beckett-st-...                               * Unverified feature
# https://www.domain.com.au/511-228-a-beckett-st-...                               * Unverified feature
# https://www.domain.com.au/511-228-a-beckett-st-...                               * Unverified feature
# https://www.domain.com.au/511-228-a-beckett-st-...                               * Unverified feature
# https://www.domain.com.au/511-228-a-beckett-st-...                               * Unverified feature
#
#                                                               property_type  \
# https://www.domain.com.au/72a-argus-street-chel...                Townhouse
# https://www.domain.com.au/72a-argus-street-chel...                Townhouse
# https://www.domain.com.au/72a-argus-street-chel...                Townhouse
# https://www.domain.com.au/72a-argus-street-chel...                Townhouse
# https://www.domain.com.au/72a-argus-street-chel...                Townhouse
# ...                                                                     ...
# https://www.domain.com.au/511-228-a-beckett-st-...  Apartment / Unit / Flat
# https://www.domain.com.au/511-228-a-beckett-st-...  Apartment / Unit / Flat
# https://www.domain.com.au/511-228-a-beckett-st-...  Apartment / Unit / Flat
# https://www.domain.com.au/511-228-a-beckett-st-...  Apartment / Unit / Flat
# https://www.domain.com.au/511-228-a-beckett-st-...  Apartment / Unit / Flat
#
#                                                    date_available   bond  \
# https://www.domain.com.au/72a-argus-street-chel...  Available Now  $6300
# https://www.domain.com.au/72a-argus-street-chel...  Available Now  $6300
# https://www.domain.com.au/72a-argus-street-chel...  Available Now  $6300
# https://www.domain.com.au/72a-argus-street-chel...  Available Now  $6300
# https://www.domain.com.au/72a-argus-street-chel...  Available Now  $6300
# ...                                                           ...    ...
# https://www.domain.com.au/511-228-a-beckett-st-...  Available Now  $2086
# https://www.domain.com.au/511-228-a-beckett-st-...  Available Now  $2086
# https://www.domain.com.au/511-228-a-beckett-st-...  Available Now  $2086
# https://www.domain.com.au/511-228-a-beckett-st-...  Available Now  $2086
# https://www.domain.com.au/511-228-a-beckett-st-...  Available Now  $2086
#
#                                                                                     property_features  \
# https://www.domain.com.au/72a-argus-street-chel...  [Split System Air Con, Split System Heating, O...
# https://www.domain.com.au/72a-argus-street-chel...  [Split System Air Con, Split System Heating, O...
# https://www.domain.com.au/72a-argus-street-chel...  [Split System Air Con, Split System Heating, O...
# https://www.domain.com.au/72a-argus-street-chel...  [Split System Air Con, Split System Heating, O...
# https://www.domain.com.au/72a-argus-street-chel...  [Split System Air Con, Split System Heating, O...
# ...                                                                                               ...
# https://www.domain.com.au/511-228-a-beckett-st-...  [Heating*, Air conditioning, Alarm System, Int...
# https://www.domain.com.au/511-228-a-beckett-st-...  [Heating*, Air conditioning, Alarm System, Int...
# https://www.domain.com.au/511-228-a-beckett-st-...  [Heating*, Air conditioning, Alarm System, Int...
# https://www.domain.com.au/511-228-a-beckett-st-...  [Heating*, Air conditioning, Alarm System, Int...
# https://www.domain.com.au/511-228-a-beckett-st-...  [Heating*, Air conditioning, Alarm System, Int...
#
#                                                                    coordinates  \
# https://www.domain.com.au/72a-argus-street-chel...  [145.0649156, -37.9592116]
# https://www.domain.com.au/72a-argus-street-chel...  [145.0649156, -37.9592116]
# https://www.domain.com.au/72a-argus-street-chel...  [145.0649156, -37.9592116]
# https://www.domain.com.au/72a-argus-street-chel...  [145.0649156, -37.9592116]
# https://www.domain.com.au/72a-argus-street-chel...  [145.0649156, -37.9592116]
# ...                                                                        ...
# https://www.domain.com.au/511-228-a-beckett-st-...  [144.9566396, -37.8102641]
# https://www.domain.com.au/511-228-a-beckett-st-...  [144.9566396, -37.8102641]
# https://www.domain.com.au/511-228-a-beckett-st-...  [144.9566396, -37.8102641]
# https://www.domain.com.au/511-228-a-beckett-st-...  [144.9566396, -37.8102641]
# https://www.domain.com.au/511-228-a-beckett-st-...  [144.9566396, -37.8102641]
#
#                                                     longitude_left  \
# https://www.domain.com.au/72a-argus-street-chel...      145.064916
# https://www.domain.com.au/72a-argus-street-chel...      145.064916
# https://www.domain.com.au/72a-argus-street-chel...      145.064916
# https://www.domain.com.au/72a-argus-street-chel...      145.064916
# https://www.domain.com.au/72a-argus-street-chel...      145.064916
# ...                                                            ...
# https://www.domain.com.au/511-228-a-beckett-st-...      144.956640
# https://www.domain.com.au/511-228-a-beckett-st-...      144.956640
# https://www.domain.com.au/511-228-a-beckett-st-...      144.956640
# https://www.domain.com.au/511-228-a-beckett-st-...      144.956640
# https://www.domain.com.au/511-228-a-beckett-st-...      144.956640
#
#                                                     latitude_left  \
# https://www.domain.com.au/72a-argus-street-chel...     -37.959212
# https://www.domain.com.au/72a-argus-street-chel...     -37.959212
# https://www.domain.com.au/72a-argus-street-chel...     -37.959212
# https://www.domain.com.au/72a-argus-street-chel...     -37.959212
# https://www.domain.com.au/72a-argus-street-chel...     -37.959212
# ...                                                           ...
# https://www.domain.com.au/511-228-a-beckett-st-...     -37.810264
# https://www.domain.com.au/511-228-a-beckett-st-...     -37.810264
# https://www.domain.com.au/511-228-a-beckett-st-...     -37.810264
# https://www.domain.com.au/511-228-a-beckett-st-...     -37.810264
# https://www.domain.com.au/511-228-a-beckett-st-...     -37.810264
#
#                                                                        geometry  \
# https://www.domain.com.au/72a-argus-street-chel...  POINT (145.06492 -37.95921)
# https://www.domain.com.au/72a-argus-street-chel...  POINT (145.06492 -37.95921)
# https://www.domain.com.au/72a-argus-street-chel...  POINT (145.06492 -37.95921)
# https://www.domain.com.au/72a-argus-street-chel...  POINT (145.06492 -37.95921)
# https://www.domain.com.au/72a-argus-street-chel...  POINT (145.06492 -37.95921)
# ...                                                                         ...
# https://www.domain.com.au/511-228-a-beckett-st-...  POINT (144.95664 -37.81026)
# https://www.domain.com.au/511-228-a-beckett-st-...  POINT (144.95664 -37.81026)
# https://www.domain.com.au/511-228-a-beckett-st-...  POINT (144.95664 -37.81026)
# https://www.domain.com.au/511-228-a-beckett-st-...  POINT (144.95664 -37.81026)
# https://www.domain.com.au/511-228-a-beckett-st-...  POINT (144.95664 -37.81026)
#
#                                                     index_right station_id  \
# https://www.domain.com.au/72a-argus-street-chel...           71      52095
# https://www.domain.com.au/72a-argus-street-chel...          114      19864
# https://www.domain.com.au/72a-argus-street-chel...          115      19865
# https://www.domain.com.au/72a-argus-street-chel...          116      19866
# https://www.domain.com.au/72a-argus-street-chel...          122      19872
# ...                                                         ...        ...
# https://www.domain.com.au/511-228-a-beckett-st-...           92      19842
# https://www.domain.com.au/511-228-a-beckett-st-...           93      19843
# https://www.domain.com.au/511-228-a-beckett-st-...          104      19854
# https://www.domain.com.au/511-228-a-beckett-st-...          158      19908
# https://www.domain.com.au/511-228-a-beckett-st-...          219      19969
#
#                                                                                          station_name  \
# https://www.domain.com.au/72a-argus-street-chel...             Southland Railway Station (Cheltenham)
# https://www.domain.com.au/72a-argus-street-chel...                Parkdale Railway Station (Parkdale)
# https://www.domain.com.au/72a-argus-street-chel...                  Mentone Railway Station (Mentone)
# https://www.domain.com.au/72a-argus-street-chel...            Cheltenham Railway Station (Cheltenham)
# https://www.domain.com.au/72a-argus-street-chel...                  Highett Railway Station (Highett)
# ...                                                                                               ...
# https://www.domain.com.au/511-228-a-beckett-st-...  Melbourne Central Railway Station (Melbourne C...
# https://www.domain.com.au/511-228-a-beckett-st-...        Parliament Railway Station (Melbourne City)
# https://www.domain.com.au/511-228-a-beckett-st-...   Flinders Street Railway Station (Melbourne City)
# https://www.domain.com.au/511-228-a-beckett-st-...                Richmond Railway Station (Richmond)
# https://www.domain.com.au/511-228-a-beckett-st-...                 Jewell Railway Station (Brunswick)
#
#                                                     interval  latitude_right  \
# https://www.domain.com.au/72a-argus-street-chel...       600      -37.958756
# https://www.domain.com.au/72a-argus-street-chel...       600      -37.993079
# https://www.domain.com.au/72a-argus-street-chel...       600      -37.981865
# https://www.domain.com.au/72a-argus-street-chel...       600      -37.966650
# https://www.domain.com.au/72a-argus-street-chel...       600      -37.948425
# ...                                                      ...             ...
# https://www.domain.com.au/511-228-a-beckett-st-...       600      -37.809939
# https://www.domain.com.au/511-228-a-beckett-st-...       600      -37.811054
# https://www.domain.com.au/511-228-a-beckett-st-...       600      -37.818305
# https://www.domain.com.au/511-228-a-beckett-st-...       600      -37.824074
# https://www.domain.com.au/511-228-a-beckett-st-...       600      -37.774987
#
#                                                     longitude_right
# https://www.domain.com.au/72a-argus-street-chel...       145.049121
# https://www.domain.com.au/72a-argus-street-chel...       145.076327
# https://www.domain.com.au/72a-argus-street-chel...       145.065166
# https://www.domain.com.au/72a-argus-street-chel...       145.054558
# https://www.domain.com.au/72a-argus-street-chel...       145.041872
# ...                                                             ...
# https://www.domain.com.au/511-228-a-beckett-st-...       144.962594
# https://www.domain.com.au/511-228-a-beckett-st-...       144.972911
# https://www.domain.com.au/511-228-a-beckett-st-...       144.966964
# https://www.domain.com.au/511-228-a-beckett-st-...       144.990164
# https://www.domain.com.au/511-228-a-beckett-st-...       144.958717
#
# [71 rows x 19 columns]

# %%
# Function to get distance using ORS API
def get_distance(lat1, lon1, lat2, lon2):
    # Coordinates for rental property and train station
    coordinates = [[lon1, lat1], [lon2, lat2]]
    
    try:
        # Request route
        route = client.directions(coordinates=coordinates, profile='driving-car', format='geojson')
        # Get distance in meters
        distance = route['features'][0]['properties']['segments'][0]['distance']
        return distance / 1000  # Convert to kilometers
    except Exception as e:
        print(f"Error occurred: {e}")
        return None  # Handle the case where API call fails

# Apply the function to DataFrame with a delay
def apply_distance_with_delay(row):
    distance = get_distance(row['latitude_left'], row['longitude_left'], row['latitude_right'], row['longitude_right'])
    time.sleep(2)  # Adding a delay of 1 second between requests
    return distance

# Apply with delay
joined_gdf['distance_km'] = joined_gdf.apply(apply_distance_with_delay, axis=1)

# %%
joined_gdf.head()
# Out:
#                                                                                      name  \
# https://www.domain.com.au/72a-argus-street-chel...  72A Argus Street, Cheltenham VIC 3192
# https://www.domain.com.au/72a-argus-street-chel...  72A Argus Street, Cheltenham VIC 3192
# https://www.domain.com.au/72a-argus-street-chel...  72A Argus Street, Cheltenham VIC 3192
# https://www.domain.com.au/72a-argus-street-chel...  72A Argus Street, Cheltenham VIC 3192
# https://www.domain.com.au/72a-argus-street-chel...  72A Argus Street, Cheltenham VIC 3192
#
#                                                           cost_text  \
# https://www.domain.com.au/72a-argus-street-chel...  $1,050 Per Week
# https://www.domain.com.au/72a-argus-street-chel...  $1,050 Per Week
# https://www.domain.com.au/72a-argus-street-chel...  $1,050 Per Week
# https://www.domain.com.au/72a-argus-street-chel...  $1,050 Per Week
# https://www.domain.com.au/72a-argus-street-chel...  $1,050 Per Week
#
#                                                                 rooms  \
# https://www.domain.com.au/72a-argus-street-chel...  [4 Beds, 3 Baths]
# https://www.domain.com.au/72a-argus-street-chel...  [4 Beds, 3 Baths]
# https://www.domain.com.au/72a-argus-street-chel...  [4 Beds, 3 Baths]
# https://www.domain.com.au/72a-argus-street-chel...  [4 Beds, 3 Baths]
# https://www.domain.com.au/72a-argus-street-chel...  [4 Beds, 3 Baths]
#
#                                                         parking  \
# https://www.domain.com.au/72a-argus-street-chel...  [2 Parking]
# https://www.domain.com.au/72a-argus-street-chel...  [2 Parking]
# https://www.domain.com.au/72a-argus-street-chel...  [2 Parking]
# https://www.domain.com.au/72a-argus-street-chel...  [2 Parking]
# https://www.domain.com.au/72a-argus-street-chel...  [2 Parking]
#
#                                                                                                  desc  \
# https://www.domain.com.au/72a-argus-street-chel...  Brand new and with a commanding street presenc...
# https://www.domain.com.au/72a-argus-street-chel...  Brand new and with a commanding street presenc...
# https://www.domain.com.au/72a-argus-street-chel...  Brand new and with a commanding street presenc...
# https://www.domain.com.au/72a-argus-street-chel...  Brand new and with a commanding street presenc...
# https://www.domain.com.au/72a-argus-street-chel...  Brand new and with a commanding street presenc...
#
#                                                    property_type  \
# https://www.domain.com.au/72a-argus-street-chel...     Townhouse
# https://www.domain.com.au/72a-argus-street-chel...     Townhouse
# https://www.domain.com.au/72a-argus-street-chel...     Townhouse
# https://www.domain.com.au/72a-argus-street-chel...     Townhouse
# https://www.domain.com.au/72a-argus-street-chel...     Townhouse
#
#                                                    date_available   bond  \
# https://www.domain.com.au/72a-argus-street-chel...  Available Now  $6300
# https://www.domain.com.au/72a-argus-street-chel...  Available Now  $6300
# https://www.domain.com.au/72a-argus-street-chel...  Available Now  $6300
# https://www.domain.com.au/72a-argus-street-chel...  Available Now  $6300
# https://www.domain.com.au/72a-argus-street-chel...  Available Now  $6300
#
#                                                                                     property_features  \
# https://www.domain.com.au/72a-argus-street-chel...  [Split System Air Con, Split System Heating, O...
# https://www.domain.com.au/72a-argus-street-chel...  [Split System Air Con, Split System Heating, O...
# https://www.domain.com.au/72a-argus-street-chel...  [Split System Air Con, Split System Heating, O...
# https://www.domain.com.au/72a-argus-street-chel...  [Split System Air Con, Split System Heating, O...
# https://www.domain.com.au/72a-argus-street-chel...  [Split System Air Con, Split System Heating, O...
#
#                                                                    coordinates  \
# https://www.domain.com.au/72a-argus-street-chel...  [145.0649156, -37.9592116]
# https://www.domain.com.au/72a-argus-street-chel...  [145.0649156, -37.9592116]
# https://www.domain.com.au/72a-argus-street-chel...  [145.0649156, -37.9592116]
# https://www.domain.com.au/72a-argus-street-chel...  [145.0649156, -37.9592116]
# https://www.domain.com.au/72a-argus-street-chel...  [145.0649156, -37.9592116]
#
#                                                     longitude_left  \
# https://www.domain.com.au/72a-argus-street-chel...      145.064916
# https://www.domain.com.au/72a-argus-street-chel...      145.064916
# https://www.domain.com.au/72a-argus-street-chel...      145.064916
# https://www.domain.com.au/72a-argus-street-chel...      145.064916
# https://www.domain.com.au/72a-argus-street-chel...      145.064916
#
#                                                     latitude_left  \
# https://www.domain.com.au/72a-argus-street-chel...     -37.959212
# https://www.domain.com.au/72a-argus-street-chel...     -37.959212
# https://www.domain.com.au/72a-argus-street-chel...     -37.959212
# https://www.domain.com.au/72a-argus-street-chel...     -37.959212
# https://www.domain.com.au/72a-argus-street-chel...     -37.959212
#
#                                                                        geometry  \
# https://www.domain.com.au/72a-argus-street-chel...  POINT (145.06492 -37.95921)
# https://www.domain.com.au/72a-argus-street-chel...  POINT (145.06492 -37.95921)
# https://www.domain.com.au/72a-argus-street-chel...  POINT (145.06492 -37.95921)
# https://www.domain.com.au/72a-argus-street-chel...  POINT (145.06492 -37.95921)
# https://www.domain.com.au/72a-argus-street-chel...  POINT (145.06492 -37.95921)
#
#                                                     index_right station_id  \
# https://www.domain.com.au/72a-argus-street-chel...           71      52095
# https://www.domain.com.au/72a-argus-street-chel...          114      19864
# https://www.domain.com.au/72a-argus-street-chel...          115      19865
# https://www.domain.com.au/72a-argus-street-chel...          116      19866
# https://www.domain.com.au/72a-argus-street-chel...          122      19872
#
#                                                                                station_name  \
# https://www.domain.com.au/72a-argus-street-chel...   Southland Railway Station (Cheltenham)
# https://www.domain.com.au/72a-argus-street-chel...      Parkdale Railway Station (Parkdale)
# https://www.domain.com.au/72a-argus-street-chel...        Mentone Railway Station (Mentone)
# https://www.domain.com.au/72a-argus-street-chel...  Cheltenham Railway Station (Cheltenham)
# https://www.domain.com.au/72a-argus-street-chel...        Highett Railway Station (Highett)
#
#                                                     interval  latitude_right  \
# https://www.domain.com.au/72a-argus-street-chel...       600      -37.958756
# https://www.domain.com.au/72a-argus-street-chel...       600      -37.993079
# https://www.domain.com.au/72a-argus-street-chel...       600      -37.981865
# https://www.domain.com.au/72a-argus-street-chel...       600      -37.966650
# https://www.domain.com.au/72a-argus-street-chel...       600      -37.948425
#
#                                                     longitude_right  \
# https://www.domain.com.au/72a-argus-street-chel...       145.049121
# https://www.domain.com.au/72a-argus-street-chel...       145.076327
# https://www.domain.com.au/72a-argus-street-chel...       145.065166
# https://www.domain.com.au/72a-argus-street-chel...       145.054558
# https://www.domain.com.au/72a-argus-street-chel...       145.041872
#
#                                                     distance_km
# https://www.domain.com.au/72a-argus-street-chel...       2.0973
# https://www.domain.com.au/72a-argus-street-chel...       4.9081
# https://www.domain.com.au/72a-argus-street-chel...       3.6822
# https://www.domain.com.au/72a-argus-street-chel...       1.7517
# https://www.domain.com.au/72a-argus-street-chel...       2.7049

# %%
# Group by 'name' (property name), and find the row with the minimum 'distance_km' for each group
joined_gdf_min_distance = joined_gdf.sort_values('distance_km').drop_duplicates(subset=['name'], keep='first')

# Reset index to clean up the DataFrame
joined_gdf_min_distance = joined_gdf_min_distance.reset_index(drop=True)

# Remove unecessary columns
joined_gdf_min_distance = joined_gdf_min_distance.drop(columns=['interval', 'index_right', 'latitude_right', 'longitude_right'])

# Display the updated DataFrame
joined_gdf_min_distance
# Out:
#                                          name         cost_text  \
# 0    511/228 A'Beckett St, Melbourne VIC 3000       $480 weekly
# 1  802/1 Ascot Vale Road, Flemington VIC 3031  $500.00 per week
# 2       8/42 Wright Street, McKinnon VIC 3204              $800
# 3   2209/22 Dorcas Street, Southbank VIC 3006     $580 per week
# 4       72A Argus Street, Cheltenham VIC 3192   $1,050 Per Week
#
#                rooms      parking  \
# 0    [1 Bed, 1 Bath]  [− Parking]
# 1    [1 Bed, 1 Bath]  [1 Parking]
# 2  [3 Beds, 2 Baths]  [1 Parking]
# 3    [1 Bed, 1 Bath]  [1 Parking]
# 4  [4 Beds, 3 Baths]  [2 Parking]
#
#                                                 desc            property_type  \
# 0                               * Unverified feature  Apartment / Unit / Flat
# 1  Positioned for absolute convenience, close to ...  Apartment / Unit / Flat
# 2  Nestling into the manicured gardens of Allnutt...                Townhouse
# 3                               * Unverified feature  Apartment / Unit / Flat
# 4  Brand new and with a commanding street presenc...                Townhouse
#
#   date_available   bond                                  property_features  \
# 0  Available Now  $2086  [Heating*, Air conditioning, Alarm System, Int...
# 1  Available Now  $2173  [Car Accom: Basement Carspace, Heating: Revers...
# 2  Available Now  $3476  [Floorboards, Built in wardrobes, Dishwasher, ...
# 3  Available Now  $2520  [Internal Laundry*, Furnished*, Built in wardr...
# 4  Available Now  $6300  [Split System Air Con, Split System Heating, O...
#
#                   coordinates  longitude_left  latitude_left  \
# 0  [144.9566396, -37.8102641]      144.956640     -37.810264
# 1  [144.9213168, -37.7867825]      144.921317     -37.786783
# 2  [145.0308476, -37.9134094]      145.030848     -37.913409
# 3  [144.9696742, -37.8301483]      144.969674     -37.830148
# 4  [145.0649156, -37.9592116]      145.064916     -37.959212
#
#                       geometry station_id  \
# 0  POINT (144.95664 -37.81026)      19841
# 1  POINT (144.92132 -37.78678)      20040
# 2  POINT (145.03085 -37.91341)      19940
# 3  POINT (144.96967 -37.83015)      19854
# 4  POINT (145.06492 -37.95921)      19866
#
#                                        station_name  distance_km
# 0        Flagstaff Railway Station (Melbourne City)       0.2794
# 1            Newmarket Railway Station (Flemington)       0.8620
# 2               McKinnon Railway Station (Mckinnon)       1.2109
# 3  Flinders Street Railway Station (Melbourne City)       1.4762
# 4           Cheltenham Railway Station (Cheltenham)       1.7517
