# %% [markdown]
# # Computing Proximity to the Closest Train Station for all Rental Properties

# %%
import requests
import numpy as np
import zipfile
import io
import geopandas as gpd
from openrouteservice import Client
import json
import pandas as pd
from shapely.geometry import Point
import ast
import time
import os
import sys
sys.path.append('../')
from scripts.utils import download_file, extract_zip

# %% [markdown]
# ## Loading Train Station Data

# %%
url = 'https://s3.ap-southeast-2.amazonaws.com/cl-isd-prd-datashare-s3-delivery/Order_FYXPQM.zip'
output_dir = '../data/landing/train_stations'

if not os.path.exists(output_dir):
    os.makedirs(output_dir)
    print(f"Created directory: {output_dir}")

# Defining the file directories
zip_path = f'{output_dir}/train_stations.zip'
extract_to = '../data/landing/train_stations/extracted'
    
# Download the ZIP file
download_file(url, zip_path)
    
# Extract the ZIP file
extract_zip(zip_path, extract_to)

# List files in the extracted directory
extracted_files = os.listdir(extract_to)
print("Files in extracted directory:", extracted_files)
# Out:
# Files in extracted directory: ['Creative Commons Licence.html', 'll_gda94', 'PTV_METRO_TRAIN_STATION_b6722101-8db5-51f0-8a6f-d1e4fe805b73.html']

# %%
# Path to the shapefile
shapefile_path = '../data/landing/train_stations/extracted/ll_gda94/esrishape/whole_of_dataset/victoria/PTV/PTV_METRO_TRAIN_STATION.shp'

# Read the shapefile into a GeoDataFrame
train_gdf = gpd.read_file(shapefile_path)

# Display the first few rows of the GeoDataFrame
print(train_gdf.head())

# Display the columns of the GeoDataFrame
train_gdf.columns
# Out:
#   STOP_ID   LATITUDE                                          STOP_NAME  \
# 0   19970 -37.781193             Royal Park Railway Station (Parkville)
# 1   19971 -37.788140  Flemington Bridge Railway Station (North Melbo...
# 2   19972 -37.794267         Macaulay Railway Station (North Melbourne)
# 3   19973 -37.807419   North Melbourne Railway Station (West Melbourne)
# 4   19974 -37.788657        Clifton Hill Railway Station (Clifton Hill)
#
#     LONGITUDE TICKETZONE                                          ROUTEUSSP  \
# 0  144.952301          1                                            Upfield
# 1  144.939323          1                                            Upfield
# 2  144.936166          1                                            Upfield
# 3  144.942570          1  Flemington,Sunbury,Upfield,Werribee,Williamsto...
# 4  144.995417          1                                 Mernda,Hurstbridge
#
#                       geometry
# 0   POINT (144.9523 -37.78119)
# 1  POINT (144.93932 -37.78814)
# 2  POINT (144.93617 -37.79427)
# 3  POINT (144.94257 -37.80742)
# 4  POINT (144.99542 -37.78866)
# Index(['STOP_ID', 'LATITUDE', 'STOP_NAME', 'LONGITUDE', 'TICKETZONE',
#        'ROUTEUSSP', 'geometry'],
#       dtype='object')

# %%
# Convert column names to lowercase
train_gdf.columns = [col.lower() for col in train_gdf.columns]

# Display the updated GeoDataFrame
train_gdf.head()
# Out:
#   stop_id   latitude                                          stop_name  \
# 0   19970 -37.781193             Royal Park Railway Station (Parkville)
# 1   19971 -37.788140  Flemington Bridge Railway Station (North Melbo...
# 2   19972 -37.794267         Macaulay Railway Station (North Melbourne)
# 3   19973 -37.807419   North Melbourne Railway Station (West Melbourne)
# 4   19974 -37.788657        Clifton Hill Railway Station (Clifton Hill)
#
#     longitude ticketzone                                          routeussp  \
# 0  144.952301          1                                            Upfield
# 1  144.939323          1                                            Upfield
# 2  144.936166          1                                            Upfield
# 3  144.942570          1  Flemington,Sunbury,Upfield,Werribee,Williamsto...
# 4  144.995417          1                                 Mernda,Hurstbridge
#
#                       geometry
# 0   POINT (144.9523 -37.78119)
# 1  POINT (144.93932 -37.78814)
# 2  POINT (144.93617 -37.79427)
# 3  POINT (144.94257 -37.80742)
# 4  POINT (144.99542 -37.78866)

# %%
# Checking longitude and latitude are within the reasonable limits for Victoria

# Latitude: Approx [-39, -34]
# Longitude: Approx [140, 150]

train_gdf.describe()
# Out:
#          latitude   longitude
# count  220.000000  220.000000
# mean   -37.852378  145.045691
# std      0.140332    0.139902
# min    -38.374235  144.661118
# 25%    -37.899626  144.961156
# 50%    -37.826147  145.036588
# 75%    -37.769623  145.121451
# max    -37.579091  145.486379

# %% [markdown]
# ## Loading Preprocessed Domain Rental Data

# %%
domain_df = pd.read_parquet('../data/raw/all_domain_properties.parquet')

# Display the DataFrame
domain_df.head()
# Out:
#                                         name              rooms      parking  \
# 0          6 Gentle Street, Clayton VIC 3168  [3 Beds, 2 Baths]  [2 Parking]
# 1          142 Civic Parade, Altona VIC 3018   [3 Beds, 1 Bath]  [1 Parking]
# 2  4/104 Bernard Street, Cheltenham VIC 3192  [3 Beds, 2 Baths]  [2 Parking]
# 3   2 Collendina Crescent, Scoresby VIC 3179  [3 Beds, 2 Baths]  [2 Parking]
# 4   103/6A Evergreen Mews, Armadale VIC 3143  [2 Beds, 2 Baths]  [1 Parking]
#
#              property_type date_available   bond                 coordinates  \
# 0                    House          09/24  $2520  [-37.9221445, 145.1130263]
# 1                    House          09/24  $2390      [-37.86445, 144.82913]
# 2                Townhouse          09/24  $3302  [-37.9543583, 145.0693877]
# 3                    House          09/24  $2694   [-37.8901142, 145.223353]
# 4  Apartment / Unit / Flat          09/24   None  [-37.8518143, 145.0133926]
#
#    weekly_cost                address      suburb postcode
# 0        580.0        6 gentle street     clayton     3168
# 1        550.0       142 civic parade      altona     3018
# 2        760.0   4/104 bernard street  cheltenham     3192
# 3        640.0  2 collendina crescent    scoresby     3179
# 4        790.0  103/6a evergreen mews    armadale     3143

# %%
# Check the data type of a few entries
print(domain_df['coordinates'].apply(type).value_counts())
# Out:
# coordinates
# <class 'numpy.ndarray'>    13017
# <class 'NoneType'>            44
# Name: count, dtype: int64

# %%
# Display rows with missing latitude or longitude values
missing_entries = domain_df[domain_df[['coordinates']].isna().any(axis=1)]

print(f"Number of properties with missing coordinates: {len(missing_entries)}")
missing_entries
# Out:
# Number of properties with missing coordinates: 44
#                                                     name              rooms  \
# 659                3/123 Williams Road, Prahran VIC 3181    [1 Bed, 1 Bath]
# 1029              17 Grevillia Drive, Mill Park VIC 3082  [4 Beds, 2 Baths]
# 1120              2/50 Lane Crescent, Reservoir VIC 3073   [2 Beds, 1 Bath]
# 1952                48 Leeds St, Doncaster East VIC 3109  [3 Beds, 2 Baths]
# 2037                    21 Nyah St, Keilor East VIC 3033  [4 Beds, 2 Baths]
# 2404      2601/65 Dudley Street, West Melbourne VIC 3003    [1 Bed, 1 Bath]
# 3152              202/18 Malone Street, Geelong VIC 3220  [2 Beds, 2 Baths]
# 3153        5/43-45 Deschamp Crescent, Rowville VIC 3178  [2 Beds, 2 Baths]
# 3795             2/70 Williams Road, Wangaratta VIC 3677   [2 Beds, 1 Bath]
# 4029              11 Paperbark Court, Broadford VIC 3658  [4 Beds, 2 Baths]
# 4404        1408/2 Newquay Promenade, Docklands VIC 3008    [1 Bed, 1 Bath]
# 4710           4/72 Grosvenor Street, Balaclava VIC 3183   [2 Beds, 1 Bath]
# 4933        28B Lightwood Drive, Ferntree Gully VIC 3156  [4 Beds, 3 Baths]
# 5085                 2 Mylson Avenue, Broadford VIC 3658   [3 Beds, 1 Bath]
# 5309         182 Stewart Street, Brunswick East VIC 3057   [3 Beds, 1 Bath]
# 6710      U303/65 Dudley Street, West Melbourne VIC 3003  [2 Beds, 2 Baths]
# 6924       10 Davenport Street, Armstrong Creek VIC 3217  [4 Beds, 2 Baths]
# 7049              2A Butterworth Place, Wodonga VIC 3690   [2 Beds, 1 Bath]
# 7181                  39 Noble Street, Anglesea VIC 3230   [3 Beds, 1 Bath]
# 7570           403/88 Carlisle Street, St Kilda VIC 3182    [1 Bed, 1 Bath]
# 7873                190 Smith Street, Thornbury VIC 3071   [4 Beds, 1 Bath]
# 8042                   4 Lancelot Avenue, Clyde VIC 3978  [5 Beds, 3 Baths]
# 8240                11-13 Cooma Street, Preston VIC 3072    [1 Bed, 1 Bath]
# 8358              9/319 Dandenong Road, Prahran VIC 3181    [1 Bed, 1 Bath]
# 8438              6/58 Glen Orme Avenue, Ormond VIC 3204   [2 Beds, 1 Bath]
# 8463        9/302 Golf Links Road, Narre Warren VIC 3805   [3 Beds, 1 Bath]
# 8857           413/70 Batesford Road, Chadstone VIC 3148   [2 Beds, 1 Bath]
# 8906              313/15 Bond Street, Caulfield VIC 3162   [2 Beds, 1 Bath]
# 9218                  104 Hamish Drive, Tarneit VIC 3029  [4 Beds, 2 Baths]
# 9447              15 Allandale Road, Kings Park VIC 3021   [3 Beds, 1 Bath]
# 10169              9/27 Coorigil Road, Carnegie VIC 3163   [2 Beds, 1 Bath]
# 10298      2/40 Irvine Crescent, Brunswick West VIC 3055   [2 Beds, 1 Bath]
# 10385               20A Central Ave, Black Rock VIC 3193  [3 Beds, 2 Baths]
# 10496            705/8 Marmion Place, Docklands VIC 3008   [2 Beds, 1 Bath]
# 10529       6A Curraweena Road, Caulfield South VIC 3162   [3 Beds, 1 Bath]
# 10702  13/159-169 Curzon Street, North Melbourne VIC ...   [2 Beds, 1 Bath]
# 10961             38 Gossia Avenue, Craigieburn VIC 3064  [4 Beds, 2 Baths]
# 11157    U2109/65 Dudley Street, West Melbourne VIC 3003  [2 Beds, 2 Baths]
# 11297             39 Spearys Road, Diggers Rest VIC 3427  [4 Beds, 2 Baths]
# 12143        304/40 Burgundy Street, Heidelberg VIC 3084   [2 Beds, 1 Bath]
# 12357                   158 Farm Road, Werribee VIC 3030   [2 Beds, 1 Bath]
# 12387        2602/350 William Street, Melbourne VIC 3000    [1 Bed, 1 Bath]
# 12642                32 Blenril Avenue, Tarneit VIC 3029  [3 Beds, 2 Baths]
# 13060          9 St Helens Avenue, Lake Gardens VIC 3355  [4 Beds, 2 Baths]
#
#            parking            property_type date_available  bond coordinates  \
# 659    [− Parking]  Apartment / Unit / Flat          09/24  None        None
# 1029   [1 Parking]                    House          09/24  None        None
# 1120   [1 Parking]                Townhouse          09/24  None        None
# 1952   [2 Parking]                    House          09/24  None        None
# 2037   [− Parking]                    House          09/24  None        None
# 2404   [− Parking]  Apartment / Unit / Flat          09/24  None        None
# 3152   [1 Parking]  Apartment / Unit / Flat          09/24  None        None
# 3153   [1 Parking]                Townhouse          09/24  None        None
# 3795   [1 Parking]  Apartment / Unit / Flat          09/24  None        None
# 4029   [2 Parking]                    House          09/24  None        None
# 4404   [− Parking]  Apartment / Unit / Flat          09/24  None        None
# 4710   [2 Parking]  Apartment / Unit / Flat          09/24  None        None
# 4933   [2 Parking]                Townhouse          09/24  None        None
# 5085   [2 Parking]                    House          09/24  None        None
# 5309   [2 Parking]                    House          09/24  None        None
# 6710   [− Parking]  Apartment / Unit / Flat          09/24  None        None
# 6924   [2 Parking]                    House          09/24  None        None
# 7049   [1 Parking]                Townhouse          09/24  None        None
# 7181   [1 Parking]                    House          09/24  None        None
# 7570   [1 Parking]  Apartment / Unit / Flat          09/24  None        None
# 7873   [− Parking]                    House          09/24  None        None
# 8042   [2 Parking]                    House          09/24  None        None
# 8240   [− Parking]  Apartment / Unit / Flat          09/24  None        None
# 8358   [1 Parking]  Apartment / Unit / Flat          09/24  None        None
# 8438   [1 Parking]  Apartment / Unit / Flat          09/24  None        None
# 8463   [1 Parking]                Townhouse          09/24  None        None
# 8857   [1 Parking]  Apartment / Unit / Flat          09/24  None        None
# 8906   [1 Parking]  Apartment / Unit / Flat          09/24  None        None
# 9218   [2 Parking]                    House          09/24  None        None
# 9447   [2 Parking]                    House          09/24  None        None
# 10169  [1 Parking]  Apartment / Unit / Flat          09/24  None        None
# 10298  [1 Parking]  Apartment / Unit / Flat          09/24  None        None
# 10385  [1 Parking]                Townhouse          09/24  None        None
# 10496  [1 Parking]  Apartment / Unit / Flat          09/24  None        None
# 10529  [1 Parking]                    House          09/24  None        None
# 10702  [1 Parking]  Apartment / Unit / Flat          09/24  None        None
# 10961  [2 Parking]                    House          09/24  None        None
# 11157  [− Parking]  Apartment / Unit / Flat          09/24  None        None
# 11297  [2 Parking]                    House          09/24  None        None
# 12143  [1 Parking]  Apartment / Unit / Flat          09/24  None        None
# 12357  [1 Parking]                Townhouse          09/24  None        None
# 12387  [− Parking]  Apartment / Unit / Flat          09/24  None        None
# 12642  [2 Parking]                    House          09/24  None        None
# 13060  [2 Parking]                    House          09/24  None        None
#
#        weekly_cost                    address           suburb postcode
# 659          440.0        3/123 williams road          prahran     3181
# 1029         540.0         17 grevillia drive        mill park     3082
# 1120         550.0         2/50 lane crescent        reservoir     3073
# 1952         780.0                48 leeds st   doncaster east     3109
# 2037         750.0                 21 nyah st      keilor east     3033
# 2404         540.0      2601/65 dudley street   west melbourne     3003
# 3152         620.0       202/18 malone street          geelong     3220
# 3153         590.0  5/43-45 deschamp crescent         rowville     3178
# 3795         370.0         2/70 williams road       wangaratta     3677
# 4029         495.0         11 paperbark court        broadford     3658
# 4404         540.0   1408/2 newquay promenade        docklands     3008
# 4710         550.0      4/72 grosvenor street        balaclava     3183
# 4933         850.0        28b lightwood drive   ferntree gully     3156
# 5085         450.0            2 mylson avenue        broadford     3658
# 5309         795.0         182 stewart street   brunswick east     3057
# 6710         650.0      u303/65 dudley street   west melbourne     3003
# 6924         600.0        10 davenport street  armstrong creek     3217
# 7049         375.0       2a butterworth place          wodonga     3690
# 7181         500.0            39 noble street         anglesea     3230
# 7570         500.0     403/88 carlisle street         st kilda     3182
# 7873         900.0           190 smith street        thornbury     3071
# 8042         775.0          4 lancelot avenue            clyde     3978
# 8240         275.0         11-13 cooma street          preston     3072
# 8358         350.0       9/319 dandenong road          prahran     3181
# 8438         560.0      6/58 glen orme avenue           ormond     3204
# 8463         475.0      9/302 golf links road     narre warren     3805
# 8857         550.0      413/70 batesford road        chadstone     3148
# 8906         595.0         313/15 bond street        caulfield     3162
# 9218         525.0           104 hamish drive          tarneit     3029
# 9447         450.0          15 allandale road       kings park     3021
# 10169        525.0         9/27 coorigil road         carnegie     3163
# 10298        535.0       2/40 irvine crescent   brunswick west     3055
# 10385        780.0            20a central ave       black rock     3193
# 10496        600.0        705/8 marmion place        docklands     3008
# 10529        750.0         6a curraweena road  caulfield south     3162
# 10702        550.0   13/159-169 curzon street  north melbourne     3051
# 10961        610.0           38 gossia avenue      craigieburn     3064
# 11157        700.0     u2109/65 dudley street   west melbourne     3003
# 11297        520.0            39 spearys road     diggers rest     3427
# 12143        500.0     304/40 burgundy street       heidelberg     3084
# 12357        450.0              158 farm road         werribee     3030
# 12387        500.0    2602/350 william street        melbourne     3000
# 12642        500.0          32 blenril avenue          tarneit     3029
# 13060        400.0         9 st helens avenue     lake gardens     3355

# %%
def extract_latitude(coords):
    if isinstance(coords, (list, tuple, np.ndarray)) and len(coords) > 0:
        return float(coords[0])
    return None

def extract_longitude(coords):
    if isinstance(coords, (list, tuple, np.ndarray)) and len(coords) > 1:
        return float(coords[1])
    return None

# Apply the functions to handle both numpy.ndarray and NoneType
domain_df['latitude'] = domain_df['coordinates'].apply(extract_latitude)
domain_df['longitude'] = domain_df['coordinates'].apply(extract_longitude)

domain_df.head()
# Out:
#                                         name              rooms      parking  \
# 0          6 Gentle Street, Clayton VIC 3168  [3 Beds, 2 Baths]  [2 Parking]
# 1          142 Civic Parade, Altona VIC 3018   [3 Beds, 1 Bath]  [1 Parking]
# 2  4/104 Bernard Street, Cheltenham VIC 3192  [3 Beds, 2 Baths]  [2 Parking]
# 3   2 Collendina Crescent, Scoresby VIC 3179  [3 Beds, 2 Baths]  [2 Parking]
# 4   103/6A Evergreen Mews, Armadale VIC 3143  [2 Beds, 2 Baths]  [1 Parking]
#
#              property_type date_available   bond                 coordinates  \
# 0                    House          09/24  $2520  [-37.9221445, 145.1130263]
# 1                    House          09/24  $2390      [-37.86445, 144.82913]
# 2                Townhouse          09/24  $3302  [-37.9543583, 145.0693877]
# 3                    House          09/24  $2694   [-37.8901142, 145.223353]
# 4  Apartment / Unit / Flat          09/24   None  [-37.8518143, 145.0133926]
#
#    weekly_cost                address      suburb postcode   latitude  \
# 0        580.0        6 gentle street     clayton     3168 -37.922145
# 1        550.0       142 civic parade      altona     3018 -37.864450
# 2        760.0   4/104 bernard street  cheltenham     3192 -37.954358
# 3        640.0  2 collendina crescent    scoresby     3179 -37.890114
# 4        790.0  103/6a evergreen mews    armadale     3143 -37.851814
#
#     longitude
# 0  145.113026
# 1  144.829130
# 2  145.069388
# 3  145.223353
# 4  145.013393

# %%
# Create a GeoDataFrame
geometry = [Point(xy) for xy in zip(domain_df['longitude'], domain_df['latitude'])]
domain_gdf = gpd.GeoDataFrame(domain_df, geometry=geometry)

# Set the Coordinate Reference System (CRS) if known, e.g., EPSG:4326 for WGS84
domain_gdf.set_crs(epsg=4326, inplace=True)

# Display the first few rows of the GeoDataFrame
domain_gdf.head(50)
# Out:
#                                                 name              rooms  \
# 0                  6 Gentle Street, Clayton VIC 3168  [3 Beds, 2 Baths]
# 1                  142 Civic Parade, Altona VIC 3018   [3 Beds, 1 Bath]
# 2          4/104 Bernard Street, Cheltenham VIC 3192  [3 Beds, 2 Baths]
# 3           2 Collendina Crescent, Scoresby VIC 3179  [3 Beds, 2 Baths]
# 4           103/6A Evergreen Mews, Armadale VIC 3143  [2 Beds, 2 Baths]
# 5            93 Honour Avenue, Wyndham Vale VIC 3024  [3 Beds, 2 Baths]
# 6    504/179 Boundary Road, North Melbourne VIC 3051    [1 Bed, 1 Bath]
# 7                     38 Dunlop, Shepparton VIC 3630   [3 Beds, 1 Bath]
# 8          18 Greenfinch Drive, Clyde North VIC 3978  [4 Beds, 2 Baths]
# 9          1008/18 Albert Street, Footscray VIC 3011    [1 Bed, 1 Bath]
# 10        506/19-21 Poplar Street, Box Hill VIC 3128  [2 Beds, 2 Baths]
# 11    31 Collins Street, Heidelberg Heights VIC 3081  [3 Beds, 2 Baths]
# 12         72 Newton Avenue, Bell Post Hill VIC 3215  [3 Beds, 2 Baths]
# 13              11/15 McKinley Ave, Malvern VIC 3144   [2 Beds, 1 Bath]
# 14                    1/14 May Road, Toorak VIC 3142    [1 Bed, 1 Bath]
# 15            21 Howitt Street, South Yarra VIC 3141  [4 Beds, 2 Baths]
# 16               5 Dragomir Street, Officer VIC 3809  [4 Beds, 2 Baths]
# 17   6501/35 Queensbridge Street, Southbank VIC 3006  [4 Beds, 4 Baths]
# 18               3/126 Brougham Street, Kew VIC 3101  [3 Beds, 2 Baths]
# 19          5/43 Banksia Grove, Tullamarine VIC 3043   [3 Beds, 1 Bath]
# 20         3 Linburn Street, Thornhill Park VIC 3335  [4 Beds, 2 Baths]
# 21      4306/228 LA TROBE STREET, Melbourne VIC 3000    [1 Bed, 1 Bath]
# 22          5/21 Wilson Street, South Yarra VIC 3141    [1 Bed, 1 Bath]
# 23         54 Ernest Street, Bell Post Hill VIC 3215   [3 Beds, 1 Bath]
# 24        806/118 Russell Street, Melbourne VIC 3000   [2 Beds, 1 Bath]
# 25                 81 Clarkes Rd, Fyansford VIC 3218  [4 Beds, 2 Baths]
# 26               389A Highett Road, Highett VIC 3190  [4 Beds, 2 Baths]
# 27      43 Mountain Street, South Melbourne VIC 3205   [2 Beds, 1 Bath]
# 28     1/962 Dandenong Road, Caulfield East VIC 3145  [2 Beds, 2 Baths]
# 29            1/24 Northcote Avenue, Balwyn VIC 3103  [3 Beds, 2 Baths]
# 30        30 Collison Road, Cranbourne East VIC 3977  [4 Beds, 2 Baths]
# 31          22 Crichton Crescent, Venus Bay VIC 3956   [4 Beds, 1 Bath]
# 32          1 Carey Crescent, Bacchus Marsh VIC 3340   [3 Beds, 1 Bath]
# 33               4 WENHAMS LANE, Wangaratta VIC 3677  [3 Beds, 2 Baths]
# 34                10 Leahy Street, Hamilton VIC 3300   [3 Beds, 1 Bath]
# 35            25 Holme Road, Ferntree Gully VIC 3156   [3 Beds, 1 Bath]
# 36  6106/35 Queens Bridge Street, Southbank VIC 3006  [3 Beds, 2 Baths]
# 37          10/10 Charnwood Grove, St Kilda VIC 3182    [1 Bed, 1 Bath]
# 38           6 Bonnie Court, Ferntree Gully VIC 3156  [5 Beds, 2 Baths]
# 39        115B/71 Riversdale Road, Hawthorn VIC 3122    [1 Bed, 1 Bath]
# 40                7 Alfonso Court, Lynbrook VIC 3975  [4 Beds, 2 Baths]
# 41                 13 Nurtja Drive, Kyabram VIC 3620  [4 Beds, 2 Baths]
# 42               36 Wendouree Drive, Kialla VIC 3631  [4 Beds, 2 Baths]
# 43            2/2 Marriott Street, St Kilda VIC 3182    [1 Bed, 1 Bath]
# 44            1408/241 City Road, Southbank VIC 3006  [3 Beds, 2 Baths]
# 45           4/210 Albion Street, Brunswick VIC 3056   [2 Beds, 1 Bath]
# 46    6 Buchanan Boulevard, Armstrong Creek VIC 3217  [4 Beds, 2 Baths]
# 47         5/39-41 Panorama Drive, San Remo VIC 3925   [3 Beds, 1 Bath]
# 48               11/647 Toorak Road, Toorak VIC 3142    [1 Bed, 1 Bath]
# 49     5610/135 A'Beckett Street, Melbourne VIC 3000   [2 Beds, 1 Bath]
#
#         parking            property_type date_available    bond  \
# 0   [2 Parking]                    House          09/24   $2520
# 1   [1 Parking]                    House          09/24   $2390
# 2   [2 Parking]                Townhouse          09/24   $3302
# 3   [2 Parking]                    House          09/24   $2694
# 4   [1 Parking]  Apartment / Unit / Flat          09/24    None
# 5   [1 Parking]                    House          09/24   $1955
# 6   [− Parking]  Apartment / Unit / Flat          09/24   $1738
# 7   [− Parking]                    House          09/24   $2145
# 8   [2 Parking]                Townhouse          09/24   $2586
# 9   [1 Parking]  Apartment / Unit / Flat          09/24   $1955
# 10  [1 Parking]  Apartment / Unit / Flat          09/24   $2694
# 11  [2 Parking]                    House          09/24   $2824
# 12  [3 Parking]                    House          09/24   $2259
# 13  [1 Parking]  Apartment / Unit / Flat          09/24   $2281
# 14  [1 Parking]  Apartment / Unit / Flat          09/24   $1912
# 15  [2 Parking]                    House          09/24   $5620
# 16  [2 Parking]                    House          09/24   $2686
# 17  [2 Parking]  Apartment / Unit / Flat          09/24  $75000
# 18  [2 Parking]  Apartment / Unit / Flat          09/24   $3259
# 19  [2 Parking]                Townhouse          09/24   $2260
# 20  [2 Parking]                    House          09/24   $2166
# 21  [− Parking]  Apartment / Unit / Flat          09/24   $2934
# 22  [1 Parking]  Apartment / Unit / Flat          09/24   $2380
# 23  [1 Parking]                    House          09/24    None
# 24  [− Parking]  Apartment / Unit / Flat          09/24   $3142
# 25  [2 Parking]                    House          09/24   $2824
# 26  [2 Parking]                Townhouse          09/24   $4563
# 27  [− Parking]                    House          09/24   $2933
# 28  [1 Parking]                Townhouse          09/24   $2499
# 29  [2 Parking]  Apartment / Unit / Flat          09/24   $3454
# 30  [4 Parking]                    House          09/24   $3911
# 31  [1 Parking]                    House          09/24   $1955
# 32  [1 Parking]                    House          09/24   $2042
# 33  [2 Parking]                    House          09/24   $1880
# 34  [2 Parking]                    House          09/24   $1520
# 35  [2 Parking]                    House          09/24   $2455
# 36  [2 Parking]  Apartment / Unit / Flat          09/24  $13800
# 37  [− Parking]  Apartment / Unit / Flat          09/24   $1690
# 38  [2 Parking]                    House          09/24   $3411
# 39  [− Parking]                   Studio          09/24   $1434
# 40  [3 Parking]                Townhouse          09/24   $2990
# 41  [2 Parking]                    House          09/24   $2281
# 42  [2 Parking]                    House          09/24   $2867
# 43  [1 Parking]  Apartment / Unit / Flat          09/24   $1868
# 44  [1 Parking]  Apartment / Unit / Flat          09/24    None
# 45  [1 Parking]  Apartment / Unit / Flat          09/24   $2607
# 46  [2 Parking]                    House          09/24   $2694
# 47  [1 Parking]                Townhouse          09/24   $2173
# 48  [1 Parking]  Apartment / Unit / Flat          09/24   $2021
# 49  [− Parking]  Apartment / Unit / Flat          09/24   $3150
#
#                    coordinates  weekly_cost                       address  \
# 0   [-37.9221445, 145.1130263]        580.0               6 gentle street
# 1       [-37.86445, 144.82913]        550.0              142 civic parade
# 2   [-37.9543583, 145.0693877]        760.0          4/104 bernard street
# 3    [-37.8901142, 145.223353]        640.0         2 collendina crescent
# 4   [-37.8518143, 145.0133926]        790.0         103/6a evergreen mews
# 5    [-37.8978691, 144.626483]        450.0              93 honour avenue
# 6   [-37.7889129, 144.9392885]        400.0         504/179 boundary road
# 7   [-36.3587392, 145.4037277]        495.0                     38 dunlop
# 8   [-38.0853229, 145.3548667]        595.0           18 greenfinch drive
# 9   [-37.8016476, 144.8977057]        450.0         1008/18 albert street
# 10  [-37.8148278, 145.1166796]        620.0       506/19-21 poplar street
# 11   [-37.7376084, 145.052296]        650.0             31 collins street
# 12  [-38.0940723, 144.3272355]        520.0              72 newton avenue
# 13  [-37.8653708, 145.0313897]        525.0            11/15 mckinley ave
# 14  [-37.8475003, 145.0041488]        440.0                 1/14 may road
# 15  [-37.8468223, 145.0022694]       1295.0              21 howitt street
# 16   [-38.071444, 145.3960198]        620.0             5 dragomir street
# 17  [-37.8228837, 144.9612147]      12500.0   6501/35 queensbridge street
# 18  [-37.8004718, 145.0315039]        750.0         3/126 brougham street
# 19    [-37.704449, 144.880174]        520.0            5/43 banksia grove
# 20  [-37.7233856, 144.6207621]        500.0              3 linburn street
# 21   [-37.809615, 144.9623021]        675.0      4306/228 la trobe street
# 22  [-37.8437612, 144.9964955]        595.0            5/21 wilson street
# 23  [-38.1003926, 144.3279504]        480.0              54 ernest street
# 24  [-37.8134998, 144.9690884]        725.0        806/118 russell street
# 25  [-38.1366177, 144.3002652]        650.0                 81 clarkes rd
# 26    [-37.94701, 145.0287283]       1050.0             389a highett road
# 27  [-37.8372065, 144.9488931]        675.0            43 mountain street
# 28  [-37.8811332, 145.0492264]        575.0          1/962 dandenong road
# 29  [-37.8170858, 145.0872497]        795.0         1/24 northcote avenue
# 30   [-38.1079939, 145.314763]        900.0              30 collison road
# 31  [-38.7012214, 145.8305739]        450.0          22 crichton crescent
# 32  [-37.6696841, 144.4236774]        470.0              1 carey crescent
# 33  [-36.3824361, 146.3277221]        470.0                4 wenhams lane
# 34  [-37.7322767, 142.0125829]        380.0               10 leahy street
# 35  [-37.8904524, 145.2679225]        565.0                 25 holme road
# 36  [-37.8230583, 144.9614033]       2300.0  6106/35 queens bridge street
# 37  [-37.8593542, 144.9851976]        390.0         10/10 charnwood grove
# 38  [-37.8912561, 145.2824528]        785.0                6 bonnie court
# 39  [-37.8283482, 145.0323547]        330.0       115b/71 riversdale road
# 40  [-38.0463004, 145.2599004]        690.0               7 alfonso court
# 41  [-36.3122774, 145.0642379]        525.0               13 nurtja drive
# 42  [-36.4313642, 145.4015274]        660.0            36 wendouree drive
# 43  [-37.8630278, 144.9882119]        430.0           2/2 marriott street
# 44  [-37.8262358, 144.9600047]        910.0            1408/241 city road
# 45  [-37.7607613, 144.9615677]        600.0           4/210 albion street
# 46  [-38.2422988, 144.3816478]        620.0          6 buchanan boulevard
# 47  [-38.5240983, 145.3766002]        500.0        5/39-41 panorama drive
# 48    [-37.843101, 145.027238]        465.0            11/647 toorak road
# 49  [-37.8097879, 144.9596466]        725.0     5610/135 a'beckett street
#
#                 suburb postcode   latitude   longitude  \
# 0              clayton     3168 -37.922145  145.113026
# 1               altona     3018 -37.864450  144.829130
# 2           cheltenham     3192 -37.954358  145.069388
# 3             scoresby     3179 -37.890114  145.223353
# 4             armadale     3143 -37.851814  145.013393
# 5         wyndham vale     3024 -37.897869  144.626483
# 6      north melbourne     3051 -37.788913  144.939289
# 7           shepparton     3630 -36.358739  145.403728
# 8          clyde north     3978 -38.085323  145.354867
# 9            footscray     3011 -37.801648  144.897706
# 10            box hill     3128 -37.814828  145.116680
# 11  heidelberg heights     3081 -37.737608  145.052296
# 12      bell post hill     3215 -38.094072  144.327236
# 13             malvern     3144 -37.865371  145.031390
# 14              toorak     3142 -37.847500  145.004149
# 15         south yarra     3141 -37.846822  145.002269
# 16             officer     3809 -38.071444  145.396020
# 17           southbank     3006 -37.822884  144.961215
# 18                 kew     3101 -37.800472  145.031504
# 19         tullamarine     3043 -37.704449  144.880174
# 20      thornhill park     3335 -37.723386  144.620762
# 21           melbourne     3000 -37.809615  144.962302
# 22         south yarra     3141 -37.843761  144.996496
# 23      bell post hill     3215 -38.100393  144.327950
# 24           melbourne     3000 -37.813500  144.969088
# 25           fyansford     3218 -38.136618  144.300265
# 26             highett     3190 -37.947010  145.028728
# 27     south melbourne     3205 -37.837207  144.948893
# 28      caulfield east     3145 -37.881133  145.049226
# 29              balwyn     3103 -37.817086  145.087250
# 30     cranbourne east     3977 -38.107994  145.314763
# 31           venus bay     3956 -38.701221  145.830574
# 32       bacchus marsh     3340 -37.669684  144.423677
# 33          wangaratta     3677 -36.382436  146.327722
# 34            hamilton     3300 -37.732277  142.012583
# 35      ferntree gully     3156 -37.890452  145.267922
# 36           southbank     3006 -37.823058  144.961403
# 37            st kilda     3182 -37.859354  144.985198
# 38      ferntree gully     3156 -37.891256  145.282453
# 39            hawthorn     3122 -37.828348  145.032355
# 40            lynbrook     3975 -38.046300  145.259900
# 41             kyabram     3620 -36.312277  145.064238
# 42              kialla     3631 -36.431364  145.401527
# 43            st kilda     3182 -37.863028  144.988212
# 44           southbank     3006 -37.826236  144.960005
# 45           brunswick     3056 -37.760761  144.961568
# 46     armstrong creek     3217 -38.242299  144.381648
# 47            san remo     3925 -38.524098  145.376600
# 48              toorak     3142 -37.843101  145.027238
# 49           melbourne     3000 -37.809788  144.959647
#
#                        geometry
# 0   POINT (145.11303 -37.92214)
# 1   POINT (144.82913 -37.86445)
# 2   POINT (145.06939 -37.95436)
# 3   POINT (145.22335 -37.89011)
# 4   POINT (145.01339 -37.85181)
# 5   POINT (144.62648 -37.89787)
# 6   POINT (144.93929 -37.78891)
# 7   POINT (145.40373 -36.35874)
# 8   POINT (145.35487 -38.08532)
# 9   POINT (144.89771 -37.80165)
# 10  POINT (145.11668 -37.81483)
# 11   POINT (145.0523 -37.73761)
# 12  POINT (144.32724 -38.09407)
# 13  POINT (145.03139 -37.86537)
# 14   POINT (145.00415 -37.8475)
# 15  POINT (145.00227 -37.84682)
# 16  POINT (145.39602 -38.07144)
# 17  POINT (144.96121 -37.82288)
# 18   POINT (145.0315 -37.80047)
# 19  POINT (144.88017 -37.70445)
# 20  POINT (144.62076 -37.72339)
# 21   POINT (144.9623 -37.80962)
# 22   POINT (144.9965 -37.84376)
# 23  POINT (144.32795 -38.10039)
# 24   POINT (144.96909 -37.8135)
# 25  POINT (144.30027 -38.13662)
# 26  POINT (145.02873 -37.94701)
# 27  POINT (144.94889 -37.83721)
# 28  POINT (145.04923 -37.88113)
# 29  POINT (145.08725 -37.81709)
# 30  POINT (145.31476 -38.10799)
# 31  POINT (145.83057 -38.70122)
# 32  POINT (144.42368 -37.66968)
# 33  POINT (146.32772 -36.38244)
# 34  POINT (142.01258 -37.73228)
# 35  POINT (145.26792 -37.89045)
# 36   POINT (144.9614 -37.82306)
# 37   POINT (144.9852 -37.85935)
# 38  POINT (145.28245 -37.89126)
# 39  POINT (145.03235 -37.82835)
# 40    POINT (145.2599 -38.0463)
# 41  POINT (145.06424 -36.31228)
# 42  POINT (145.40153 -36.43136)
# 43  POINT (144.98821 -37.86303)
# 44     POINT (144.96 -37.82624)
# 45  POINT (144.96157 -37.76076)
# 46   POINT (144.38165 -38.2423)
# 47    POINT (145.3766 -38.5241)
# 48   POINT (145.02724 -37.8431)
# 49  POINT (144.95965 -37.80979)

# %% [markdown]
# ## Calculating distances to closest train station

# %%
# Make sure CRS is EPSG 4326 for Rental Data
domain_gdf = domain_gdf.to_crs(epsg=4326)
print(domain_gdf.crs)
# Out:
# EPSG:4326

# %%
# Make sure CRS is EPSG 4326 for Train Data
train_gdf = train_gdf.to_crs(epsg=4326)
print(train_gdf.crs)
# Out:
# EPSG:4326

# %%
# Initialize OpenRouteService client with your API key
api_key = '5b3ce3597851110001cf62483425e548d4ed4c2ca4a6b5814be96094'
client = Client(key=api_key)

# %% [markdown]
# ## Creating Train Station Isochrones

# %%
# THIS TAKES A WHILE. EXPECT IT TO BE ABOUT 13 MINUTES

def generate_isochrones(train_gdf, client, processed_stations, output_file, interval=600):  # 600 seconds = 10 minutes
    isochrone_features = []  # To store all isochrone features
    
    for index, train_station in train_gdf.iterrows():
        station_id = train_station['stop_id']  # Use STOP_ID
        station_name = train_station['stop_name']  # Use STOP_NAME
        lat, lon = train_station.geometry.y, train_station.geometry.x
        
        # Skip if station already processed
        if station_id in processed_stations:
            continue
        
        print(f"Processing: {station_id} - {station_name} (Lat: {lat}, Lon: {lon})")
        
        # Isochrone parameters for 10 minutes (600 seconds) driving time
        params_iso = {
            'profile': 'driving-car',
            'intervals': [interval],  # Single interval of 10 minutes
            'locations': [[lon, lat]],
        }
        
        try:
            # Fetch isochrones
            isochrones = client.isochrones(**params_iso)
            
            # Convert the isochrone to a GeoJSON Feature
            for feature in isochrones['features']:
                isochrone_feature = {
                    'type': 'Feature',
                    'geometry': feature['geometry'],  # Isochrone geometry
                    'properties': {
                        'station_id': station_id,  # Use STOP_ID
                        'station_name': station_name,  # Use STOP_NAME
                        'interval': interval,  # 10-minute interval
                        'latitude': lat,
                        'longitude': lon
                    }
                }
                isochrone_features.append(isochrone_feature)
            
            # Mark station as processed
            processed_stations.append(station_id)

            # Delay to prevent hitting the rate limit
            delay = 3
            time.sleep(delay)
            
        except Exception as e:
            print(f"Error processing station {station_id} - {station_name}: {e}")
    
    # Print the count and sample of isochrone features
    print(f"Isochrone features count: {len(isochrone_features)}")
    print("Sample isochrone features:", json.dumps(isochrone_features[:1], indent=2))
    
    # Create a GeoJSON structure to hold all isochrones
    isochrone_collection = {
        'type': 'FeatureCollection',
        'features': isochrone_features
    }
    
    # Ensure the directory exists
    output_directory = os.path.dirname(output_file)
    os.makedirs(output_directory, exist_ok=True)
    
    # Save the entire collection to a single GeoJSON file
    with open(output_file, 'w') as f:
        json.dump(isochrone_collection, f, indent=2)
    
    print(f"All isochrones saved to {output_file}")

# Prepare test parameters
processed_stations = []

# Run the test
generate_isochrones(
    train_gdf, 
    client, 
    processed_stations, 
    '../data/curated/isochrones/isochrones.geojson',
    interval=600
)
# Out:
# Processing: 19970 - Royal Park Railway Station (Parkville) (Lat: -37.7811929725527, Lon: 144.95230120580877)
# Processing: 19971 - Flemington Bridge Railway Station (North Melbourne) (Lat: -37.788139984393844, Lon: 144.93932321237276)
# Processing: 19972 - Macaulay Railway Station (North Melbourne) (Lat: -37.79426700459872, Lon: 144.93616600406753)
# Processing: 19973 - North Melbourne Railway Station (West Melbourne) (Lat: -37.80741897361899, Lon: 144.94257002890663)
# Processing: 19974 - Clifton Hill Railway Station (Clifton Hill) (Lat: -37.78865703363607, Lon: 144.9954169601631)
# Processing: 19975 - Victoria Park Railway Station (Abbotsford) (Lat: -37.79915796626723, Lon: 144.9944510689111)
# Processing: 19976 - Collingwood Railway Station (Abbotsford) (Lat: -37.80452601640281, Lon: 144.99375014165992)
# Processing: 19977 - North Richmond Railway Station (Richmond) (Lat: -37.8103979761548, Lon: 144.9924998535909)
# Processing: 19978 - West Richmond Railway Station (Richmond) (Lat: -37.81494900584843, Lon: 144.991423087592)
# Processing: 19979 - Jolimont-MCG Railway Station (East Melbourne) (Lat: -37.816526974237526, Lon: 144.9840981689869)
# Processing: 19983 - Macleod Railway Station (Macleod) (Lat: -37.72601198852847, Lon: 145.06914313196347)
# Processing: 19984 - Watsonia Railway Station (Watsonia) (Lat: -37.71095796058549, Lon: 145.08379299256393)
# Processing: 19985 - Greensborough Railway Station (Greensborough) (Lat: -37.703953978517774, Lon: 145.10824705206068)
# Processing: 19986 - Montmorency Railway Station (Montmorency) (Lat: -37.715295960542775, Lon: 145.121515927139)
# Processing: 19987 - Eltham Railway Station (Eltham) (Lat: -37.71354996061303, Lon: 145.14782184864805)
# Processing: 19988 - Diamond Creek Railway Station (Diamond Creek) (Lat: -37.67329701063555, Lon: 145.1585059320563)
# Processing: 19989 - Wattle Glen Railway Station (Wattle Glen) (Lat: -37.66396797039701, Lon: 145.18161506467828)
# Processing: 19990 - Hurstbridge Railway Station (Hurstbridge) (Lat: -37.639397969862365, Lon: 145.1920168942208)
# Processing: 19991 - Williamstown Railway Station (Williamstown) (Lat: -37.867752990404725, Lon: 144.90532295721854)
# Processing: 19992 - Williamstown Beach Railway Station (Williamstown) (Lat: -37.86398198938481, Lon: 144.89448409561462)
# Processing: 19993 - North Williamstown Railway Station (Williamstown) (Lat: -37.85733296977821, Lon: 144.88906897782545)
# Processing: 19994 - Newport Railway Station (Newport) (Lat: -37.84271796018809, Lon: 144.88359986187862)
# Processing: 19995 - Spotswood Railway Station (Spotswood) (Lat: -37.83063897072853, Lon: 144.8859330113764)
# Processing: 19996 - Yarraville Railway Station (Yarraville) (Lat: -37.815849989791694, Lon: 144.8899340507632)
# Processing: 19997 - Seddon Railway Station (Seddon) (Lat: -37.809005040754464, Lon: 144.89567208120746)
# Processing: 20000 - Watergardens Railway Station (Sydenham) (Lat: -37.70112896819069, Lon: 144.77418001840798)
# Processing: 20001 - Keilor Plains Railway Station (St Albans) (Lat: -37.72927898714574, Lon: 144.79373809136527)
# Processing: 20002 - St Albans Railway Station (St Albans) (Lat: -37.74486095681743, Lon: 144.8000499727449)
# Processing: 20003 - Ginifer Railway Station (St Albans) (Lat: -37.76006699999778, Lon: 144.81134785114367)
# Processing: 20004 - Albion Railway Station (Sunshine North) (Lat: -37.77765299958764, Lon: 144.82470386247024)
# Processing: 20005 - Epping Railway Station (Epping) (Lat: -37.65218696812649, Lon: 145.03106807483192)
# Processing: 20006 - Lalor Railway Station (Lalor) (Lat: -37.665851039818996, Lon: 145.01719296110826)
# Processing: 20007 - Thomastown Railway Station (Thomastown) (Lat: -37.680337978698795, Lon: 145.01427914567134)
# Processing: 20008 - Keon Park Railway Station (Thomastown) (Lat: -37.6948700083548, Lon: 145.01188405834273)
# Processing: 20009 - Ruthven Railway Station (Reservoir) (Lat: -37.707897956372506, Lon: 145.00951704207858)
# Processing: 20010 - Reservoir Railway Station (Reservoir) (Lat: -37.71688499694048, Lon: 145.00699596597707)
# Processing: 20011 - Regent Railway Station (Reservoir) (Lat: -37.728403018220824, Lon: 145.00277316312736)
# Processing: 20012 - Preston Railway Station (Preston) (Lat: -37.738673997291826, Lon: 145.00052208049493)
# Processing: 20013 - Bell Railway Station (Preston) (Lat: -37.74556196740014, Lon: 145.00015487669162)
# Processing: 20014 - Thornbury Railway Station (Thornbury) (Lat: -37.75505201755157, Lon: 144.99857195554867)
# Processing: 20015 - Croxton Railway Station (Northcote) (Lat: -37.764100977920975, Lon: 144.99705601149938)
# Processing: 20016 - Northcote Railway Station (Northcote) (Lat: -37.7698650286647, Lon: 144.99527690393882)
# Processing: 20017 - Merri Railway Station (Northcote) (Lat: -37.77784704042674, Lon: 144.9929721934344)
# Processing: 20019 - Rushall Railway Station (Fitzroy North) (Lat: -37.783216981751494, Lon: 144.99240699877623)
# Processing: 20021 - Sunshine Railway Station (Sunshine) (Lat: -37.78853598103241, Lon: 144.83287803702032)
# Processing: 20022 - Tottenham Railway Station (West Footscray) (Lat: -37.79925101953307, Lon: 144.86294482805647)
# Processing: 20023 - West Footscray Railway Station (West Footscray) (Lat: -37.80180296938542, Lon: 144.88398504854027)
# Processing: 20024 - Middle Footscray Railway Station (Footscray) (Lat: -37.802504970278676, Lon: 144.8914719665355)
# Processing: 20025 - Footscray Railway Station (Footscray) (Lat: -37.80108297392747, Lon: 144.90319893797937)
# Processing: 20026 - South Kensington Railway Station (Kensington) (Lat: -37.799531010135645, Lon: 144.92546896739066)
# Processing: 20030 - Broadmeadows Railway Station (Broadmeadows) (Lat: -37.68304895729302, Lon: 144.91961320131395)
# Processing: 20031 - Jacana Railway Station (Glenroy) (Lat: -37.695131010164516, Lon: 144.9158511944258)
# Processing: 20032 - Glenroy Railway Station (Glenroy) (Lat: -37.70453600891375, Lon: 144.91721989592028)
# Processing: 20033 - Oak Park Railway Station (Oak Park) (Lat: -37.71794996733691, Lon: 144.9215190050332)
# Processing: 20034 - Pascoe Vale Railway Station (Pascoe Vale) (Lat: -37.73075597710179, Lon: 144.92819593517615)
# Processing: 20035 - Strathmore Railway Station (Strathmore) (Lat: -37.74359096751782, Lon: 144.92731609110757)
# Processing: 20036 - Glenbervie Railway Station (Essendon) (Lat: -37.74720995793417, Lon: 144.9209390576499)
# Processing: 20037 - Essendon Railway Station (Essendon) (Lat: -37.75601195980886, Lon: 144.91619785779378)
# Processing: 20038 - Moonee Ponds Railway Station (Moonee Ponds) (Lat: -37.765707029872225, Lon: 144.91916101804085)
# Processing: 20039 - Ascot Vale Railway Station (Ascot Vale) (Lat: -37.775305978752286, Lon: 144.92182105511844)
# Processing: 20040 - Newmarket Railway Station (Flemington) (Lat: -37.78732800123391, Lon: 144.9289778791842)
# Processing: 20041 - Kensington Railway Station (Kensington) (Lat: -37.79378001234484, Lon: 144.93052408229383)
# Processing: 20042 - Box Hill Railway Station (Box Hill) (Lat: -37.819222033091656, Lon: 145.1214291542125)
# Processing: 22180 - Southern Cross Railway Station (Melbourne City) (Lat: -37.81793601351573, Lon: 144.9514108850503)
# Processing: 40220 - Roxburgh Park Railway Station (Roxburgh Park) (Lat: -37.63823102879973, Lon: 144.9354038580987)
# Processing: 40221 - Craigieburn Railway Station (Craigieburn) (Lat: -37.6018170275946, Lon: 144.94331989483877)
# Processing: 44817 - Coolaroo Railway Station (Coolaroo) (Lat: -37.6610030113571, Lon: 144.92605609416944)
# Processing: 45793 - Lynbrook Railway Station (Lynbrook) (Lat: -38.057340961642154, Lon: 145.24927487781102)
# Processing: 45794 - Cardinia Road Railway Station (Pakenham) (Lat: -38.071289971320894, Lon: 145.43779105694023)
# Processing: 45795 - South Morang Railway Station (South Morang) (Lat: -37.64915901306895, Lon: 145.0670320966615)
# Processing: 46468 - Williams Landing Railway Station (Williams Landing) (Lat: -37.8698650235294, Lon: 144.74744497619167)
# Processing: 52095 - Southland Railway Station (Cheltenham) (Lat: -37.95875605115335, Lon: 145.0491210080803)
# Processing: 52159 - Middle Gorge Railway Station (South Morang) (Lat: -37.644060959065094, Lon: 145.09214389829435)
# Processing: 52160 - Hawkstowe Railway Station (South Morang) (Lat: -37.62299502042986, Lon: 145.0973959520007)
# Processing: 52161 - Mernda Railway Station (Mernda) (Lat: -37.602548008693105, Lon: 145.1008850816138)
# Processing: 15351 - Sunbury Railway Station (Sunbury) (Lat: -37.579091041919106, Lon: 144.7273191965987)
# Processing: 15353 - Diggers Rest Railway Station (Diggers Rest) (Lat: -37.62701703098356, Lon: 144.719921894289)
# Processing: 19827 - Stony Point Railway Station (Crib Point) (Lat: -38.37423501463105, Lon: 145.2218371303087)
# Processing: 19828 - Crib Point Railway Station (Crib Point) (Lat: -38.366123042492156, Lon: 145.20404302458843)
# Processing: 19829 - Morradoo Railway Station (Crib Point) (Lat: -38.35403298231219, Lon: 145.18960200468328)
# Processing: 19830 - Bittern Railway Station (Bittern) (Lat: -38.33739000410354, Lon: 145.17802694776515)
# Processing: 19831 - Hastings Railway Station (Hastings) (Lat: -38.30565897380473, Lon: 145.18598004542605)
# Processing: 19832 - Tyabb Railway Station (Tyabb) (Lat: -38.25981504276969, Lon: 145.18640091121645)
# Processing: 19833 - Somerville Railway Station (Somerville) (Lat: -38.22534198465516, Lon: 145.17624495783332)
# Processing: 19834 - Baxter Railway Station (Baxter) (Lat: -38.194043042101164, Lon: 145.1605259068461)
# Processing: 19835 - Glen Iris Railway Station (Glen Iris) (Lat: -37.85930802724669, Lon: 145.0582250497741)
# Processing: 19836 - Leawarra Railway Station (Frankston) (Lat: -38.152034013128976, Lon: 145.1395339285365)
# Processing: 19837 - Darling Railway Station (Malvern East) (Lat: -37.86895701673703, Lon: 145.06295114201313)
# Processing: 19838 - East Malvern Railway Station (Malvern East) (Lat: -37.87693002547972, Lon: 145.06939298848198)
# Processing: 19839 - Holmesglen Railway Station (Malvern East) (Lat: -37.874402019247384, Lon: 145.09066211307118)
# Processing: 19840 - Jordanville Railway Station (Mount Waverley) (Lat: -37.87360300336732, Lon: 145.11209003619842)
# Processing: 19841 - Flagstaff Railway Station (Melbourne City) (Lat: -37.811980983068906, Lon: 144.95565385897856)
# Processing: 19842 - Melbourne Central Railway Station (Melbourne City) (Lat: -37.80993897219737, Lon: 144.9625939477722)
# Processing: 19843 - Parliament Railway Station (Melbourne City) (Lat: -37.81105398311787, Lon: 144.9729111811868)
# Processing: 19844 - Belgrave Railway Station (Belgrave) (Lat: -37.90910196303172, Lon: 145.35529094228033)
# Processing: 19845 - Tecoma Railway Station (Tecoma) (Lat: -37.90811799418759, Lon: 145.3429951499282)
# Processing: 19846 - Upwey Railway Station (Upwey) (Lat: -37.903690983475485, Lon: 145.33133294736945)
# Processing: 19847 - Alamein Railway Station (Ashburton) (Lat: -37.86831999881286, Lon: 145.0796558510017)
# Processing: 19848 - Ashburton Railway Station (Ashburton) (Lat: -37.86196798070856, Lon: 145.08134389547052)
# Processing: 19849 - Burwood Railway Station (Glen Iris) (Lat: -37.851562991336685, Lon: 145.08051084427572)
# Processing: 19850 - Hartwell Railway Station (Camberwell) (Lat: -37.843984988466225, Lon: 145.0755601197322)
# Processing: 19851 - Willison Railway Station (Camberwell) (Lat: -37.835715965394016, Lon: 145.07029800484113)
# Processing: 19852 - Riversdale Railway Station (Camberwell) (Lat: -37.831505045420805, Lon: 145.0696460448304)
# Processing: 19853 - Camberwell Railway Station (Camberwell) (Lat: -37.826567020894245, Lon: 145.05869701396765)
# Processing: 19854 - Flinders Street Railway Station (Melbourne City) (Lat: -37.81830501305625, Lon: 144.96696399665555)
# Processing: 19855 - Frankston Railway Station (Frankston) (Lat: -38.14299000537099, Lon: 145.12616208447614)
# Processing: 19856 - Kananook Railway Station (Seaford) (Lat: -38.12174199466812, Lon: 145.13529493934251)
# Processing: 19857 - Seaford Railway Station (Seaford) (Lat: -38.10402099378123, Lon: 145.12822994038072)
# Processing: 19858 - Carrum Railway Station (Carrum) (Lat: -38.076504033265415, Lon: 145.1228331806026)
# Processing: 19859 - Bonbeach Railway Station (Bonbeach) (Lat: -38.06294499455282, Lon: 145.11967993833284)
# Processing: 19860 - Chelsea Railway Station (Chelsea) (Lat: -38.05195500582945, Lon: 145.1160410561567)
# Processing: 19861 - Edithvale Railway Station (Edithvale) (Lat: -38.03805603411457, Lon: 145.10853614659555)
# Processing: 19862 - Aspendale Railway Station (Aspendale) (Lat: -38.02722003428127, Lon: 145.10215009763107)
# Processing: 19863 - Mordialloc Railway Station (Mordialloc) (Lat: -38.006583036530465, Lon: 145.08765900709295)
# Processing: 19864 - Parkdale Railway Station (Parkdale) (Lat: -37.993078985669186, Lon: 145.0763269243707)
# Processing: 19865 - Mentone Railway Station (Mentone) (Lat: -37.98186498543101, Lon: 145.06516585321697)
# Processing: 19866 - Cheltenham Railway Station (Cheltenham) (Lat: -37.96665004267008, Lon: 145.05455809320318)
# Processing: 19867 - Upper Ferntree Gully Railway Station (Upper Ferntree Gully) (Lat: -37.89267201519074, Lon: 145.30753010573622)
# Processing: 19868 - Ferntree Gully Railway Station (Ferntree Gully) (Lat: -37.88169804430563, Lon: 145.2952508595173)
# Processing: 19869 - Boronia Railway Station (Boronia) (Lat: -37.86045201284621, Lon: 145.28438498378276)
# Processing: 19870 - Bayswater Railway Station (Bayswater) (Lat: -37.84173003269863, Lon: 145.26813602050083)
# Processing: 19871 - Heathmont Railway Station (Heathmont) (Lat: -37.828322013500426, Lon: 145.24455493593294)
# Processing: 19872 - Highett Railway Station (Highett) (Lat: -37.948425037176236, Lon: 145.04187207003986)
# Processing: 19873 - Glen Waverley Railway Station (Glen Waverley) (Lat: -37.87950402884809, Lon: 145.16205804677077)
# Processing: 19874 - Syndal Railway Station (Glen Waverley) (Lat: -37.87623001198126, Lon: 145.14977988400065)
# Processing: 19875 - Mount Waverley Railway Station (Mount Waverley) (Lat: -37.87525504140691, Lon: 145.1280560390715)
# Processing: 19876 - Lilydale Railway Station (Lilydale) (Lat: -37.75551804148801, Lon: 145.34771006372208)
# Processing: 19877 - Mooroolbark Railway Station (Mooroolbark) (Lat: -37.78474896242301, Lon: 145.312401980717)
# Processing: 19878 - Croydon Railway Station (Croydon) (Lat: -37.795437003004096, Lon: 145.28059813649503)
# Processing: 19879 - Ringwood East Railway Station (Ringwood East) (Lat: -37.811968020901645, Lon: 145.25019111735213)
# Processing: 19880 - Pakenham Railway Station (Pakenham) (Lat: -38.080613971994666, Lon: 145.4863791670269)
# Processing: 19881 - Officer Railway Station (Officer) (Lat: -38.06614602358953, Lon: 145.41098691161596)
# Processing: 19882 - Beaconsfield Railway Station (Beaconsfield) (Lat: -38.05083099268969, Lon: 145.36607402041432)
# Processing: 19883 - Berwick Railway Station (Berwick) (Lat: -38.04040800417337, Lon: 145.345726106732)
# Processing: 19884 - Narre Warren Railway Station (Narre Warren) (Lat: -38.02780899067889, Lon: 145.30396899348813)
# Processing: 19885 - Hallam Railway Station (Hallam) (Lat: -38.0177399723026, Lon: 145.26977691372707)
# Processing: 19886 - Cranbourne Railway Station (Cranbourne) (Lat: -38.099537015167755, Lon: 145.2805988876704)
# Processing: 19887 - Merinda Park Railway Station (Cranbourne North) (Lat: -38.07900000428343, Lon: 145.26351110606686)
# Processing: 19888 - Dandenong Railway Station (Dandenong) (Lat: -37.98996804320864, Lon: 145.20972494168106)
# Processing: 19889 - Yarraman Railway Station (Noble Park) (Lat: -37.97825499531765, Lon: 145.19160002133484)
# Processing: 19890 - Noble Park Railway Station (Noble Park) (Lat: -37.96662798649904, Lon: 145.17632485727145)
# Processing: 19891 - Sandown Park Railway Station (Springvale) (Lat: -37.9565049634813, Lon: 145.16282594045538)
# Processing: 19892 - East Camberwell Railway Station (Camberwell) (Lat: -37.82589399751228, Lon: 145.06818984612514)
# Processing: 19893 - Canterbury Railway Station (Canterbury) (Lat: -37.824485052015234, Lon: 145.08122400522683)
# Processing: 19894 - Chatham Railway Station (Surrey Hills) (Lat: -37.824300013259794, Lon: 145.08864792992347)
# Processing: 19895 - Surrey Hills Railway Station (Surrey Hills) (Lat: -37.82414800244947, Lon: 145.09877510312708)
# Processing: 19896 - Mont Albert Railway Station (Mont Albert) (Lat: -37.819427052222316, Lon: 145.1055301411415)
# Processing: 19897 - Laburnum Railway Station (Blackburn) (Lat: -37.82078002325073, Lon: 145.1407028348687)
# Processing: 19898 - Blackburn Railway Station (Blackburn) (Lat: -37.820071002378896, Lon: 145.1500138764687)
# Processing: 19899 - Nunawading Railway Station (Nunawading) (Lat: -37.82042802941446, Lon: 145.1752369288804)
# Processing: 19900 - Mitcham Railway Station (Mitcham) (Lat: -37.818087035153475, Lon: 145.1928920581536)
# Processing: 19901 - Heatherdale Railway Station (Ringwood) (Lat: -37.81883502338564, Lon: 145.21354994696432)
# Processing: 19902 - Ringwood Railway Station (Ringwood) (Lat: -37.81566000007894, Lon: 145.2294741698739)
# Processing: 19903 - Auburn Railway Station (Hawthorn East) (Lat: -37.82239804230204, Lon: 145.04584392844583)
# Processing: 19904 - Glenferrie Railway Station (Hawthorn) (Lat: -37.821466991314885, Lon: 145.03643891857303)
# Processing: 19905 - Hawthorn Railway Station (Hawthorn) (Lat: -37.821825996611395, Lon: 145.02289894827368)
# Processing: 19906 - Burnley Railway Station (Burnley) (Lat: -37.82755998022155, Lon: 145.0075550556105)
# Processing: 19907 - East Richmond Railway Station (Richmond) (Lat: -37.82639997289394, Lon: 144.9970661029343)
# Processing: 19908 - Richmond Railway Station (Richmond) (Lat: -37.82407401385715, Lon: 144.9901641806745)
# Processing: 19909 - Heyington Railway Station (Toorak) (Lat: -37.834671965373985, Lon: 145.02263508424622)
# Processing: 19910 - Kooyong Railway Station (Kooyong) (Lat: -37.839929048366116, Lon: 145.03355208421473)
# Processing: 19911 - Tooronga Railway Station (Malvern) (Lat: -37.84936599739654, Lon: 145.04173415478712)
# Processing: 19912 - Gardiner Railway Station (Glen Iris) (Lat: -37.85327901773509, Lon: 145.05165504987352)
# Processing: 19913 - Springvale Railway Station (Springvale) (Lat: -37.94950899259216, Lon: 145.1534518921023)
# Processing: 19914 - Westall Railway Station (Clayton South) (Lat: -37.938491011333234, Lon: 145.13883302874603)
# Processing: 19915 - Clayton Railway Station (Clayton) (Lat: -37.92468303486988, Lon: 145.12053387025009)
# Processing: 19916 - Huntingdale Railway Station (Oakleigh) (Lat: -37.911016990825836, Lon: 145.10236393324308)
# Processing: 19917 - Oakleigh Railway Station (Oakleigh) (Lat: -37.90037196749365, Lon: 145.0883080921356)
# Processing: 19918 - Hughesdale Railway Station (Hughesdale) (Lat: -37.89488097733909, Lon: 145.07763518406495)
# Processing: 19919 - Murrumbeena Railway Station (Murrumbeena) (Lat: -37.89019800833117, Lon: 145.0673751866043)
# Processing: 19920 - Carnegie Railway Station (Carnegie) (Lat: -37.886240976370786, Lon: 145.05857497723898)
# Processing: 19921 - Werribee Railway Station (Werribee) (Lat: -37.89937800378759, Lon: 144.66111806209827)
# Processing: 19922 - Hoppers Crossing Railway Station (Hoppers Crossing) (Lat: -37.88327601324334, Lon: 144.7009549451706)
# Processing: 19923 - Laverton Railway Station (Laverton) (Lat: -37.863693995393945, Lon: 144.77261691069953)
# Processing: 19924 - Aircraft Railway Station (Laverton) (Lat: -37.866606032750546, Lon: 144.7608088985207)
# Processing: 19925 - Westona Railway Station (Altona) (Lat: -37.8651629765648, Lon: 144.81349417315855)
# Processing: 19926 - Altona Railway Station (Altona) (Lat: -37.86714801409339, Lon: 144.82964484849458)
# Processing: 19927 - Seaholme Railway Station (Seaholme) (Lat: -37.86784200270676, Lon: 144.84095784803088)
# Processing: 19928 - Westgarth Railway Station (Northcote) (Lat: -37.780621021498604, Lon: 144.9992329526931)
# Processing: 19929 - Dennis Railway Station (Northcote) (Lat: -37.779186960703825, Lon: 145.00824193502052)
# Processing: 19930 - Fairfield Railway Station (Fairfield) (Lat: -37.77917103027729, Lon: 145.01690497413267)
# Processing: 19931 - Alphington Railway Station (Alphington) (Lat: -37.778393970184325, Lon: 145.0312549420362)
# Processing: 19932 - Darebin Railway Station (Ivanhoe) (Lat: -37.774962990239736, Lon: 145.0384761897359)
# Processing: 19933 - Ivanhoe Railway Station (Ivanhoe) (Lat: -37.76889698950453, Lon: 145.0454249007254)
# Processing: 19934 - Eaglemont Railway Station (Eaglemont) (Lat: -37.76358600115558, Lon: 145.0539428530202)
# Processing: 19935 - Heidelberg Railway Station (Heidelberg) (Lat: -37.75707297186314, Lon: 145.06068602994233)
# Processing: 19936 - Rosanna Railway Station (Rosanna) (Lat: -37.74287898170107, Lon: 145.06614004306664)
# Processing: 19937 - Moorabbin Railway Station (Moorabbin) (Lat: -37.934352997334734, Lon: 145.0367381151247)
# Processing: 19938 - Patterson Railway Station (Bentleigh) (Lat: -37.9251489679829, Lon: 145.03547018698544)
# Processing: 19939 - Bentleigh Railway Station (Bentleigh) (Lat: -37.917424987593655, Lon: 145.0369951450514)
# Processing: 19940 - McKinnon Railway Station (Mckinnon) (Lat: -37.9103090471004, Lon: 145.03829905678242)
# Processing: 19941 - Ormond Railway Station (Ormond) (Lat: -37.903212006932286, Lon: 145.0396130453646)
# Processing: 19942 - Glenhuntly Railway Station (Glen Huntly) (Lat: -37.889719026839934, Lon: 145.04222302981012)
# Processing: 19943 - Caulfield Railway Station (Caulfield East) (Lat: -37.87745904950535, Lon: 145.04252511062438)
# Processing: 19944 - Malvern Railway Station (Malvern) (Lat: -37.86625296743994, Lon: 145.02929401539313)
# Processing: 19945 - Armadale Railway Station (Armadale) (Lat: -37.85645196640077, Lon: 145.0193259624038)
# Processing: 19946 - Toorak Railway Station (Armadale) (Lat: -37.85077404613171, Lon: 145.01390904858653)
# Processing: 19947 - Hawksburn Railway Station (South Yarra) (Lat: -37.84459104465304, Lon: 145.00214211386543)
# Processing: 19948 - Sandringham Railway Station (Sandringham) (Lat: -37.95032997678135, Lon: 145.00456092996131)
# Processing: 19949 - Hampton Railway Station (Hampton) (Lat: -37.93797702778554, Lon: 145.0014710475163)
# Processing: 19950 - Brighton Beach Railway Station (Brighton) (Lat: -37.92648402636408, Lon: 144.98915400748288)
# Processing: 19951 - Middle Brighton Railway Station (Brighton) (Lat: -37.91513403726259, Lon: 144.99629892106807)
# Processing: 19952 - North Brighton Railway Station (Brighton) (Lat: -37.904886999374064, Lon: 145.00260504023572)
# Processing: 19953 - Gardenvale Railway Station (Brighton) (Lat: -37.89669501891709, Lon: 145.0041681594568)
# Processing: 19954 - Elsternwick Railway Station (Elsternwick) (Lat: -37.88475300849933, Lon: 145.00089792626244)
# Processing: 19955 - Ripponlea Railway Station (Ripponlea) (Lat: -37.875906008374365, Lon: 144.99523695425376)
# Processing: 19956 - Balaclava Railway Station (Balaclava) (Lat: -37.869488016261954, Lon: 144.99351218235657)
# Processing: 19957 - Windsor Railway Station (Windsor) (Lat: -37.85605299340357, Lon: 144.99203509329004)
# Processing: 19958 - Prahran Railway Station (Prahran) (Lat: -37.849518003492406, Lon: 144.98985999271946)
# Processing: 19959 - South Yarra Railway Station (South Yarra) (Lat: -37.83844899324962, Lon: 144.99234219972408)
# Processing: 19960 - Upfield Railway Station (Coolaroo) (Lat: -37.66607802131612, Lon: 144.94673986754253)
# Processing: 19961 - Gowrie Railway Station (Glenroy) (Lat: -37.700677977421826, Lon: 144.95887403782967)
# Processing: 19962 - Fawkner Railway Station (Fawkner) (Lat: -37.71462095840933, Lon: 144.96054517607726)
# Processing: 19963 - Merlynston Railway Station (Coburg North) (Lat: -37.72093400681235, Lon: 144.96131413229386)
# Processing: 19964 - Batman Railway Station (Coburg North) (Lat: -37.7335230271606, Lon: 144.96284088444295)
# Processing: 19965 - Coburg Railway Station (Coburg) (Lat: -37.74234500853543, Lon: 144.96333587826746)
# Processing: 19966 - Moreland Railway Station (Coburg) (Lat: -37.7544850178849, Lon: 144.96182315245065)
# Processing: 19967 - Anstey Railway Station (Brunswick) (Lat: -37.761242037577134, Lon: 144.96068412503988)
# Processing: 19968 - Brunswick Railway Station (Brunswick) (Lat: -37.767720957795504, Lon: 144.95958686111737)
# Processing: 19969 - Jewell Railway Station (Brunswick) (Lat: -37.7749870197818, Lon: 144.95871710696892)
# Isochrone features count: 220
# Sample isochrone features: [
#   {
#     "type": "Feature",
#     "geometry": {
#       "coordinates": [
#         [
#           [
#             144.897211,
#             -37.769377
#           ],
#           [
#             144.898317,
#             -37.771499
#           ],
#           [
#             144.902936,
#             -37.775505
#           ],
#           [
#             144.908501,
#             -37.780303
#           ],
#           [
#             144.908868,
#             -37.782626
#           ],
#           [
#             144.909098,
#             -37.782875
#           ],
#           [
#             144.910307,
#             -37.783416
#           ],
#           [
#             144.914767,
#             -37.785016
#           ],
#           [
#             144.918,
#             -37.791442
#           ],
#           [
#             144.917991,
#             -37.794272
#           ],
#           [
#             144.917908,
#             -37.794854
#           ],
#           [
#             144.916556,
#             -37.79846
#           ],
#           [
#             144.916483,
#             -37.800895
#           ],
#           [
#             144.916519,
#             -37.801219
#           ],
#           [
#             144.917195,
#             -37.801556
#           ],
#           [
#             144.92138,
#             -37.80653
#           ],
#           [
#             144.921009,
#             -37.810111
#           ],
#           [
#             144.923194,
#             -37.810337
#           ],
#           [
#             144.925741,
#             -37.811022
#           ],
#           [
#             144.930852,
#             -37.818239
#           ],
#           [
#             144.929039,
#             -37.823359
#           ],
#           [
#             144.928995,
#             -37.823573
#           ],
#           [
#             144.929056,
#             -37.82441
#           ],
#           [
#             144.932656,
#             -37.824439
#           ],
#           [
#             144.932708,
#             -37.823917
#           ],
#           [
#             144.937908,
#             -37.816718
#           ],
#           [
#             144.938136,
#             -37.816632
#           ],
#           [
#             144.939236,
#             -37.816262
#           ],
#           [
#             144.945525,
#             -37.816675
#           ],
#           [
#             144.954131,
#             -37.817086
#           ],
#           [
#             144.956259,
#             -37.818037
#           ],
#           [
#             144.961264,
#             -37.818925
#           ],
#           [
#             144.962424,
#             -37.819147
#           ],
#           [
#             144.965091,
#             -37.8189
#           ],
#           [
#             144.965102,
#             -37.818897
#           ],
#           [
#             144.969763,
#             -37.816817
#           ],
#           [
#             144.971219,
#             -37.81585
#           ],
#           [
#             144.973647,
#             -37.813126
#           ],
#           [
#             144.978366,
#             -37.810084
#           ],
#           [
#             144.981142,
#             -37.807973
#           ],
#           [
#             144.982308,
#             -37.806794
#           ],
#           [
#             144.987294,
#             -37.800356
#           ],
#           [
#             144.988088,
#             -37.799737
#           ],
#           [
#             144.995554,
#             -37.797055
#           ],
#           [
#             144.997038,
#             -37.797163
#           ],
#           [
#             144.997572,
#             -37.797187
#           ],
#           [
#             144.998456,
#             -37.7972
#           ],
#           [
#             144.999136,
#             -37.797187
#           ],
#           [
#             144.999962,
#             -37.797115
#           ],
#           [
#             145.000998,
#             -37.796965
#           ],
#           [
#             145.000482,
#             -37.793402
#           ],
#           [
#             144.993764,
#             -37.788783
#           ],
#           [
#             144.993212,
#             -37.786119
#           ],
#           [
#             144.991,
#             -37.777624
#           ],
#           [
#             144.989525,
#             -37.776007
#           ],
#           [
#             144.989196,
#             -37.768193
#           ],
#           [
#             144.989309,
#             -37.767565
#           ],
#           [
#             144.988617,
#             -37.766219
#           ],
#           [
#             144.982974,
#             -37.762913
#           ],
#           [
#             144.98094,
#             -37.757473
#           ],
#           [
#             144.978726,
#             -37.751594
#           ],
#           [
#             144.976897,
#             -37.749755
#           ],
#           [
#             144.976761,
#             -37.74974
#           ],
#           [
#             144.976704,
#             -37.749734
#           ],
#           [
#             144.976533,
#             -37.74972
#           ],
#           [
#             144.974037,
#             -37.751039
#           ],
#           [
#             144.965616,
#             -37.752002
#           ],
#           [
#             144.96522,
#             -37.751957
#           ],
#           [
#             144.96166,
#             -37.751227
#           ],
#           [
#             144.955948,
#             -37.748548
#           ],
#           [
#             144.95313,
#             -37.745643
#           ],
#           [
#             144.948631,
#             -37.74135
#           ],
#           [
#             144.947333,
#             -37.739999
#           ],
#           [
#             144.943774,
#             -37.739457
#           ],
#           [
#             144.942555,
#             -37.740671
#           ],
#           [
#             144.933663,
#             -37.740919
#           ],
#           [
#             144.932317,
#             -37.738565
#           ],
#           [
#             144.932143,
#             -37.737954
#           ],
#           [
#             144.931778,
#             -37.737
#           ],
#           [
#             144.931257,
#             -37.736175
#           ],
#           [
#             144.930736,
#             -37.735534
#           ],
#           [
#             144.930432,
#             -37.735225
#           ],
#           [
#             144.930161,
#             -37.734976
#           ],
#           [
#             144.927726,
#             -37.737627
#           ],
#           [
#             144.928134,
#             -37.738579
#           ],
#           [
#             144.928989,
#             -37.740155
#           ],
#           [
#             144.925155,
#             -37.747719
#           ],
#           [
#             144.923786,
#             -37.748825
#           ],
#           [
#             144.923371,
#             -37.749341
#           ],
#           [
#             144.91878,
#             -37.755456
#           ],
#           [
#             144.911735,
#             -37.759361
#           ],
#           [
#             144.9062,
#             -37.761897
#           ],
#           [
#             144.904469,
#             -37.763166
#           ],
#           [
#             144.898732,
#             -37.767923
#           ],
#           [
#             144.897254,
#             -37.769182
#           ],
#           [
#             144.897211,
#             -37.769377
#           ]
#         ]
#       ],
#       "type": "Polygon"
#     },
#     "properties": {
#       "station_id": "19970",
#       "station_name": "Royal Park Railway Station (Parkville)",
#       "interval": 600,
#       "latitude": -37.7811929725527,
#       "longitude": 144.95230120580877
#     }
#   }
# ]
# All isochrones saved to ../data/curated/isochrones/isochrones.geojson

# %% [markdown]
# ## Finding which Train Station Isochrones each Rental Property Falls In

# %%
isochrone_gdf = gpd.read_file('../data/curated/isochrones/isochrones.geojson')

# Display the first few rows to verify
isochrone_gdf.head()
# Out:
#   station_id                                       station_name  interval  \
# 0      19970             Royal Park Railway Station (Parkville)       600
# 1      19971  Flemington Bridge Railway Station (North Melbo...       600
# 2      19972         Macaulay Railway Station (North Melbourne)       600
# 3      19973   North Melbourne Railway Station (West Melbourne)       600
# 4      19974        Clifton Hill Railway Station (Clifton Hill)       600
#
#     latitude   longitude                                           geometry
# 0 -37.781193  144.952301  POLYGON ((144.89721 -37.76938, 144.89832 -37.7...
# 1 -37.788140  144.939323  POLYGON ((144.8873 -37.77075, 144.8921 -37.774...
# 2 -37.794267  144.936166  POLYGON ((144.89347 -37.76897, 144.8941 -37.77...
# 3 -37.807419  144.942570  POLYGON ((144.90048 -37.79937, 144.89971 -37.8...
# 4 -37.788657  144.995417  POLYGON ((144.95551 -37.78951, 144.95568 -37.7...

# %%
# Perform Spatial join to find which isochrones each Rental Property falls in
joined_gdf = gpd.sjoin(domain_gdf, isochrone_gdf, how='inner', predicate='within')

# %%
joined_gdf
# Out:
#                                                                                      name  \
# https://www.domain.com.au/72a-argus-street-chel...  72A Argus Street, Cheltenham VIC 3192
# https://www.domain.com.au/72a-argus-street-chel...  72A Argus Street, Cheltenham VIC 3192
# https://www.domain.com.au/72a-argus-street-chel...  72A Argus Street, Cheltenham VIC 3192
# https://www.domain.com.au/72a-argus-street-chel...  72A Argus Street, Cheltenham VIC 3192
# https://www.domain.com.au/72a-argus-street-chel...  72A Argus Street, Cheltenham VIC 3192
# ...                                                                                   ...
# https://www.domain.com.au/3-lauren-square-paken...     3 Lauren Square, Pakenham VIC 3810
# https://www.domain.com.au/1-7-carluke-close-ber...    1/7 Carluke Close, Berwick VIC 3806
# https://www.domain.com.au/1-7-carluke-close-ber...    1/7 Carluke Close, Berwick VIC 3806
# https://www.domain.com.au/1-7-carluke-close-ber...    1/7 Carluke Close, Berwick VIC 3806
# https://www.domain.com.au/1-7-carluke-close-ber...    1/7 Carluke Close, Berwick VIC 3806
#
#                                                           cost_text  \
# https://www.domain.com.au/72a-argus-street-chel...  $1,050 Per Week
# https://www.domain.com.au/72a-argus-street-chel...  $1,050 Per Week
# https://www.domain.com.au/72a-argus-street-chel...  $1,050 Per Week
# https://www.domain.com.au/72a-argus-street-chel...  $1,050 Per Week
# https://www.domain.com.au/72a-argus-street-chel...  $1,050 Per Week
# ...                                                             ...
# https://www.domain.com.au/3-lauren-square-paken...    $500 per week
# https://www.domain.com.au/1-7-carluke-close-ber...          $375/wk
# https://www.domain.com.au/1-7-carluke-close-ber...          $375/wk
# https://www.domain.com.au/1-7-carluke-close-ber...          $375/wk
# https://www.domain.com.au/1-7-carluke-close-ber...          $375/wk
#
#                                                                 rooms  \
# https://www.domain.com.au/72a-argus-street-chel...  [4 Beds, 3 Baths]
# https://www.domain.com.au/72a-argus-street-chel...  [4 Beds, 3 Baths]
# https://www.domain.com.au/72a-argus-street-chel...  [4 Beds, 3 Baths]
# https://www.domain.com.au/72a-argus-street-chel...  [4 Beds, 3 Baths]
# https://www.domain.com.au/72a-argus-street-chel...  [4 Beds, 3 Baths]
# ...                                                               ...
# https://www.domain.com.au/3-lauren-square-paken...   [3 Beds, 1 Bath]
# https://www.domain.com.au/1-7-carluke-close-ber...   [0 Beds, 1 Bath]
# https://www.domain.com.au/1-7-carluke-close-ber...   [0 Beds, 1 Bath]
# https://www.domain.com.au/1-7-carluke-close-ber...   [0 Beds, 1 Bath]
# https://www.domain.com.au/1-7-carluke-close-ber...   [0 Beds, 1 Bath]
#
#                                                         parking  \
# https://www.domain.com.au/72a-argus-street-chel...  [2 Parking]
# https://www.domain.com.au/72a-argus-street-chel...  [2 Parking]
# https://www.domain.com.au/72a-argus-street-chel...  [2 Parking]
# https://www.domain.com.au/72a-argus-street-chel...  [2 Parking]
# https://www.domain.com.au/72a-argus-street-chel...  [2 Parking]
# ...                                                         ...
# https://www.domain.com.au/3-lauren-square-paken...  [2 Parking]
# https://www.domain.com.au/1-7-carluke-close-ber...  [1 Parking]
# https://www.domain.com.au/1-7-carluke-close-ber...  [1 Parking]
# https://www.domain.com.au/1-7-carluke-close-ber...  [1 Parking]
# https://www.domain.com.au/1-7-carluke-close-ber...  [1 Parking]
#
#                                                                                                  desc  \
# https://www.domain.com.au/72a-argus-street-chel...  Brand new and with a commanding street presenc...
# https://www.domain.com.au/72a-argus-street-chel...  Brand new and with a commanding street presenc...
# https://www.domain.com.au/72a-argus-street-chel...  Brand new and with a commanding street presenc...
# https://www.domain.com.au/72a-argus-street-chel...  Brand new and with a commanding street presenc...
# https://www.domain.com.au/72a-argus-street-chel...  Brand new and with a commanding street presenc...
# ...                                                                                               ...
# https://www.domain.com.au/3-lauren-square-paken...  APPLY NOW: We invite prospective renters to ap...
# https://www.domain.com.au/1-7-carluke-close-ber...                               * Unverified feature
# https://www.domain.com.au/1-7-carluke-close-ber...                               * Unverified feature
# https://www.domain.com.au/1-7-carluke-close-ber...                               * Unverified feature
# https://www.domain.com.au/1-7-carluke-close-ber...                               * Unverified feature
#
#                                                    property_type  \
# https://www.domain.com.au/72a-argus-street-chel...     Townhouse
# https://www.domain.com.au/72a-argus-street-chel...     Townhouse
# https://www.domain.com.au/72a-argus-street-chel...     Townhouse
# https://www.domain.com.au/72a-argus-street-chel...     Townhouse
# https://www.domain.com.au/72a-argus-street-chel...     Townhouse
# ...                                                          ...
# https://www.domain.com.au/3-lauren-square-paken...         House
# https://www.domain.com.au/1-7-carluke-close-ber...        Studio
# https://www.domain.com.au/1-7-carluke-close-ber...        Studio
# https://www.domain.com.au/1-7-carluke-close-ber...        Studio
# https://www.domain.com.au/1-7-carluke-close-ber...        Studio
#
#                                                    date_available   bond  \
# https://www.domain.com.au/72a-argus-street-chel...  Available Now  $6300
# https://www.domain.com.au/72a-argus-street-chel...  Available Now  $6300
# https://www.domain.com.au/72a-argus-street-chel...  Available Now  $6300
# https://www.domain.com.au/72a-argus-street-chel...  Available Now  $6300
# https://www.domain.com.au/72a-argus-street-chel...  Available Now  $6300
# ...                                                           ...    ...
# https://www.domain.com.au/3-lauren-square-paken...  Available Now  $2173
# https://www.domain.com.au/1-7-carluke-close-ber...  Available Now  $1629
# https://www.domain.com.au/1-7-carluke-close-ber...  Available Now  $1629
# https://www.domain.com.au/1-7-carluke-close-ber...  Available Now  $1629
# https://www.domain.com.au/1-7-carluke-close-ber...  Available Now  $1629
#
#                                                                                     property_features  \
# https://www.domain.com.au/72a-argus-street-chel...  [Split System Air Con, Split System Heating, O...
# https://www.domain.com.au/72a-argus-street-chel...  [Split System Air Con, Split System Heating, O...
# https://www.domain.com.au/72a-argus-street-chel...  [Split System Air Con, Split System Heating, O...
# https://www.domain.com.au/72a-argus-street-chel...  [Split System Air Con, Split System Heating, O...
# https://www.domain.com.au/72a-argus-street-chel...  [Split System Air Con, Split System Heating, O...
# ...                                                                                               ...
# https://www.domain.com.au/3-lauren-square-paken...                                                 []
# https://www.domain.com.au/1-7-carluke-close-ber...                                [Heating*, Ensuite]
# https://www.domain.com.au/1-7-carluke-close-ber...                                [Heating*, Ensuite]
# https://www.domain.com.au/1-7-carluke-close-ber...                                [Heating*, Ensuite]
# https://www.domain.com.au/1-7-carluke-close-ber...                                [Heating*, Ensuite]
#
#                                                                    coordinates  \
# https://www.domain.com.au/72a-argus-street-chel...  [-37.9592116, 145.0649156]
# https://www.domain.com.au/72a-argus-street-chel...  [-37.9592116, 145.0649156]
# https://www.domain.com.au/72a-argus-street-chel...  [-37.9592116, 145.0649156]
# https://www.domain.com.au/72a-argus-street-chel...  [-37.9592116, 145.0649156]
# https://www.domain.com.au/72a-argus-street-chel...  [-37.9592116, 145.0649156]
# ...                                                                        ...
# https://www.domain.com.au/3-lauren-square-paken...  [-38.0730438, 145.4890878]
# https://www.domain.com.au/1-7-carluke-close-ber...  [-38.0505947, 145.3413087]
# https://www.domain.com.au/1-7-carluke-close-ber...  [-38.0505947, 145.3413087]
# https://www.domain.com.au/1-7-carluke-close-ber...  [-38.0505947, 145.3413087]
# https://www.domain.com.au/1-7-carluke-close-ber...  [-38.0505947, 145.3413087]
#
#                                                     latitude_left  \
# https://www.domain.com.au/72a-argus-street-chel...     -37.959212
# https://www.domain.com.au/72a-argus-street-chel...     -37.959212
# https://www.domain.com.au/72a-argus-street-chel...     -37.959212
# https://www.domain.com.au/72a-argus-street-chel...     -37.959212
# https://www.domain.com.au/72a-argus-street-chel...     -37.959212
# ...                                                           ...
# https://www.domain.com.au/3-lauren-square-paken...     -38.073044
# https://www.domain.com.au/1-7-carluke-close-ber...     -38.050595
# https://www.domain.com.au/1-7-carluke-close-ber...     -38.050595
# https://www.domain.com.au/1-7-carluke-close-ber...     -38.050595
# https://www.domain.com.au/1-7-carluke-close-ber...     -38.050595
#
#                                                     longitude_left  \
# https://www.domain.com.au/72a-argus-street-chel...      145.064916
# https://www.domain.com.au/72a-argus-street-chel...      145.064916
# https://www.domain.com.au/72a-argus-street-chel...      145.064916
# https://www.domain.com.au/72a-argus-street-chel...      145.064916
# https://www.domain.com.au/72a-argus-street-chel...      145.064916
# ...                                                            ...
# https://www.domain.com.au/3-lauren-square-paken...      145.489088
# https://www.domain.com.au/1-7-carluke-close-ber...      145.341309
# https://www.domain.com.au/1-7-carluke-close-ber...      145.341309
# https://www.domain.com.au/1-7-carluke-close-ber...      145.341309
# https://www.domain.com.au/1-7-carluke-close-ber...      145.341309
#
#                                                                        geometry  \
# https://www.domain.com.au/72a-argus-street-chel...  POINT (145.06492 -37.95921)
# https://www.domain.com.au/72a-argus-street-chel...  POINT (145.06492 -37.95921)
# https://www.domain.com.au/72a-argus-street-chel...  POINT (145.06492 -37.95921)
# https://www.domain.com.au/72a-argus-street-chel...  POINT (145.06492 -37.95921)
# https://www.domain.com.au/72a-argus-street-chel...  POINT (145.06492 -37.95921)
# ...                                                                         ...
# https://www.domain.com.au/3-lauren-square-paken...  POINT (145.48909 -38.07304)
# https://www.domain.com.au/1-7-carluke-close-ber...  POINT (145.34131 -38.05059)
# https://www.domain.com.au/1-7-carluke-close-ber...  POINT (145.34131 -38.05059)
# https://www.domain.com.au/1-7-carluke-close-ber...  POINT (145.34131 -38.05059)
# https://www.domain.com.au/1-7-carluke-close-ber...  POINT (145.34131 -38.05059)
#
#                                                     index_right station_id  \
# https://www.domain.com.au/72a-argus-street-chel...           71      52095
# https://www.domain.com.au/72a-argus-street-chel...          114      19864
# https://www.domain.com.au/72a-argus-street-chel...          115      19865
# https://www.domain.com.au/72a-argus-street-chel...          116      19866
# https://www.domain.com.au/72a-argus-street-chel...          122      19872
# ...                                                         ...        ...
# https://www.domain.com.au/3-lauren-square-paken...          130      19880
# https://www.domain.com.au/1-7-carluke-close-ber...          131      19881
# https://www.domain.com.au/1-7-carluke-close-ber...          132      19882
# https://www.domain.com.au/1-7-carluke-close-ber...          133      19883
# https://www.domain.com.au/1-7-carluke-close-ber...          134      19884
#
#                                                                                    station_name  \
# https://www.domain.com.au/72a-argus-street-chel...       Southland Railway Station (Cheltenham)
# https://www.domain.com.au/72a-argus-street-chel...          Parkdale Railway Station (Parkdale)
# https://www.domain.com.au/72a-argus-street-chel...            Mentone Railway Station (Mentone)
# https://www.domain.com.au/72a-argus-street-chel...      Cheltenham Railway Station (Cheltenham)
# https://www.domain.com.au/72a-argus-street-chel...            Highett Railway Station (Highett)
# ...                                                                                         ...
# https://www.domain.com.au/3-lauren-square-paken...          Pakenham Railway Station (Pakenham)
# https://www.domain.com.au/1-7-carluke-close-ber...            Officer Railway Station (Officer)
# https://www.domain.com.au/1-7-carluke-close-ber...  Beaconsfield Railway Station (Beaconsfield)
# https://www.domain.com.au/1-7-carluke-close-ber...            Berwick Railway Station (Berwick)
# https://www.domain.com.au/1-7-carluke-close-ber...  Narre Warren Railway Station (Narre Warren)
#
#                                                     interval  latitude_right  \
# https://www.domain.com.au/72a-argus-street-chel...       600      -37.958756
# https://www.domain.com.au/72a-argus-street-chel...       600      -37.993079
# https://www.domain.com.au/72a-argus-street-chel...       600      -37.981865
# https://www.domain.com.au/72a-argus-street-chel...       600      -37.966650
# https://www.domain.com.au/72a-argus-street-chel...       600      -37.948425
# ...                                                      ...             ...
# https://www.domain.com.au/3-lauren-square-paken...       600      -38.080614
# https://www.domain.com.au/1-7-carluke-close-ber...       600      -38.066146
# https://www.domain.com.au/1-7-carluke-close-ber...       600      -38.050831
# https://www.domain.com.au/1-7-carluke-close-ber...       600      -38.040408
# https://www.domain.com.au/1-7-carluke-close-ber...       600      -38.027809
#
#                                                     longitude_right
# https://www.domain.com.au/72a-argus-street-chel...       145.049121
# https://www.domain.com.au/72a-argus-street-chel...       145.076327
# https://www.domain.com.au/72a-argus-street-chel...       145.065166
# https://www.domain.com.au/72a-argus-street-chel...       145.054558
# https://www.domain.com.au/72a-argus-street-chel...       145.041872
# ...                                                             ...
# https://www.domain.com.au/3-lauren-square-paken...       145.486379
# https://www.domain.com.au/1-7-carluke-close-ber...       145.410987
# https://www.domain.com.au/1-7-carluke-close-ber...       145.366074
# https://www.domain.com.au/1-7-carluke-close-ber...       145.345726
# https://www.domain.com.au/1-7-carluke-close-ber...       145.303969
#
# [113432 rows x 19 columns]

# %% [markdown]
# ## BATCH TESTING

# %%
import openrouteservice
import time
import numpy as np

# Initialize OpenRouteService client with your API key
api_key = '5b3ce3597851110001cf62483425e548d4ed4c2ca4a6b5814be96094'
client = openrouteservice.Client(key=api_key)

# Function to get batch distances using ORS Matrix API
def get_batch_distances(df, batch_size=50):
    all_distances = []
    
    for i in range(0, len(df), batch_size):
        batch = df.iloc[i:i + batch_size]
        
        # Prepare coordinates: first half are properties, second half are stations
        coords = [[row['longitude_left'], row['latitude_left']] for _, row in batch.iterrows()] + \
                 [[row['longitude_right'], row['latitude_right']] for _, row in batch.iterrows()]
        
        try:
            # ORS Matrix API request for driving distances
            matrix = client.distance_matrix(
                locations=coords, 
                profile='driving-car',
                metrics=['distance'],
                sources=list(range(len(batch))),  # Property indices
                destinations=list(range(len(batch), len(batch)*2))  # Station indices
            )
            
            # Get driving distances and append
            for j in range(len(batch)):
                distance = matrix['distances'][j][j]  # Property to station distance
                all_distances.append(distance / 1000)  # Convert from meters to kilometers
        except Exception as e:
            print(f"Error occurred: {e}")
            all_distances.extend([None] * len(batch))  # Append None for failed API calls

        # Respect the rate limit by adding a delay between batches
        time.sleep(2)  
    
    return all_distances

# Apply batch distance calculation to the DataFrame
batch_size = 50  # Adjust batch size according to your preference
test_dist = get_batch_distances(joined_gdf.iloc[:1000], batch_size=batch_size)

# %%
import time

# Function to get distances using ORS API for multiple properties
def get_distances(properties):
    distances = []  # List to store distances for each property-station pair
    
    # Iterate over each property
    for index, row in properties.iterrows():
        lat1 = row['latitude_left']
        lon1 = row['longitude_left']
        lat2 = row['latitude_right']
        lon2 = row['longitude_right']
        
        # Coordinates for rental property and train station
        coordinates = [[lon1, lat1], [lon2, lat2]]
        
        try:
            # Request route for the current property-station pair
            route = client.directions(coordinates=coordinates, profile='driving-car', format='geojson')
            
            # Get distance in meters and convert to kilometers
            distance = route['features'][0]['properties']['segments'][0]['distance']
            distances.append(distance / 1000)  # Append distance in kilometers
            
        except Exception as e:
            print(f"Error occurred for property at index {index}: {e}")
            distances.append(None)  # Handle failed API call and append None
        
        # Optional delay to avoid overwhelming the API
        time.sleep(2)
    
    return distances  # Return the list of distances

test_dist_single = get_distances(joined_gdf.iloc[50:75])

# %%
print(test_dist[50:55])
print(test_dist_single[0:5])
# Out:
# [4.304939999999999, 4.23354, 3.39082, 2.68735, 3.77915]
# [4.3049, 4.2335, 3.3908, 2.6874000000000002, 3.7792]

# %% [markdown]
# ## Calculating Distance to nearby Train Stations for each Rental Property

# %%
# Function to get distance using ORS API
def get_distance(lat1, lon1, lat2, lon2):
    # Coordinates for rental property and train station
    coordinates = [[lon1, lat1], [lon2, lat2]]
    
    try:
        # Request route
        route = client.directions(coordinates=coordinates, profile='driving-car', format='geojson')
        # Get distance in meters
        distance = route['features'][0]['properties']['segments'][0]['distance']
        return distance / 1000  # Convert to kilometers
    except Exception as e:
        print(f"Error occurred: {e}")
        return None  # Handle the case where API call fails

# Apply the function to DataFrame with a delay
def apply_distance_with_delay(row):
    distance = get_distance(row['latitude_left'], row['longitude_left'], row['latitude_right'], row['longitude_right'])
    time.sleep(2)  # Adding a delay of 1 second between requests
    return distance

# Apply with delay
joined_gdf['distance_km'] = joined_gdf.apply(apply_distance_with_delay, axis=1)
# Out:
# Error occurred: HTTP Error: 502
# Error occurred: 403 ({'error': 'Quota exceeded'})
# Error occurred: 403 ({'error': 'Quota exceeded'})
# Error occurred: 403 ({'error': 'Quota exceeded'})
# Error occurred: 403 ({'error': 'Quota exceeded'})
# Error occurred: 403 ({'error': 'Quota exceeded'})
# Error occurred: 403 ({'error': 'Quota exceeded'})
# Error occurred: 403 ({'error': 'Quota exceeded'})
# Error occurred: 403 ({'error': 'Quota exceeded'})
# Error occurred: 403 ({'error': 'Quota exceeded'})
# Error occurred: 403 ({'error': 'Quota exceeded'})
# Error occurred: 403 ({'error': 'Quota exceeded'})
# Error occurred: 403 ({'error': 'Quota exceeded'})
# Error occurred: 403 ({'error': 'Quota exceeded'})
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[876], line 23
#      20     return distance
#      22 # Apply with delay
# ---> 23 joined_gdf['distance_km'] = joined_gdf.apply(apply_distance_with_delay, axis=1)
#
# File ~/Desktop/UNI/project-2-group-real-estate-industry-project-31/.venv/lib/python3.9/site-packages/geopandas/geodataframe.py:1834, in GeoDataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    1832 @doc(pd.DataFrame)
#    1833 def apply(self, func, axis=0, raw=False, result_type=None, args=(), **kwargs):
# -> 1834     result = super().apply(
#    1835         func, axis=axis, raw=raw, result_type=result_type, args=args, **kwargs
#    1836     )
#    1837     # Reconstruct gdf if it was lost by apply
#    1838     if (
#    1839         isinstance(result, DataFrame)
#    1840         and self._geometry_column_name in result.columns
#    1841     ):
#    1842         # axis=1 apply will split GeometryDType to object, try and cast back
#
# File ~/Desktop/UNI/project-2-group-real-estate-industry-project-31/.venv/lib/python3.9/site-packages/pandas/core/frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File ~/Desktop/UNI/project-2-group-real-estate-industry-project-31/.venv/lib/python3.9/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~/Desktop/UNI/project-2-group-real-estate-industry-project-31/.venv/lib/python3.9/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~/Desktop/UNI/project-2-group-real-estate-industry-project-31/.venv/lib/python3.9/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[876], line 18, in apply_distance_with_delay(row)
#      17 def apply_distance_with_delay(row):
# ---> 18     distance = get_distance(row['latitude_left'], row['longitude_left'], row['latitude_right'], row['longitude_right'])
#      19     time.sleep(2)  # Adding a delay of 1 second between requests
#      20     return distance
#
# Cell In[876], line 8, in get_distance(lat1, lon1, lat2, lon2)
#       4 coordinates = [[lon1, lat1], [lon2, lat2]]
#       6 try:
#       7     # Request route
# ----> 8     route = client.directions(coordinates=coordinates, profile='driving-car', format='geojson')
#       9     # Get distance in meters
#      10     distance = route['features'][0]['properties']['segments'][0]['distance']
#
# File ~/Desktop/UNI/project-2-group-real-estate-industry-project-31/.venv/lib/python3.9/site-packages/openrouteservice/client.py:299, in _make_api_method.<locals>.wrapper(*args, **kwargs)
#     296 @functools.wraps(func)
#     297 def wrapper(*args, **kwargs):
#     298     args[0]._extra_params = kwargs.pop("extra_params", None)
# --> 299     result = func(*args, **kwargs)
#     300     try:
#     301         del args[0]._extra_params
#
# File ~/Desktop/UNI/project-2-group-real-estate-industry-project-31/.venv/lib/python3.9/site-packages/openrouteservice/directions.py:281, in directions(client, coordinates, profile, format_out, format, preference, units, language, geometry, geometry_simplify, instructions, instructions_format, alternative_routes, roundabout_exits, attributes, maneuvers, radiuses, bearings, skip_segments, continue_straight, elevation, extra_info, suppress_warnings, optimized, optimize_waypoints, options, validate, dry_run)
#     278 if options:
#     279     params['options'] = options
# --> 281 return client.request("/v2/directions/" + profile + '/' + format, {}, post_json=params, dry_run=dry_run)
#
# File ~/Desktop/UNI/project-2-group-real-estate-industry-project-31/.venv/lib/python3.9/site-packages/openrouteservice/client.py:186, in Client.request(self, url, get_params, first_request_time, retry_counter, requests_kwargs, post_json, dry_run)
#     183     return
#     185 try:
# --> 186     response = requests_method(self._base_url + authed_url,
#     187                                **final_requests_kwargs)
#     188     self._req = response.request
#     190 except requests.exceptions.Timeout:
#
# File ~/Desktop/UNI/project-2-group-real-estate-industry-project-31/.venv/lib/python3.9/site-packages/requests/sessions.py:637, in Session.post(self, url, data, json, **kwargs)
#     626 def post(self, url, data=None, json=None, **kwargs):
#     627     r"""Sends a POST request. Returns :class:`Response` object.
#     628
#     629     :param url: URL for the new :class:`Request` object.
#    (...)
#     634     :rtype: requests.Response
#     635     """
# --> 637     return self.request("POST", url, data=data, json=json, **kwargs)
#
# File ~/Desktop/UNI/project-2-group-real-estate-industry-project-31/.venv/lib/python3.9/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Desktop/UNI/project-2-group-real-estate-industry-project-31/.venv/lib/python3.9/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Desktop/UNI/project-2-group-real-estate-industry-project-31/.venv/lib/python3.9/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/Desktop/UNI/project-2-group-real-estate-industry-project-31/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/Desktop/UNI/project-2-group-real-estate-industry-project-31/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/Desktop/UNI/project-2-group-real-estate-industry-project-31/.venv/lib/python3.9/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File ~/opt/anaconda3/lib/python3.9/http/client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File ~/opt/anaconda3/lib/python3.9/http/client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File ~/opt/anaconda3/lib/python3.9/http/client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File ~/opt/anaconda3/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File ~/opt/anaconda3/lib/python3.9/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File ~/opt/anaconda3/lib/python3.9/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
joined_gdf.head()
# Out:
#                                                                                      name  \
# https://www.domain.com.au/72a-argus-street-chel...  72A Argus Street, Cheltenham VIC 3192
# https://www.domain.com.au/72a-argus-street-chel...  72A Argus Street, Cheltenham VIC 3192
# https://www.domain.com.au/72a-argus-street-chel...  72A Argus Street, Cheltenham VIC 3192
# https://www.domain.com.au/72a-argus-street-chel...  72A Argus Street, Cheltenham VIC 3192
# https://www.domain.com.au/72a-argus-street-chel...  72A Argus Street, Cheltenham VIC 3192
#
#                                                           cost_text  \
# https://www.domain.com.au/72a-argus-street-chel...  $1,050 Per Week
# https://www.domain.com.au/72a-argus-street-chel...  $1,050 Per Week
# https://www.domain.com.au/72a-argus-street-chel...  $1,050 Per Week
# https://www.domain.com.au/72a-argus-street-chel...  $1,050 Per Week
# https://www.domain.com.au/72a-argus-street-chel...  $1,050 Per Week
#
#                                                                 rooms  \
# https://www.domain.com.au/72a-argus-street-chel...  [4 Beds, 3 Baths]
# https://www.domain.com.au/72a-argus-street-chel...  [4 Beds, 3 Baths]
# https://www.domain.com.au/72a-argus-street-chel...  [4 Beds, 3 Baths]
# https://www.domain.com.au/72a-argus-street-chel...  [4 Beds, 3 Baths]
# https://www.domain.com.au/72a-argus-street-chel...  [4 Beds, 3 Baths]
#
#                                                         parking  \
# https://www.domain.com.au/72a-argus-street-chel...  [2 Parking]
# https://www.domain.com.au/72a-argus-street-chel...  [2 Parking]
# https://www.domain.com.au/72a-argus-street-chel...  [2 Parking]
# https://www.domain.com.au/72a-argus-street-chel...  [2 Parking]
# https://www.domain.com.au/72a-argus-street-chel...  [2 Parking]
#
#                                                                                                  desc  \
# https://www.domain.com.au/72a-argus-street-chel...  Brand new and with a commanding street presenc...
# https://www.domain.com.au/72a-argus-street-chel...  Brand new and with a commanding street presenc...
# https://www.domain.com.au/72a-argus-street-chel...  Brand new and with a commanding street presenc...
# https://www.domain.com.au/72a-argus-street-chel...  Brand new and with a commanding street presenc...
# https://www.domain.com.au/72a-argus-street-chel...  Brand new and with a commanding street presenc...
#
#                                                    property_type  \
# https://www.domain.com.au/72a-argus-street-chel...     Townhouse
# https://www.domain.com.au/72a-argus-street-chel...     Townhouse
# https://www.domain.com.au/72a-argus-street-chel...     Townhouse
# https://www.domain.com.au/72a-argus-street-chel...     Townhouse
# https://www.domain.com.au/72a-argus-street-chel...     Townhouse
#
#                                                    date_available   bond  \
# https://www.domain.com.au/72a-argus-street-chel...  Available Now  $6300
# https://www.domain.com.au/72a-argus-street-chel...  Available Now  $6300
# https://www.domain.com.au/72a-argus-street-chel...  Available Now  $6300
# https://www.domain.com.au/72a-argus-street-chel...  Available Now  $6300
# https://www.domain.com.au/72a-argus-street-chel...  Available Now  $6300
#
#                                                                                     property_features  \
# https://www.domain.com.au/72a-argus-street-chel...  [Split System Air Con, Split System Heating, O...
# https://www.domain.com.au/72a-argus-street-chel...  [Split System Air Con, Split System Heating, O...
# https://www.domain.com.au/72a-argus-street-chel...  [Split System Air Con, Split System Heating, O...
# https://www.domain.com.au/72a-argus-street-chel...  [Split System Air Con, Split System Heating, O...
# https://www.domain.com.au/72a-argus-street-chel...  [Split System Air Con, Split System Heating, O...
#
#                                                                    coordinates  \
# https://www.domain.com.au/72a-argus-street-chel...  [-37.9592116, 145.0649156]
# https://www.domain.com.au/72a-argus-street-chel...  [-37.9592116, 145.0649156]
# https://www.domain.com.au/72a-argus-street-chel...  [-37.9592116, 145.0649156]
# https://www.domain.com.au/72a-argus-street-chel...  [-37.9592116, 145.0649156]
# https://www.domain.com.au/72a-argus-street-chel...  [-37.9592116, 145.0649156]
#
#                                                     latitude_left  \
# https://www.domain.com.au/72a-argus-street-chel...     -37.959212
# https://www.domain.com.au/72a-argus-street-chel...     -37.959212
# https://www.domain.com.au/72a-argus-street-chel...     -37.959212
# https://www.domain.com.au/72a-argus-street-chel...     -37.959212
# https://www.domain.com.au/72a-argus-street-chel...     -37.959212
#
#                                                     longitude_left  \
# https://www.domain.com.au/72a-argus-street-chel...      145.064916
# https://www.domain.com.au/72a-argus-street-chel...      145.064916
# https://www.domain.com.au/72a-argus-street-chel...      145.064916
# https://www.domain.com.au/72a-argus-street-chel...      145.064916
# https://www.domain.com.au/72a-argus-street-chel...      145.064916
#
#                                                                        geometry  \
# https://www.domain.com.au/72a-argus-street-chel...  POINT (145.06492 -37.95921)
# https://www.domain.com.au/72a-argus-street-chel...  POINT (145.06492 -37.95921)
# https://www.domain.com.au/72a-argus-street-chel...  POINT (145.06492 -37.95921)
# https://www.domain.com.au/72a-argus-street-chel...  POINT (145.06492 -37.95921)
# https://www.domain.com.au/72a-argus-street-chel...  POINT (145.06492 -37.95921)
#
#                                                     index_right station_id  \
# https://www.domain.com.au/72a-argus-street-chel...           71      52095
# https://www.domain.com.au/72a-argus-street-chel...          114      19864
# https://www.domain.com.au/72a-argus-street-chel...          115      19865
# https://www.domain.com.au/72a-argus-street-chel...          116      19866
# https://www.domain.com.au/72a-argus-street-chel...          122      19872
#
#                                                                                station_name  \
# https://www.domain.com.au/72a-argus-street-chel...   Southland Railway Station (Cheltenham)
# https://www.domain.com.au/72a-argus-street-chel...      Parkdale Railway Station (Parkdale)
# https://www.domain.com.au/72a-argus-street-chel...        Mentone Railway Station (Mentone)
# https://www.domain.com.au/72a-argus-street-chel...  Cheltenham Railway Station (Cheltenham)
# https://www.domain.com.au/72a-argus-street-chel...        Highett Railway Station (Highett)
#
#                                                     interval  latitude_right  \
# https://www.domain.com.au/72a-argus-street-chel...       600      -37.958756
# https://www.domain.com.au/72a-argus-street-chel...       600      -37.993079
# https://www.domain.com.au/72a-argus-street-chel...       600      -37.981865
# https://www.domain.com.au/72a-argus-street-chel...       600      -37.966650
# https://www.domain.com.au/72a-argus-street-chel...       600      -37.948425
#
#                                                     longitude_right
# https://www.domain.com.au/72a-argus-street-chel...       145.049121
# https://www.domain.com.au/72a-argus-street-chel...       145.076327
# https://www.domain.com.au/72a-argus-street-chel...       145.065166
# https://www.domain.com.au/72a-argus-street-chel...       145.054558
# https://www.domain.com.au/72a-argus-street-chel...       145.041872

# %% [markdown]
# - now finding the closest train station based on minimum distance

# %%
# Group by 'name' (property name), and find the row with the minimum 'distance_km' for each group
joined_gdf_min_distance = joined_gdf.sort_values('distance_km').drop_duplicates(subset=['name'], keep='first')

# Reset index to clean up the DataFrame
joined_gdf_min_distance = joined_gdf_min_distance.reset_index(drop=True)

# Remove unecessary columns
joined_gdf_min_distance = joined_gdf_min_distance.drop(columns=['interval', 'index_right', 'latitude_right', 'longitude_right'])

# Display the updated DataFrame
joined_gdf_min_distance
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/5b/_4xfpt552zl2s4838tp16dzw0000gn/T/ipykernel_33951/530301944.py in ?()
# ----> 2 # Group by 'name' (property name), and find the row with the minimum 'distance_km' for each group
#       3 joined_gdf_min_distance = joined_gdf.sort_values('distance_km').drop_duplicates(subset=['name'], keep='first')
#       4
#       5 # Reset index to clean up the DataFrame
#
# ~/Desktop/UNI/project-2-group-real-estate-industry-project-31/.venv/lib/python3.9/site-packages/pandas/core/frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7185             )
#    7186         elif len(by):
#    7187             # len(by) == 1
#    7188
# -> 7189             k = self._get_label_or_level_values(by[0], axis=axis)
#    7190
#    7191             # need to rewrap column in Series to apply key function
#    7192             if key is not None:
#
# ~/Desktop/UNI/project-2-group-real-estate-industry-project-31/.venv/lib/python3.9/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#    1914         if values.ndim > 1:
#
# KeyError: 'distance_km'

# %% [markdown]
# ## Prox to Melbourne CBD

# %%
domain_df.head(50)
# Out:
#                                                 name              rooms  \
# 0                  6 Gentle Street, Clayton VIC 3168  [3 Beds, 2 Baths]
# 1                  142 Civic Parade, Altona VIC 3018   [3 Beds, 1 Bath]
# 2          4/104 Bernard Street, Cheltenham VIC 3192  [3 Beds, 2 Baths]
# 3           2 Collendina Crescent, Scoresby VIC 3179  [3 Beds, 2 Baths]
# 4           103/6A Evergreen Mews, Armadale VIC 3143  [2 Beds, 2 Baths]
# 5            93 Honour Avenue, Wyndham Vale VIC 3024  [3 Beds, 2 Baths]
# 6    504/179 Boundary Road, North Melbourne VIC 3051    [1 Bed, 1 Bath]
# 7                     38 Dunlop, Shepparton VIC 3630   [3 Beds, 1 Bath]
# 8          18 Greenfinch Drive, Clyde North VIC 3978  [4 Beds, 2 Baths]
# 9          1008/18 Albert Street, Footscray VIC 3011    [1 Bed, 1 Bath]
# 10        506/19-21 Poplar Street, Box Hill VIC 3128  [2 Beds, 2 Baths]
# 11    31 Collins Street, Heidelberg Heights VIC 3081  [3 Beds, 2 Baths]
# 12         72 Newton Avenue, Bell Post Hill VIC 3215  [3 Beds, 2 Baths]
# 13              11/15 McKinley Ave, Malvern VIC 3144   [2 Beds, 1 Bath]
# 14                    1/14 May Road, Toorak VIC 3142    [1 Bed, 1 Bath]
# 15            21 Howitt Street, South Yarra VIC 3141  [4 Beds, 2 Baths]
# 16               5 Dragomir Street, Officer VIC 3809  [4 Beds, 2 Baths]
# 17   6501/35 Queensbridge Street, Southbank VIC 3006  [4 Beds, 4 Baths]
# 18               3/126 Brougham Street, Kew VIC 3101  [3 Beds, 2 Baths]
# 19          5/43 Banksia Grove, Tullamarine VIC 3043   [3 Beds, 1 Bath]
# 20         3 Linburn Street, Thornhill Park VIC 3335  [4 Beds, 2 Baths]
# 21      4306/228 LA TROBE STREET, Melbourne VIC 3000    [1 Bed, 1 Bath]
# 22          5/21 Wilson Street, South Yarra VIC 3141    [1 Bed, 1 Bath]
# 23         54 Ernest Street, Bell Post Hill VIC 3215   [3 Beds, 1 Bath]
# 24        806/118 Russell Street, Melbourne VIC 3000   [2 Beds, 1 Bath]
# 25                 81 Clarkes Rd, Fyansford VIC 3218  [4 Beds, 2 Baths]
# 26               389A Highett Road, Highett VIC 3190  [4 Beds, 2 Baths]
# 27      43 Mountain Street, South Melbourne VIC 3205   [2 Beds, 1 Bath]
# 28     1/962 Dandenong Road, Caulfield East VIC 3145  [2 Beds, 2 Baths]
# 29            1/24 Northcote Avenue, Balwyn VIC 3103  [3 Beds, 2 Baths]
# 30        30 Collison Road, Cranbourne East VIC 3977  [4 Beds, 2 Baths]
# 31          22 Crichton Crescent, Venus Bay VIC 3956   [4 Beds, 1 Bath]
# 32          1 Carey Crescent, Bacchus Marsh VIC 3340   [3 Beds, 1 Bath]
# 33               4 WENHAMS LANE, Wangaratta VIC 3677  [3 Beds, 2 Baths]
# 34                10 Leahy Street, Hamilton VIC 3300   [3 Beds, 1 Bath]
# 35            25 Holme Road, Ferntree Gully VIC 3156   [3 Beds, 1 Bath]
# 36  6106/35 Queens Bridge Street, Southbank VIC 3006  [3 Beds, 2 Baths]
# 37          10/10 Charnwood Grove, St Kilda VIC 3182    [1 Bed, 1 Bath]
# 38           6 Bonnie Court, Ferntree Gully VIC 3156  [5 Beds, 2 Baths]
# 39        115B/71 Riversdale Road, Hawthorn VIC 3122    [1 Bed, 1 Bath]
# 40                7 Alfonso Court, Lynbrook VIC 3975  [4 Beds, 2 Baths]
# 41                 13 Nurtja Drive, Kyabram VIC 3620  [4 Beds, 2 Baths]
# 42               36 Wendouree Drive, Kialla VIC 3631  [4 Beds, 2 Baths]
# 43            2/2 Marriott Street, St Kilda VIC 3182    [1 Bed, 1 Bath]
# 44            1408/241 City Road, Southbank VIC 3006  [3 Beds, 2 Baths]
# 45           4/210 Albion Street, Brunswick VIC 3056   [2 Beds, 1 Bath]
# 46    6 Buchanan Boulevard, Armstrong Creek VIC 3217  [4 Beds, 2 Baths]
# 47         5/39-41 Panorama Drive, San Remo VIC 3925   [3 Beds, 1 Bath]
# 48               11/647 Toorak Road, Toorak VIC 3142    [1 Bed, 1 Bath]
# 49     5610/135 A'Beckett Street, Melbourne VIC 3000   [2 Beds, 1 Bath]
#
#         parking            property_type date_available    bond  \
# 0   [2 Parking]                    House          09/24   $2520
# 1   [1 Parking]                    House          09/24   $2390
# 2   [2 Parking]                Townhouse          09/24   $3302
# 3   [2 Parking]                    House          09/24   $2694
# 4   [1 Parking]  Apartment / Unit / Flat          09/24    None
# 5   [1 Parking]                    House          09/24   $1955
# 6   [− Parking]  Apartment / Unit / Flat          09/24   $1738
# 7   [− Parking]                    House          09/24   $2145
# 8   [2 Parking]                Townhouse          09/24   $2586
# 9   [1 Parking]  Apartment / Unit / Flat          09/24   $1955
# 10  [1 Parking]  Apartment / Unit / Flat          09/24   $2694
# 11  [2 Parking]                    House          09/24   $2824
# 12  [3 Parking]                    House          09/24   $2259
# 13  [1 Parking]  Apartment / Unit / Flat          09/24   $2281
# 14  [1 Parking]  Apartment / Unit / Flat          09/24   $1912
# 15  [2 Parking]                    House          09/24   $5620
# 16  [2 Parking]                    House          09/24   $2686
# 17  [2 Parking]  Apartment / Unit / Flat          09/24  $75000
# 18  [2 Parking]  Apartment / Unit / Flat          09/24   $3259
# 19  [2 Parking]                Townhouse          09/24   $2260
# 20  [2 Parking]                    House          09/24   $2166
# 21  [− Parking]  Apartment / Unit / Flat          09/24   $2934
# 22  [1 Parking]  Apartment / Unit / Flat          09/24   $2380
# 23  [1 Parking]                    House          09/24    None
# 24  [− Parking]  Apartment / Unit / Flat          09/24   $3142
# 25  [2 Parking]                    House          09/24   $2824
# 26  [2 Parking]                Townhouse          09/24   $4563
# 27  [− Parking]                    House          09/24   $2933
# 28  [1 Parking]                Townhouse          09/24   $2499
# 29  [2 Parking]  Apartment / Unit / Flat          09/24   $3454
# 30  [4 Parking]                    House          09/24   $3911
# 31  [1 Parking]                    House          09/24   $1955
# 32  [1 Parking]                    House          09/24   $2042
# 33  [2 Parking]                    House          09/24   $1880
# 34  [2 Parking]                    House          09/24   $1520
# 35  [2 Parking]                    House          09/24   $2455
# 36  [2 Parking]  Apartment / Unit / Flat          09/24  $13800
# 37  [− Parking]  Apartment / Unit / Flat          09/24   $1690
# 38  [2 Parking]                    House          09/24   $3411
# 39  [− Parking]                   Studio          09/24   $1434
# 40  [3 Parking]                Townhouse          09/24   $2990
# 41  [2 Parking]                    House          09/24   $2281
# 42  [2 Parking]                    House          09/24   $2867
# 43  [1 Parking]  Apartment / Unit / Flat          09/24   $1868
# 44  [1 Parking]  Apartment / Unit / Flat          09/24    None
# 45  [1 Parking]  Apartment / Unit / Flat          09/24   $2607
# 46  [2 Parking]                    House          09/24   $2694
# 47  [1 Parking]                Townhouse          09/24   $2173
# 48  [1 Parking]  Apartment / Unit / Flat          09/24   $2021
# 49  [− Parking]  Apartment / Unit / Flat          09/24   $3150
#
#                    coordinates  weekly_cost                       address  \
# 0   [-37.9221445, 145.1130263]        580.0               6 gentle street
# 1       [-37.86445, 144.82913]        550.0              142 civic parade
# 2   [-37.9543583, 145.0693877]        760.0          4/104 bernard street
# 3    [-37.8901142, 145.223353]        640.0         2 collendina crescent
# 4   [-37.8518143, 145.0133926]        790.0         103/6a evergreen mews
# 5    [-37.8978691, 144.626483]        450.0              93 honour avenue
# 6   [-37.7889129, 144.9392885]        400.0         504/179 boundary road
# 7   [-36.3587392, 145.4037277]        495.0                     38 dunlop
# 8   [-38.0853229, 145.3548667]        595.0           18 greenfinch drive
# 9   [-37.8016476, 144.8977057]        450.0         1008/18 albert street
# 10  [-37.8148278, 145.1166796]        620.0       506/19-21 poplar street
# 11   [-37.7376084, 145.052296]        650.0             31 collins street
# 12  [-38.0940723, 144.3272355]        520.0              72 newton avenue
# 13  [-37.8653708, 145.0313897]        525.0            11/15 mckinley ave
# 14  [-37.8475003, 145.0041488]        440.0                 1/14 may road
# 15  [-37.8468223, 145.0022694]       1295.0              21 howitt street
# 16   [-38.071444, 145.3960198]        620.0             5 dragomir street
# 17  [-37.8228837, 144.9612147]      12500.0   6501/35 queensbridge street
# 18  [-37.8004718, 145.0315039]        750.0         3/126 brougham street
# 19    [-37.704449, 144.880174]        520.0            5/43 banksia grove
# 20  [-37.7233856, 144.6207621]        500.0              3 linburn street
# 21   [-37.809615, 144.9623021]        675.0      4306/228 la trobe street
# 22  [-37.8437612, 144.9964955]        595.0            5/21 wilson street
# 23  [-38.1003926, 144.3279504]        480.0              54 ernest street
# 24  [-37.8134998, 144.9690884]        725.0        806/118 russell street
# 25  [-38.1366177, 144.3002652]        650.0                 81 clarkes rd
# 26    [-37.94701, 145.0287283]       1050.0             389a highett road
# 27  [-37.8372065, 144.9488931]        675.0            43 mountain street
# 28  [-37.8811332, 145.0492264]        575.0          1/962 dandenong road
# 29  [-37.8170858, 145.0872497]        795.0         1/24 northcote avenue
# 30   [-38.1079939, 145.314763]        900.0              30 collison road
# 31  [-38.7012214, 145.8305739]        450.0          22 crichton crescent
# 32  [-37.6696841, 144.4236774]        470.0              1 carey crescent
# 33  [-36.3824361, 146.3277221]        470.0                4 wenhams lane
# 34  [-37.7322767, 142.0125829]        380.0               10 leahy street
# 35  [-37.8904524, 145.2679225]        565.0                 25 holme road
# 36  [-37.8230583, 144.9614033]       2300.0  6106/35 queens bridge street
# 37  [-37.8593542, 144.9851976]        390.0         10/10 charnwood grove
# 38  [-37.8912561, 145.2824528]        785.0                6 bonnie court
# 39  [-37.8283482, 145.0323547]        330.0       115b/71 riversdale road
# 40  [-38.0463004, 145.2599004]        690.0               7 alfonso court
# 41  [-36.3122774, 145.0642379]        525.0               13 nurtja drive
# 42  [-36.4313642, 145.4015274]        660.0            36 wendouree drive
# 43  [-37.8630278, 144.9882119]        430.0           2/2 marriott street
# 44  [-37.8262358, 144.9600047]        910.0            1408/241 city road
# 45  [-37.7607613, 144.9615677]        600.0           4/210 albion street
# 46  [-38.2422988, 144.3816478]        620.0          6 buchanan boulevard
# 47  [-38.5240983, 145.3766002]        500.0        5/39-41 panorama drive
# 48    [-37.843101, 145.027238]        465.0            11/647 toorak road
# 49  [-37.8097879, 144.9596466]        725.0     5610/135 a'beckett street
#
#                 suburb postcode   latitude   longitude
# 0              clayton     3168 -37.922145  145.113026
# 1               altona     3018 -37.864450  144.829130
# 2           cheltenham     3192 -37.954358  145.069388
# 3             scoresby     3179 -37.890114  145.223353
# 4             armadale     3143 -37.851814  145.013393
# 5         wyndham vale     3024 -37.897869  144.626483
# 6      north melbourne     3051 -37.788913  144.939289
# 7           shepparton     3630 -36.358739  145.403728
# 8          clyde north     3978 -38.085323  145.354867
# 9            footscray     3011 -37.801648  144.897706
# 10            box hill     3128 -37.814828  145.116680
# 11  heidelberg heights     3081 -37.737608  145.052296
# 12      bell post hill     3215 -38.094072  144.327236
# 13             malvern     3144 -37.865371  145.031390
# 14              toorak     3142 -37.847500  145.004149
# 15         south yarra     3141 -37.846822  145.002269
# 16             officer     3809 -38.071444  145.396020
# 17           southbank     3006 -37.822884  144.961215
# 18                 kew     3101 -37.800472  145.031504
# 19         tullamarine     3043 -37.704449  144.880174
# 20      thornhill park     3335 -37.723386  144.620762
# 21           melbourne     3000 -37.809615  144.962302
# 22         south yarra     3141 -37.843761  144.996496
# 23      bell post hill     3215 -38.100393  144.327950
# 24           melbourne     3000 -37.813500  144.969088
# 25           fyansford     3218 -38.136618  144.300265
# 26             highett     3190 -37.947010  145.028728
# 27     south melbourne     3205 -37.837207  144.948893
# 28      caulfield east     3145 -37.881133  145.049226
# 29              balwyn     3103 -37.817086  145.087250
# 30     cranbourne east     3977 -38.107994  145.314763
# 31           venus bay     3956 -38.701221  145.830574
# 32       bacchus marsh     3340 -37.669684  144.423677
# 33          wangaratta     3677 -36.382436  146.327722
# 34            hamilton     3300 -37.732277  142.012583
# 35      ferntree gully     3156 -37.890452  145.267922
# 36           southbank     3006 -37.823058  144.961403
# 37            st kilda     3182 -37.859354  144.985198
# 38      ferntree gully     3156 -37.891256  145.282453
# 39            hawthorn     3122 -37.828348  145.032355
# 40            lynbrook     3975 -38.046300  145.259900
# 41             kyabram     3620 -36.312277  145.064238
# 42              kialla     3631 -36.431364  145.401527
# 43            st kilda     3182 -37.863028  144.988212
# 44           southbank     3006 -37.826236  144.960005
# 45           brunswick     3056 -37.760761  144.961568
# 46     armstrong creek     3217 -38.242299  144.381648
# 47            san remo     3925 -38.524098  145.376600
# 48              toorak     3142 -37.843101  145.027238
# 49           melbourne     3000 -37.809788  144.959647

# %%
domain_gdf.head(0)
# Out:
#                                                 name              rooms  \
# 0                  6 Gentle Street, Clayton VIC 3168  [3 Beds, 2 Baths]
# 1                  142 Civic Parade, Altona VIC 3018   [3 Beds, 1 Bath]
# 2          4/104 Bernard Street, Cheltenham VIC 3192  [3 Beds, 2 Baths]
# 3           2 Collendina Crescent, Scoresby VIC 3179  [3 Beds, 2 Baths]
# 4           103/6A Evergreen Mews, Armadale VIC 3143  [2 Beds, 2 Baths]
# 5            93 Honour Avenue, Wyndham Vale VIC 3024  [3 Beds, 2 Baths]
# 6    504/179 Boundary Road, North Melbourne VIC 3051    [1 Bed, 1 Bath]
# 7                     38 Dunlop, Shepparton VIC 3630   [3 Beds, 1 Bath]
# 8          18 Greenfinch Drive, Clyde North VIC 3978  [4 Beds, 2 Baths]
# 9          1008/18 Albert Street, Footscray VIC 3011    [1 Bed, 1 Bath]
# 10        506/19-21 Poplar Street, Box Hill VIC 3128  [2 Beds, 2 Baths]
# 11    31 Collins Street, Heidelberg Heights VIC 3081  [3 Beds, 2 Baths]
# 12         72 Newton Avenue, Bell Post Hill VIC 3215  [3 Beds, 2 Baths]
# 13              11/15 McKinley Ave, Malvern VIC 3144   [2 Beds, 1 Bath]
# 14                    1/14 May Road, Toorak VIC 3142    [1 Bed, 1 Bath]
# 15            21 Howitt Street, South Yarra VIC 3141  [4 Beds, 2 Baths]
# 16               5 Dragomir Street, Officer VIC 3809  [4 Beds, 2 Baths]
# 17   6501/35 Queensbridge Street, Southbank VIC 3006  [4 Beds, 4 Baths]
# 18               3/126 Brougham Street, Kew VIC 3101  [3 Beds, 2 Baths]
# 19          5/43 Banksia Grove, Tullamarine VIC 3043   [3 Beds, 1 Bath]
# 20         3 Linburn Street, Thornhill Park VIC 3335  [4 Beds, 2 Baths]
# 21      4306/228 LA TROBE STREET, Melbourne VIC 3000    [1 Bed, 1 Bath]
# 22          5/21 Wilson Street, South Yarra VIC 3141    [1 Bed, 1 Bath]
# 23         54 Ernest Street, Bell Post Hill VIC 3215   [3 Beds, 1 Bath]
# 24        806/118 Russell Street, Melbourne VIC 3000   [2 Beds, 1 Bath]
# 25                 81 Clarkes Rd, Fyansford VIC 3218  [4 Beds, 2 Baths]
# 26               389A Highett Road, Highett VIC 3190  [4 Beds, 2 Baths]
# 27      43 Mountain Street, South Melbourne VIC 3205   [2 Beds, 1 Bath]
# 28     1/962 Dandenong Road, Caulfield East VIC 3145  [2 Beds, 2 Baths]
# 29            1/24 Northcote Avenue, Balwyn VIC 3103  [3 Beds, 2 Baths]
# 30        30 Collison Road, Cranbourne East VIC 3977  [4 Beds, 2 Baths]
# 31          22 Crichton Crescent, Venus Bay VIC 3956   [4 Beds, 1 Bath]
# 32          1 Carey Crescent, Bacchus Marsh VIC 3340   [3 Beds, 1 Bath]
# 33               4 WENHAMS LANE, Wangaratta VIC 3677  [3 Beds, 2 Baths]
# 34                10 Leahy Street, Hamilton VIC 3300   [3 Beds, 1 Bath]
# 35            25 Holme Road, Ferntree Gully VIC 3156   [3 Beds, 1 Bath]
# 36  6106/35 Queens Bridge Street, Southbank VIC 3006  [3 Beds, 2 Baths]
# 37          10/10 Charnwood Grove, St Kilda VIC 3182    [1 Bed, 1 Bath]
# 38           6 Bonnie Court, Ferntree Gully VIC 3156  [5 Beds, 2 Baths]
# 39        115B/71 Riversdale Road, Hawthorn VIC 3122    [1 Bed, 1 Bath]
# 40                7 Alfonso Court, Lynbrook VIC 3975  [4 Beds, 2 Baths]
# 41                 13 Nurtja Drive, Kyabram VIC 3620  [4 Beds, 2 Baths]
# 42               36 Wendouree Drive, Kialla VIC 3631  [4 Beds, 2 Baths]
# 43            2/2 Marriott Street, St Kilda VIC 3182    [1 Bed, 1 Bath]
# 44            1408/241 City Road, Southbank VIC 3006  [3 Beds, 2 Baths]
# 45           4/210 Albion Street, Brunswick VIC 3056   [2 Beds, 1 Bath]
# 46    6 Buchanan Boulevard, Armstrong Creek VIC 3217  [4 Beds, 2 Baths]
# 47         5/39-41 Panorama Drive, San Remo VIC 3925   [3 Beds, 1 Bath]
# 48               11/647 Toorak Road, Toorak VIC 3142    [1 Bed, 1 Bath]
# 49     5610/135 A'Beckett Street, Melbourne VIC 3000   [2 Beds, 1 Bath]
#
#         parking            property_type date_available    bond  \
# 0   [2 Parking]                    House          09/24   $2520
# 1   [1 Parking]                    House          09/24   $2390
# 2   [2 Parking]                Townhouse          09/24   $3302
# 3   [2 Parking]                    House          09/24   $2694
# 4   [1 Parking]  Apartment / Unit / Flat          09/24    None
# 5   [1 Parking]                    House          09/24   $1955
# 6   [− Parking]  Apartment / Unit / Flat          09/24   $1738
# 7   [− Parking]                    House          09/24   $2145
# 8   [2 Parking]                Townhouse          09/24   $2586
# 9   [1 Parking]  Apartment / Unit / Flat          09/24   $1955
# 10  [1 Parking]  Apartment / Unit / Flat          09/24   $2694
# 11  [2 Parking]                    House          09/24   $2824
# 12  [3 Parking]                    House          09/24   $2259
# 13  [1 Parking]  Apartment / Unit / Flat          09/24   $2281
# 14  [1 Parking]  Apartment / Unit / Flat          09/24   $1912
# 15  [2 Parking]                    House          09/24   $5620
# 16  [2 Parking]                    House          09/24   $2686
# 17  [2 Parking]  Apartment / Unit / Flat          09/24  $75000
# 18  [2 Parking]  Apartment / Unit / Flat          09/24   $3259
# 19  [2 Parking]                Townhouse          09/24   $2260
# 20  [2 Parking]                    House          09/24   $2166
# 21  [− Parking]  Apartment / Unit / Flat          09/24   $2934
# 22  [1 Parking]  Apartment / Unit / Flat          09/24   $2380
# 23  [1 Parking]                    House          09/24    None
# 24  [− Parking]  Apartment / Unit / Flat          09/24   $3142
# 25  [2 Parking]                    House          09/24   $2824
# 26  [2 Parking]                Townhouse          09/24   $4563
# 27  [− Parking]                    House          09/24   $2933
# 28  [1 Parking]                Townhouse          09/24   $2499
# 29  [2 Parking]  Apartment / Unit / Flat          09/24   $3454
# 30  [4 Parking]                    House          09/24   $3911
# 31  [1 Parking]                    House          09/24   $1955
# 32  [1 Parking]                    House          09/24   $2042
# 33  [2 Parking]                    House          09/24   $1880
# 34  [2 Parking]                    House          09/24   $1520
# 35  [2 Parking]                    House          09/24   $2455
# 36  [2 Parking]  Apartment / Unit / Flat          09/24  $13800
# 37  [− Parking]  Apartment / Unit / Flat          09/24   $1690
# 38  [2 Parking]                    House          09/24   $3411
# 39  [− Parking]                   Studio          09/24   $1434
# 40  [3 Parking]                Townhouse          09/24   $2990
# 41  [2 Parking]                    House          09/24   $2281
# 42  [2 Parking]                    House          09/24   $2867
# 43  [1 Parking]  Apartment / Unit / Flat          09/24   $1868
# 44  [1 Parking]  Apartment / Unit / Flat          09/24    None
# 45  [1 Parking]  Apartment / Unit / Flat          09/24   $2607
# 46  [2 Parking]                    House          09/24   $2694
# 47  [1 Parking]                Townhouse          09/24   $2173
# 48  [1 Parking]  Apartment / Unit / Flat          09/24   $2021
# 49  [− Parking]  Apartment / Unit / Flat          09/24   $3150
#
#                    coordinates  weekly_cost                       address  \
# 0   [-37.9221445, 145.1130263]        580.0               6 gentle street
# 1       [-37.86445, 144.82913]        550.0              142 civic parade
# 2   [-37.9543583, 145.0693877]        760.0          4/104 bernard street
# 3    [-37.8901142, 145.223353]        640.0         2 collendina crescent
# 4   [-37.8518143, 145.0133926]        790.0         103/6a evergreen mews
# 5    [-37.8978691, 144.626483]        450.0              93 honour avenue
# 6   [-37.7889129, 144.9392885]        400.0         504/179 boundary road
# 7   [-36.3587392, 145.4037277]        495.0                     38 dunlop
# 8   [-38.0853229, 145.3548667]        595.0           18 greenfinch drive
# 9   [-37.8016476, 144.8977057]        450.0         1008/18 albert street
# 10  [-37.8148278, 145.1166796]        620.0       506/19-21 poplar street
# 11   [-37.7376084, 145.052296]        650.0             31 collins street
# 12  [-38.0940723, 144.3272355]        520.0              72 newton avenue
# 13  [-37.8653708, 145.0313897]        525.0            11/15 mckinley ave
# 14  [-37.8475003, 145.0041488]        440.0                 1/14 may road
# 15  [-37.8468223, 145.0022694]       1295.0              21 howitt street
# 16   [-38.071444, 145.3960198]        620.0             5 dragomir street
# 17  [-37.8228837, 144.9612147]      12500.0   6501/35 queensbridge street
# 18  [-37.8004718, 145.0315039]        750.0         3/126 brougham street
# 19    [-37.704449, 144.880174]        520.0            5/43 banksia grove
# 20  [-37.7233856, 144.6207621]        500.0              3 linburn street
# 21   [-37.809615, 144.9623021]        675.0      4306/228 la trobe street
# 22  [-37.8437612, 144.9964955]        595.0            5/21 wilson street
# 23  [-38.1003926, 144.3279504]        480.0              54 ernest street
# 24  [-37.8134998, 144.9690884]        725.0        806/118 russell street
# 25  [-38.1366177, 144.3002652]        650.0                 81 clarkes rd
# 26    [-37.94701, 145.0287283]       1050.0             389a highett road
# 27  [-37.8372065, 144.9488931]        675.0            43 mountain street
# 28  [-37.8811332, 145.0492264]        575.0          1/962 dandenong road
# 29  [-37.8170858, 145.0872497]        795.0         1/24 northcote avenue
# 30   [-38.1079939, 145.314763]        900.0              30 collison road
# 31  [-38.7012214, 145.8305739]        450.0          22 crichton crescent
# 32  [-37.6696841, 144.4236774]        470.0              1 carey crescent
# 33  [-36.3824361, 146.3277221]        470.0                4 wenhams lane
# 34  [-37.7322767, 142.0125829]        380.0               10 leahy street
# 35  [-37.8904524, 145.2679225]        565.0                 25 holme road
# 36  [-37.8230583, 144.9614033]       2300.0  6106/35 queens bridge street
# 37  [-37.8593542, 144.9851976]        390.0         10/10 charnwood grove
# 38  [-37.8912561, 145.2824528]        785.0                6 bonnie court
# 39  [-37.8283482, 145.0323547]        330.0       115b/71 riversdale road
# 40  [-38.0463004, 145.2599004]        690.0               7 alfonso court
# 41  [-36.3122774, 145.0642379]        525.0               13 nurtja drive
# 42  [-36.4313642, 145.4015274]        660.0            36 wendouree drive
# 43  [-37.8630278, 144.9882119]        430.0           2/2 marriott street
# 44  [-37.8262358, 144.9600047]        910.0            1408/241 city road
# 45  [-37.7607613, 144.9615677]        600.0           4/210 albion street
# 46  [-38.2422988, 144.3816478]        620.0          6 buchanan boulevard
# 47  [-38.5240983, 145.3766002]        500.0        5/39-41 panorama drive
# 48    [-37.843101, 145.027238]        465.0            11/647 toorak road
# 49  [-37.8097879, 144.9596466]        725.0     5610/135 a'beckett street
#
#                 suburb postcode   latitude   longitude  \
# 0              clayton     3168 -37.922145  145.113026
# 1               altona     3018 -37.864450  144.829130
# 2           cheltenham     3192 -37.954358  145.069388
# 3             scoresby     3179 -37.890114  145.223353
# 4             armadale     3143 -37.851814  145.013393
# 5         wyndham vale     3024 -37.897869  144.626483
# 6      north melbourne     3051 -37.788913  144.939289
# 7           shepparton     3630 -36.358739  145.403728
# 8          clyde north     3978 -38.085323  145.354867
# 9            footscray     3011 -37.801648  144.897706
# 10            box hill     3128 -37.814828  145.116680
# 11  heidelberg heights     3081 -37.737608  145.052296
# 12      bell post hill     3215 -38.094072  144.327236
# 13             malvern     3144 -37.865371  145.031390
# 14              toorak     3142 -37.847500  145.004149
# 15         south yarra     3141 -37.846822  145.002269
# 16             officer     3809 -38.071444  145.396020
# 17           southbank     3006 -37.822884  144.961215
# 18                 kew     3101 -37.800472  145.031504
# 19         tullamarine     3043 -37.704449  144.880174
# 20      thornhill park     3335 -37.723386  144.620762
# 21           melbourne     3000 -37.809615  144.962302
# 22         south yarra     3141 -37.843761  144.996496
# 23      bell post hill     3215 -38.100393  144.327950
# 24           melbourne     3000 -37.813500  144.969088
# 25           fyansford     3218 -38.136618  144.300265
# 26             highett     3190 -37.947010  145.028728
# 27     south melbourne     3205 -37.837207  144.948893
# 28      caulfield east     3145 -37.881133  145.049226
# 29              balwyn     3103 -37.817086  145.087250
# 30     cranbourne east     3977 -38.107994  145.314763
# 31           venus bay     3956 -38.701221  145.830574
# 32       bacchus marsh     3340 -37.669684  144.423677
# 33          wangaratta     3677 -36.382436  146.327722
# 34            hamilton     3300 -37.732277  142.012583
# 35      ferntree gully     3156 -37.890452  145.267922
# 36           southbank     3006 -37.823058  144.961403
# 37            st kilda     3182 -37.859354  144.985198
# 38      ferntree gully     3156 -37.891256  145.282453
# 39            hawthorn     3122 -37.828348  145.032355
# 40            lynbrook     3975 -38.046300  145.259900
# 41             kyabram     3620 -36.312277  145.064238
# 42              kialla     3631 -36.431364  145.401527
# 43            st kilda     3182 -37.863028  144.988212
# 44           southbank     3006 -37.826236  144.960005
# 45           brunswick     3056 -37.760761  144.961568
# 46     armstrong creek     3217 -38.242299  144.381648
# 47            san remo     3925 -38.524098  145.376600
# 48              toorak     3142 -37.843101  145.027238
# 49           melbourne     3000 -37.809788  144.959647
#
#                        geometry
# 0   POINT (145.11303 -37.92214)
# 1   POINT (144.82913 -37.86445)
# 2   POINT (145.06939 -37.95436)
# 3   POINT (145.22335 -37.89011)
# 4   POINT (145.01339 -37.85181)
# 5   POINT (144.62648 -37.89787)
# 6   POINT (144.93929 -37.78891)
# 7   POINT (145.40373 -36.35874)
# 8   POINT (145.35487 -38.08532)
# 9   POINT (144.89771 -37.80165)
# 10  POINT (145.11668 -37.81483)
# 11   POINT (145.0523 -37.73761)
# 12  POINT (144.32724 -38.09407)
# 13  POINT (145.03139 -37.86537)
# 14   POINT (145.00415 -37.8475)
# 15  POINT (145.00227 -37.84682)
# 16  POINT (145.39602 -38.07144)
# 17  POINT (144.96121 -37.82288)
# 18   POINT (145.0315 -37.80047)
# 19  POINT (144.88017 -37.70445)
# 20  POINT (144.62076 -37.72339)
# 21   POINT (144.9623 -37.80962)
# 22   POINT (144.9965 -37.84376)
# 23  POINT (144.32795 -38.10039)
# 24   POINT (144.96909 -37.8135)
# 25  POINT (144.30027 -38.13662)
# 26  POINT (145.02873 -37.94701)
# 27  POINT (144.94889 -37.83721)
# 28  POINT (145.04923 -37.88113)
# 29  POINT (145.08725 -37.81709)
# 30  POINT (145.31476 -38.10799)
# 31  POINT (145.83057 -38.70122)
# 32  POINT (144.42368 -37.66968)
# 33  POINT (146.32772 -36.38244)
# 34  POINT (142.01258 -37.73228)
# 35  POINT (145.26792 -37.89045)
# 36   POINT (144.9614 -37.82306)
# 37   POINT (144.9852 -37.85935)
# 38  POINT (145.28245 -37.89126)
# 39  POINT (145.03235 -37.82835)
# 40    POINT (145.2599 -38.0463)
# 41  POINT (145.06424 -36.31228)
# 42  POINT (145.40153 -36.43136)
# 43  POINT (144.98821 -37.86303)
# 44     POINT (144.96 -37.82624)
# 45  POINT (144.96157 -37.76076)
# 46   POINT (144.38165 -38.2423)
# 47    POINT (145.3766 -38.5241)
# 48   POINT (145.02724 -37.8431)
# 49  POINT (144.95965 -37.80979)

# %%
import pandas as pd

# Check for NaN values
missing_lat_long = domain_df[['latitude', 'longitude']].isna().sum()
print(f"Missing latitude values: {missing_lat_long['latitude']}")
print(f"Missing longitude values: {missing_lat_long['longitude']}")

# Define the latitude and longitude range for Victoria, Australia
lat_min, lat_max = -39.15, -34.0
lon_min, lon_max = 141.0, 150.0

# Check if latitude and longitude are within Victoria's range
invalid_lat = domain_gdf[(domain_gdf['latitude'] < lat_min) | (domain_gdf['latitude'] > lat_max)]
invalid_lon = domain_gdf[(domain_gdf['longitude'] < lon_min) | (domain_gdf['longitude'] > lon_max)]

print(f"Number of properties with invalid latitude: {len(invalid_lat)}")
print(f"Number of properties with invalid longitude: {len(invalid_lon)}")

# Display rows with invalid coordinates if any
if not invalid_lat.empty:
    print("Properties with invalid latitude:")
    print(invalid_lat[['latitude', 'longitude']])
    
if not invalid_lon.empty:
    print("Properties with invalid longitude:")
    print(invalid_lon[['latitude', 'longitude']])
# Out:
# Missing latitude values: 44
# Missing longitude values: 44
# Number of properties with invalid latitude: 0
# Number of properties with invalid longitude: 0

# %%
# Display rows with missing latitude or longitude values
missing_entries = domain_gdf[domain_gdf[['latitude', 'longitude']].isna().any(axis=1)]

print(f"Number of properties with missing latitude or longitude: {len(missing_entries)}")
missing_entries
# Out:
# Number of properties with missing latitude or longitude: 0
# Empty GeoDataFrame
# Columns: [name, rooms, parking, property_type, date_available, bond, coordinates, weekly_cost, address, suburb, postcode, latitude, longitude, geometry]
# Index: []

# %%
# Drop rows with missing latitude or longitude values
domain_gdf = domain_gdf.dropna(subset=['latitude', 'longitude'])

# Verify the result
print(f"Number of remaining properties: {len(domain_gdf)}")
# Out:
# Number of remaining properties: 13017

# %%
property_coordinates = domain_gdf[['longitude', 'latitude']].values.tolist()

# %%
import time
from openrouteservice import Client
import math

# Initialize OpenRouteService client with your API key
api_key ='5b3ce3597851110001cf62483425e548d4ed4c2ca4a6b5814be96094'
client = Client(key=api_key)

# Define Melbourne CBD coordinates
melbourne_cbd = [144.9660, -37.8180]

def calculate_distances_to_cbd(properties, batch_size):
    distances_to_cbd = []
    num_batches = math.ceil(len(properties) / batch_size)

    for i in range(num_batches):
        # Get current batch of properties
        batch = properties[i * batch_size: (i + 1) * batch_size]
        # Create matrix request with properties as sources and Melbourne CBD as the destination
        locations = batch + [melbourne_cbd]  # Batch properties + CBD point

        while True:
            try:
                # Perform matrix request
                response = client.distance_matrix(
                    locations=locations,
                    profile='driving-car',
                    metrics=['distance'],
                    sources=list(range(len(batch))),  # Sources: property indices
                    destinations=[len(batch)]  # Destination: index of Melbourne CBD
                )

                # Extract distances from response (km)
                distances = [response['distances'][j][0] / 1000 for j in range(len(batch))]
                distances_to_cbd.extend(distances)
                break  # Exit the loop if successful

            except Exception as e:
                print(f"Error with batch {i+1}: {e}")
                if "Rate limit exceeded" in str(e):
                    print("Rate limit exceeded. Waiting for 60 seconds...")
                    time.sleep(60)  # Wait for a minute before retrying
                else:
                    distances_to_cbd.extend([None] * len(batch))  # Append None for failed requests
                    break  # Exit the loop on other errors

        time.sleep(2)  # Optional: additional delay between batches

    return distances_to_cbd

test_df = domain_gdf.iloc[:50]
# Convert the coordinates column to a list of [longitude, latitude] pairs
property_coordinates = test_df[['longitude', 'latitude']].values.tolist()

# Calculate distances
distances = calculate_distances_to_cbd(property_coordinates, batch_size=50)

# Add the distances as a new column 'dist_cbd' to the original DataFrame
test_df['dist_cbd'] = distances

# Display the updated DataFrame with the new column
test_df.head()
# Out:
# /Users/umabarnes/Desktop/UNI/project-2-group-real-estate-industry-project-31/.venv/lib/python3.9/site-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
#                                         name              rooms      parking  \
# 0          6 Gentle Street, Clayton VIC 3168  [3 Beds, 2 Baths]  [2 Parking]
# 1          142 Civic Parade, Altona VIC 3018   [3 Beds, 1 Bath]  [1 Parking]
# 2  4/104 Bernard Street, Cheltenham VIC 3192  [3 Beds, 2 Baths]  [2 Parking]
# 3   2 Collendina Crescent, Scoresby VIC 3179  [3 Beds, 2 Baths]  [2 Parking]
# 4   103/6A Evergreen Mews, Armadale VIC 3143  [2 Beds, 2 Baths]  [1 Parking]
#
#              property_type date_available   bond                 coordinates  \
# 0                    House          09/24  $2520  [-37.9221445, 145.1130263]
# 1                    House          09/24  $2390      [-37.86445, 144.82913]
# 2                Townhouse          09/24  $3302  [-37.9543583, 145.0693877]
# 3                    House          09/24  $2694   [-37.8901142, 145.223353]
# 4  Apartment / Unit / Flat          09/24   None  [-37.8518143, 145.0133926]
#
#    weekly_cost                address      suburb postcode   latitude  \
# 0        580.0        6 gentle street     clayton     3168 -37.922145
# 1        550.0       142 civic parade      altona     3018 -37.864450
# 2        760.0   4/104 bernard street  cheltenham     3192 -37.954358
# 3        640.0  2 collendina crescent    scoresby     3179 -37.890114
# 4        790.0  103/6a evergreen mews    armadale     3143 -37.851814
#
#     longitude                     geometry  dist_cbd
# 0  145.113026  POINT (145.11303 -37.92214)  23.88966
# 1  144.829130  POINT (144.82913 -37.86445)  18.04568
# 2  145.069388  POINT (145.06939 -37.95436)  24.14656
# 3  145.223353  POINT (145.22335 -37.89011)  35.23065
# 4  145.013393  POINT (145.01339 -37.85181)   7.16913

# %%
# Display the updated DataFrame with the new column
test_df.head(50)
# Out:
#                                                 name              rooms  \
# 0                  6 Gentle Street, Clayton VIC 3168  [3 Beds, 2 Baths]
# 1                  142 Civic Parade, Altona VIC 3018   [3 Beds, 1 Bath]
# 2          4/104 Bernard Street, Cheltenham VIC 3192  [3 Beds, 2 Baths]
# 3           2 Collendina Crescent, Scoresby VIC 3179  [3 Beds, 2 Baths]
# 4           103/6A Evergreen Mews, Armadale VIC 3143  [2 Beds, 2 Baths]
# 5            93 Honour Avenue, Wyndham Vale VIC 3024  [3 Beds, 2 Baths]
# 6    504/179 Boundary Road, North Melbourne VIC 3051    [1 Bed, 1 Bath]
# 7                     38 Dunlop, Shepparton VIC 3630   [3 Beds, 1 Bath]
# 8          18 Greenfinch Drive, Clyde North VIC 3978  [4 Beds, 2 Baths]
# 9          1008/18 Albert Street, Footscray VIC 3011    [1 Bed, 1 Bath]
# 10        506/19-21 Poplar Street, Box Hill VIC 3128  [2 Beds, 2 Baths]
# 11    31 Collins Street, Heidelberg Heights VIC 3081  [3 Beds, 2 Baths]
# 12         72 Newton Avenue, Bell Post Hill VIC 3215  [3 Beds, 2 Baths]
# 13              11/15 McKinley Ave, Malvern VIC 3144   [2 Beds, 1 Bath]
# 14                    1/14 May Road, Toorak VIC 3142    [1 Bed, 1 Bath]
# 15            21 Howitt Street, South Yarra VIC 3141  [4 Beds, 2 Baths]
# 16               5 Dragomir Street, Officer VIC 3809  [4 Beds, 2 Baths]
# 17   6501/35 Queensbridge Street, Southbank VIC 3006  [4 Beds, 4 Baths]
# 18               3/126 Brougham Street, Kew VIC 3101  [3 Beds, 2 Baths]
# 19          5/43 Banksia Grove, Tullamarine VIC 3043   [3 Beds, 1 Bath]
# 20         3 Linburn Street, Thornhill Park VIC 3335  [4 Beds, 2 Baths]
# 21      4306/228 LA TROBE STREET, Melbourne VIC 3000    [1 Bed, 1 Bath]
# 22          5/21 Wilson Street, South Yarra VIC 3141    [1 Bed, 1 Bath]
# 23         54 Ernest Street, Bell Post Hill VIC 3215   [3 Beds, 1 Bath]
# 24        806/118 Russell Street, Melbourne VIC 3000   [2 Beds, 1 Bath]
# 25                 81 Clarkes Rd, Fyansford VIC 3218  [4 Beds, 2 Baths]
# 26               389A Highett Road, Highett VIC 3190  [4 Beds, 2 Baths]
# 27      43 Mountain Street, South Melbourne VIC 3205   [2 Beds, 1 Bath]
# 28     1/962 Dandenong Road, Caulfield East VIC 3145  [2 Beds, 2 Baths]
# 29            1/24 Northcote Avenue, Balwyn VIC 3103  [3 Beds, 2 Baths]
# 30        30 Collison Road, Cranbourne East VIC 3977  [4 Beds, 2 Baths]
# 31          22 Crichton Crescent, Venus Bay VIC 3956   [4 Beds, 1 Bath]
# 32          1 Carey Crescent, Bacchus Marsh VIC 3340   [3 Beds, 1 Bath]
# 33               4 WENHAMS LANE, Wangaratta VIC 3677  [3 Beds, 2 Baths]
# 34                10 Leahy Street, Hamilton VIC 3300   [3 Beds, 1 Bath]
# 35            25 Holme Road, Ferntree Gully VIC 3156   [3 Beds, 1 Bath]
# 36  6106/35 Queens Bridge Street, Southbank VIC 3006  [3 Beds, 2 Baths]
# 37          10/10 Charnwood Grove, St Kilda VIC 3182    [1 Bed, 1 Bath]
# 38           6 Bonnie Court, Ferntree Gully VIC 3156  [5 Beds, 2 Baths]
# 39        115B/71 Riversdale Road, Hawthorn VIC 3122    [1 Bed, 1 Bath]
# 40                7 Alfonso Court, Lynbrook VIC 3975  [4 Beds, 2 Baths]
# 41                 13 Nurtja Drive, Kyabram VIC 3620  [4 Beds, 2 Baths]
# 42               36 Wendouree Drive, Kialla VIC 3631  [4 Beds, 2 Baths]
# 43            2/2 Marriott Street, St Kilda VIC 3182    [1 Bed, 1 Bath]
# 44            1408/241 City Road, Southbank VIC 3006  [3 Beds, 2 Baths]
# 45           4/210 Albion Street, Brunswick VIC 3056   [2 Beds, 1 Bath]
# 46    6 Buchanan Boulevard, Armstrong Creek VIC 3217  [4 Beds, 2 Baths]
# 47         5/39-41 Panorama Drive, San Remo VIC 3925   [3 Beds, 1 Bath]
# 48               11/647 Toorak Road, Toorak VIC 3142    [1 Bed, 1 Bath]
# 49     5610/135 A'Beckett Street, Melbourne VIC 3000   [2 Beds, 1 Bath]
#
#         parking            property_type date_available    bond  \
# 0   [2 Parking]                    House          09/24   $2520
# 1   [1 Parking]                    House          09/24   $2390
# 2   [2 Parking]                Townhouse          09/24   $3302
# 3   [2 Parking]                    House          09/24   $2694
# 4   [1 Parking]  Apartment / Unit / Flat          09/24    None
# 5   [1 Parking]                    House          09/24   $1955
# 6   [− Parking]  Apartment / Unit / Flat          09/24   $1738
# 7   [− Parking]                    House          09/24   $2145
# 8   [2 Parking]                Townhouse          09/24   $2586
# 9   [1 Parking]  Apartment / Unit / Flat          09/24   $1955
# 10  [1 Parking]  Apartment / Unit / Flat          09/24   $2694
# 11  [2 Parking]                    House          09/24   $2824
# 12  [3 Parking]                    House          09/24   $2259
# 13  [1 Parking]  Apartment / Unit / Flat          09/24   $2281
# 14  [1 Parking]  Apartment / Unit / Flat          09/24   $1912
# 15  [2 Parking]                    House          09/24   $5620
# 16  [2 Parking]                    House          09/24   $2686
# 17  [2 Parking]  Apartment / Unit / Flat          09/24  $75000
# 18  [2 Parking]  Apartment / Unit / Flat          09/24   $3259
# 19  [2 Parking]                Townhouse          09/24   $2260
# 20  [2 Parking]                    House          09/24   $2166
# 21  [− Parking]  Apartment / Unit / Flat          09/24   $2934
# 22  [1 Parking]  Apartment / Unit / Flat          09/24   $2380
# 23  [1 Parking]                    House          09/24    None
# 24  [− Parking]  Apartment / Unit / Flat          09/24   $3142
# 25  [2 Parking]                    House          09/24   $2824
# 26  [2 Parking]                Townhouse          09/24   $4563
# 27  [− Parking]                    House          09/24   $2933
# 28  [1 Parking]                Townhouse          09/24   $2499
# 29  [2 Parking]  Apartment / Unit / Flat          09/24   $3454
# 30  [4 Parking]                    House          09/24   $3911
# 31  [1 Parking]                    House          09/24   $1955
# 32  [1 Parking]                    House          09/24   $2042
# 33  [2 Parking]                    House          09/24   $1880
# 34  [2 Parking]                    House          09/24   $1520
# 35  [2 Parking]                    House          09/24   $2455
# 36  [2 Parking]  Apartment / Unit / Flat          09/24  $13800
# 37  [− Parking]  Apartment / Unit / Flat          09/24   $1690
# 38  [2 Parking]                    House          09/24   $3411
# 39  [− Parking]                   Studio          09/24   $1434
# 40  [3 Parking]                Townhouse          09/24   $2990
# 41  [2 Parking]                    House          09/24   $2281
# 42  [2 Parking]                    House          09/24   $2867
# 43  [1 Parking]  Apartment / Unit / Flat          09/24   $1868
# 44  [1 Parking]  Apartment / Unit / Flat          09/24    None
# 45  [1 Parking]  Apartment / Unit / Flat          09/24   $2607
# 46  [2 Parking]                    House          09/24   $2694
# 47  [1 Parking]                Townhouse          09/24   $2173
# 48  [1 Parking]  Apartment / Unit / Flat          09/24   $2021
# 49  [− Parking]  Apartment / Unit / Flat          09/24   $3150
#
#                    coordinates  weekly_cost                       address  \
# 0   [-37.9221445, 145.1130263]        580.0               6 gentle street
# 1       [-37.86445, 144.82913]        550.0              142 civic parade
# 2   [-37.9543583, 145.0693877]        760.0          4/104 bernard street
# 3    [-37.8901142, 145.223353]        640.0         2 collendina crescent
# 4   [-37.8518143, 145.0133926]        790.0         103/6a evergreen mews
# 5    [-37.8978691, 144.626483]        450.0              93 honour avenue
# 6   [-37.7889129, 144.9392885]        400.0         504/179 boundary road
# 7   [-36.3587392, 145.4037277]        495.0                     38 dunlop
# 8   [-38.0853229, 145.3548667]        595.0           18 greenfinch drive
# 9   [-37.8016476, 144.8977057]        450.0         1008/18 albert street
# 10  [-37.8148278, 145.1166796]        620.0       506/19-21 poplar street
# 11   [-37.7376084, 145.052296]        650.0             31 collins street
# 12  [-38.0940723, 144.3272355]        520.0              72 newton avenue
# 13  [-37.8653708, 145.0313897]        525.0            11/15 mckinley ave
# 14  [-37.8475003, 145.0041488]        440.0                 1/14 may road
# 15  [-37.8468223, 145.0022694]       1295.0              21 howitt street
# 16   [-38.071444, 145.3960198]        620.0             5 dragomir street
# 17  [-37.8228837, 144.9612147]      12500.0   6501/35 queensbridge street
# 18  [-37.8004718, 145.0315039]        750.0         3/126 brougham street
# 19    [-37.704449, 144.880174]        520.0            5/43 banksia grove
# 20  [-37.7233856, 144.6207621]        500.0              3 linburn street
# 21   [-37.809615, 144.9623021]        675.0      4306/228 la trobe street
# 22  [-37.8437612, 144.9964955]        595.0            5/21 wilson street
# 23  [-38.1003926, 144.3279504]        480.0              54 ernest street
# 24  [-37.8134998, 144.9690884]        725.0        806/118 russell street
# 25  [-38.1366177, 144.3002652]        650.0                 81 clarkes rd
# 26    [-37.94701, 145.0287283]       1050.0             389a highett road
# 27  [-37.8372065, 144.9488931]        675.0            43 mountain street
# 28  [-37.8811332, 145.0492264]        575.0          1/962 dandenong road
# 29  [-37.8170858, 145.0872497]        795.0         1/24 northcote avenue
# 30   [-38.1079939, 145.314763]        900.0              30 collison road
# 31  [-38.7012214, 145.8305739]        450.0          22 crichton crescent
# 32  [-37.6696841, 144.4236774]        470.0              1 carey crescent
# 33  [-36.3824361, 146.3277221]        470.0                4 wenhams lane
# 34  [-37.7322767, 142.0125829]        380.0               10 leahy street
# 35  [-37.8904524, 145.2679225]        565.0                 25 holme road
# 36  [-37.8230583, 144.9614033]       2300.0  6106/35 queens bridge street
# 37  [-37.8593542, 144.9851976]        390.0         10/10 charnwood grove
# 38  [-37.8912561, 145.2824528]        785.0                6 bonnie court
# 39  [-37.8283482, 145.0323547]        330.0       115b/71 riversdale road
# 40  [-38.0463004, 145.2599004]        690.0               7 alfonso court
# 41  [-36.3122774, 145.0642379]        525.0               13 nurtja drive
# 42  [-36.4313642, 145.4015274]        660.0            36 wendouree drive
# 43  [-37.8630278, 144.9882119]        430.0           2/2 marriott street
# 44  [-37.8262358, 144.9600047]        910.0            1408/241 city road
# 45  [-37.7607613, 144.9615677]        600.0           4/210 albion street
# 46  [-38.2422988, 144.3816478]        620.0          6 buchanan boulevard
# 47  [-38.5240983, 145.3766002]        500.0        5/39-41 panorama drive
# 48    [-37.843101, 145.027238]        465.0            11/647 toorak road
# 49  [-37.8097879, 144.9596466]        725.0     5610/135 a'beckett street
#
#                 suburb postcode   latitude   longitude  \
# 0              clayton     3168 -37.922145  145.113026
# 1               altona     3018 -37.864450  144.829130
# 2           cheltenham     3192 -37.954358  145.069388
# 3             scoresby     3179 -37.890114  145.223353
# 4             armadale     3143 -37.851814  145.013393
# 5         wyndham vale     3024 -37.897869  144.626483
# 6      north melbourne     3051 -37.788913  144.939289
# 7           shepparton     3630 -36.358739  145.403728
# 8          clyde north     3978 -38.085323  145.354867
# 9            footscray     3011 -37.801648  144.897706
# 10            box hill     3128 -37.814828  145.116680
# 11  heidelberg heights     3081 -37.737608  145.052296
# 12      bell post hill     3215 -38.094072  144.327236
# 13             malvern     3144 -37.865371  145.031390
# 14              toorak     3142 -37.847500  145.004149
# 15         south yarra     3141 -37.846822  145.002269
# 16             officer     3809 -38.071444  145.396020
# 17           southbank     3006 -37.822884  144.961215
# 18                 kew     3101 -37.800472  145.031504
# 19         tullamarine     3043 -37.704449  144.880174
# 20      thornhill park     3335 -37.723386  144.620762
# 21           melbourne     3000 -37.809615  144.962302
# 22         south yarra     3141 -37.843761  144.996496
# 23      bell post hill     3215 -38.100393  144.327950
# 24           melbourne     3000 -37.813500  144.969088
# 25           fyansford     3218 -38.136618  144.300265
# 26             highett     3190 -37.947010  145.028728
# 27     south melbourne     3205 -37.837207  144.948893
# 28      caulfield east     3145 -37.881133  145.049226
# 29              balwyn     3103 -37.817086  145.087250
# 30     cranbourne east     3977 -38.107994  145.314763
# 31           venus bay     3956 -38.701221  145.830574
# 32       bacchus marsh     3340 -37.669684  144.423677
# 33          wangaratta     3677 -36.382436  146.327722
# 34            hamilton     3300 -37.732277  142.012583
# 35      ferntree gully     3156 -37.890452  145.267922
# 36           southbank     3006 -37.823058  144.961403
# 37            st kilda     3182 -37.859354  144.985198
# 38      ferntree gully     3156 -37.891256  145.282453
# 39            hawthorn     3122 -37.828348  145.032355
# 40            lynbrook     3975 -38.046300  145.259900
# 41             kyabram     3620 -36.312277  145.064238
# 42              kialla     3631 -36.431364  145.401527
# 43            st kilda     3182 -37.863028  144.988212
# 44           southbank     3006 -37.826236  144.960005
# 45           brunswick     3056 -37.760761  144.961568
# 46     armstrong creek     3217 -38.242299  144.381648
# 47            san remo     3925 -38.524098  145.376600
# 48              toorak     3142 -37.843101  145.027238
# 49           melbourne     3000 -37.809788  144.959647
#
#                        geometry   dist_cbd
# 0   POINT (145.11303 -37.92214)   23.88966
# 1   POINT (144.82913 -37.86445)   18.04568
# 2   POINT (145.06939 -37.95436)   24.14656
# 3   POINT (145.22335 -37.89011)   35.23065
# 4   POINT (145.01339 -37.85181)    7.16913
# 5   POINT (144.62648 -37.89787)   41.61408
# 6   POINT (144.93929 -37.78891)    4.88400
# 7   POINT (145.40373 -36.35874)  184.10120
# 8   POINT (145.35487 -38.08532)   52.13875
# 9   POINT (144.89771 -37.80165)    8.11363
# 10  POINT (145.11668 -37.81483)   19.65789
# 11   POINT (145.0523 -37.73761)   15.18829
# 12  POINT (144.32724 -38.09407)   71.43796
# 13  POINT (145.03139 -37.86537)   10.18581
# 14   POINT (145.00415 -37.8475)    6.10715
# 15  POINT (145.00227 -37.84682)    5.97443
# 16  POINT (145.39602 -38.07144)   53.29368
# 17  POINT (144.96121 -37.82288)    1.73865
# 18   POINT (145.0315 -37.80047)    9.34981
# 19  POINT (144.88017 -37.70445)   17.46099
# 20  POINT (144.62076 -37.72339)   46.38772
# 21   POINT (144.9623 -37.80962)    1.94178
# 22   POINT (144.9965 -37.84376)    4.99687
# 23  POINT (144.32795 -38.10039)   73.51967
# 24   POINT (144.96909 -37.8135)    0.77966
# 25  POINT (144.30027 -38.13662)   78.05519
# 26  POINT (145.02873 -37.94701)   19.50494
# 27  POINT (144.94889 -37.83721)    4.30794
# 28  POINT (145.04923 -37.88113)   13.33504
# 29  POINT (145.08725 -37.81709)   15.73820
# 30  POINT (145.31476 -38.10799)   53.48175
# 31  POINT (145.83057 -38.70122)  169.33361
# 32  POINT (144.42368 -37.66968)   59.73481
# 33  POINT (146.32772 -36.38244)  246.00189
# 34  POINT (142.01258 -37.73228)  311.42225
# 35  POINT (145.26792 -37.89045)   38.08138
# 36   POINT (144.9614 -37.82306)    1.66098
# 37   POINT (144.9852 -37.85935)    5.49348
# 38  POINT (145.28245 -37.89126)   40.45805
# 39  POINT (145.03235 -37.82835)    7.34003
# 40    POINT (145.2599 -38.0463)   42.22204
# 41  POINT (145.06424 -36.31228)  201.06897
# 42  POINT (145.40153 -36.43136)  176.76484
# 43  POINT (144.98821 -37.86303)    5.84479
# 44     POINT (144.96 -37.82624)    1.92702
# 45  POINT (144.96157 -37.76076)    7.62100
# 46   POINT (144.38165 -38.2423)   94.46217
# 47    POINT (145.3766 -38.5241)  122.68734
# 48   POINT (145.02724 -37.8431)    8.04236
# 49  POINT (144.95965 -37.80979)    2.03251

# %%
distances
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  60.445080000000004,
#  136.47022,
#  80.53591,
#  37.994519999999994,
#  15.97158,
#  55.48563,
#  21.64295,
#  17.85241,
#  9.60468,
#  14.55365,
#  2.70932,
#  82.25602,
#  39.76613,
#  39.113949999999996,
#  154.13094,
#  23.12314,
#  15.730780000000001,
#  7.54138,
#  46.32709,
#  10.9173,
#  36.79421,
#  1.96312,
#  67.57392999999999,
#  13.995809999999999,
#  1.5955899999999998,
#  110.71828,
#  19.52121,
#  3.1943099999999998,
#  30.1847,
#  46.54853,
#  2.07973,
#  2.48321,
#  9.39995,
#  19.28865,
#  6.016640000000001,
#  16.07474,
#  34.66225,
#  1.14473,
#  5.99671,
#  166.64797000000002,
#  17.22778,
#  51.52988,
#  4.59009,
#  54.6398,
#  56.79656,
#  1.9189200000000002,
#  17.183709999999998,
#  9.15317,
#  1.94178,
#  8.02116,
#  161.85241,
#  111.47422999999999,
#  1.4919200000000001,
#  60.86018,
#  9.82348,
#  20.47884,
#  90.77405,
#  6.43441,
#  5.25952,
#  26.57623,
#  28.34602,
#  2.59224,
#  34.99119,
#  1.55427,
#  3.48451,
#  1.5955899999999998,
#  313.70405999999997,
#  16.359389999999998,
#  153.53497,
#  149.68732999999997,
#  52.829449999999994,
#  39.30351,
#  5.616689999999999,
#  30.14563,
#  24.50651,
#  22.09982,
#  3.1943099999999998,
#  21.56283,
#  1.43706,
#  14.19735,
#  6.12983,
#  2.6041399999999997,
#  71.20427000000001,
#  18.670720000000003,
#  32.81901,
#  34.58238,
#  0.87812,
#  8.299430000000001,
#  22.13505,
#  135.94326999999998,
#  3.14617,
#  7.65904,
#  10.548860000000001,
#  85.68404,
#  6.30422,
#  16.49293,
#  1.88646,
#  22.779,
#  5.82121,
#  256.15306,
#  34.9375,
#  8.58977,
#  10.15358,
#  50.85411,
#  355.59956,
#  2.98448,
#  88.43397,
#  6.9512,
#  1.63571,
#  31.640099999999997,
#  40.51202,
#  280.29653,
#  4.36145,
#  17.454150000000002,
#  63.46438,
#  2.55008,
#  19.14758,
#  13.41048,
#  5.497859999999999,
#  2.43206,
#  7.0679300000000005,
#  1.98549,
#  93.58563000000001,
#  21.15234,
#  35.52509,
#  23.0121,
#  2.85339,
#  34.213269999999994,
#  18.54884,
#  6.35903,
#  76.5423,
#  16.77253,
#  5.75614,
#  34.66545,
#  1.15274,
#  5.29596,
#  7.634810000000001,
#  39.688019999999995,
#  32.50985,
#  18.83636,
#  2.81765,
#  87.51176,
#  10.510110000000001,
#  19.207189999999997,
#  7.15875,
#  5.79809,
#  2.83125,
#  152.65952,
#  25.645880000000002,
#  2.00639,
#  22.440759999999997,
#  8.80101,
#  87.56278999999999,
#  1.7610899999999998,
#  37.78993,
#  2.71253,
#  17.47491,
#  7.252689999999999,
#  71.66747,
#  1.59507,
#  1.75986,
#  17.109450000000002,
#  16.80574,
#  12.063540000000001,
#  90.18373,
#  3.5568,
#  9.37497,
#  2.2589200000000003,
#  25.89388,
#  2.18614,
#  18.58554,
#  153.24316000000002,
#  4.7685900000000006,
#  154.32081,
#  10.12662,
#  40.04236,
#  22.598950000000002,
#  59.04016,
#  64.28321,
#  33.31164,
#  16.35412,
#  17.495060000000002,
#  90.49372,
#  124.87317,
#  6.88066,
#  114.33669,
#  2.4744699999999997,
#  57.7653,
#  5.1475,
#  11.02191,
#  2.94452,
#  35.559779999999996,
#  5.3217799999999995,
#  10.65002,
#  12.20287,
#  39.99753,
#  1.90404,
#  56.52113,
#  91.58639,
#  9.43658,
#  14.63001,
#  95.73543,
#  24.10554,
#  10.4415,
#  104.27441999999999,
#  63.7369,
#  109.38925,
#  55.023410000000005,
#  24.03111,
#  47.49625,
#  6.147390000000001,
#  45.69946,
#  16.22197,
#  32.65431,
#  183.07797,
#  90.56809,
#  13.36116,
#  78.86946,
#  1.29016,
#  7.71615,
#  4.62579,
#  15.894770000000001,
#  35.39711,
#  51.53351,
#  5.876939999999999,
#  10.88401,
#  10.12209,
#  9.72586,
#  10.817219999999999,
#  94.46217,
#  52.28509,
#  128.71538,
#  92.05502,
#  5.81461,
#  46.50664,
#  1.25591,
#  3.06112,
#  15.73491,
#  216.40610999999998,
#  14.00643,
#  2.4718,
#  3.35023,
#  183.50203,
#  28.54112,
#  11.923309999999999,
#  8.50201,
#  3.54437,
#  32.85212,
#  50.827940000000005,
#  12.92584,
#  31.43,
#  2.49608,
#  7.01496,
#  21.36361,
#  48.86569,
#  8.23126,
#  12.192450000000001,
#  84.4025,
#  57.45937,
#  40.682339999999996,
#  41.85729,
#  12.026909999999999,
#  7.22126,
#  10.6911,
#  22.442790000000002,
#  152.35578,
#  2.78186,
#  14.27149,
#  98.94083,
#  118.66746,
#  17.037470000000003,
#  10.69539,
#  88.9863,
#  1.29016,
#  10.361690000000001,
#  542.8483100000001,
#  110.32806,
#  33.76648,
#  12.50605,
#  1.80353,
#  19.82461,
#  20.54468,
#  28.577009999999998,
#  49.79745,
#  25.45667,
#  9.41547,
#  7.8982,
#  100.67736000000001,
#  10.17898,
#  42.30075,
#  1.59507,
#  29.28585,
#  36.62279,
#  67.40224,
#  2.54914,
#  1.98825,
#  105.01955000000001,
#  4.60582,
#  45.962379999999996,
#  4.5327,
#  4.307939999999999,
#  48.93552,
#  39.858019999999996,
#  19.75787,
#  9.53349,
#  81.34383,
#  1.783,
#  133.47148,
#  279.78344,
#  183.55908,
#  2.3270399999999998,
#  10.761389999999999,
#  36.93602,
#  22.094240000000003,
#  206.88381,
#  17.64426,
#  7.30115,
#  68.35128,
#  2.17169,
#  27.43876,
#  31.011400000000002,
#  1.586,
#  98.68054,
#  2.53918,
#  11.51372,
#  256.98666000000003,
#  70.4953,
#  10.8672,
#  6.4406300000000005,
#  22.43923,
#  10.634129999999999,
#  15.15256,
#  1.97312,
#  57.88215,
#  24.26823,
#  28.54627,
#  3.02908,
#  72.31672,
#  24.230330000000002,
#  36.72985,
#  1.90466,
#  39.55054,
#  41.67959,
#  5.16595,
#  34.42472,
#  71.43803999999999,
#  4.39313,
#  17.161330000000003,
#  4.39313,
#  73.1542,
#  16.6233,
#  389.91788,
#  15.57381,
#  39.6916,
#  0.68021,
#  40.62909,
#  56.529900000000005,
#  3.34388,
#  5.1862200000000005,
#  5.765479999999999,
#  1.7286400000000002,
#  2.45246,
#  36.04654,
#  152.8202,
#  75.89592999999999,
#  24.16479,
#  4.76044,
#  8.16011,
#  18.163919999999997,
#  2.2618899999999997,
#  37.02265,
#  7.4015699999999995,
#  2.28601,
#  30.38246,
#  77.38837,
#  24.84151,
#  2.62128,
#  17.520799999999998,
#  14.89588,
#  36.02629,
#  1.67397,
#  2.0393,
#  45.41867,
#  203.47552,
#  4.17584,
#  206.36769,
#  111.78481,
#  18.67959,
#  24.1393,
#  21.71475,
#  18.27849,
#  4.89382,
#  10.81865,
#  4.24542,
#  8.13718,
#  3.7980300000000002,
#  38.33025,
#  47.644709999999996,
#  114.45195,
#  3.1876700000000002,
#  74.20022999999999,
#  101.08059,
#  7.002140000000001,
#  37.30682,
#  29.582330000000002,
#  30.83796,
#  23.04696,
#  53.70451,
#  2.62128,
#  29.780009999999997,
#  82.3538,
#  27.79277,
#  283.63238,
#  39.945800000000006,
#  2.30851,
#  77.32071,
#  1.58401,
#  2.74661,
#  55.505900000000004,
#  541.8776899999999,
#  91.98998,
#  35.70881,
#  53.44832,
#  48.44122,
#  36.27485,
#  16.715400000000002,
#  7.12371,
#  19.274759999999997,
#  51.75428,
#  32.92049,
#  8.60091,
#  3.67617,
#  43.35756,
#  40.83374,
#  18.358220000000003,
#  30.70555,
#  73.63607,
#  45.050019999999996,
#  13.718879999999999,
#  33.41091,
#  54.380199999999995,
#  51.737,
#  114.13704,
#  35.54704,
#  11.342469999999999,
#  16.54203,
#  5.50164,
#  4.70776,
#  6.12773,
#  8.734729999999999,
#  1.94179,
#  8.35442,
#  1.42573,
#  18.766830000000002,
#  152.24919,
#  64.46306,
#  120.82745,
#  46.772330000000004,
#  46.46545,
#  38.79649,
#  91.23003,
#  1.21268,
#  45.996379999999995,
#  14.84215,
#  14.330459999999999,
#  25.298509999999997,
#  10.47295,
#  18.69318,
#  289.86088,
#  11.236979999999999,
#  19.08896,
#  2.2208699999999997,
#  155.63984,
#  15.46088,
#  92.44408,
#  4.8398900000000005,
#  7.13163,
#  14.048540000000001,
#  4.57054,
#  2.21273,
#  61.24934,
#  2.40504,
#  3.18565,
#  1.58958,
#  2.84933,
#  6.8773100000000005,
#  6.0694,
#  19.05361,
#  0.05887,
#  24.64986,
#  46.271,
#  4.92033,
#  4.03304,
#  11.58288,
#  30.17066,
#  60.662699999999994,
#  37.886160000000004,
#  6.5349200000000005,
#  52.89529,
#  28.388270000000002,
#  1.53081,
#  5.620970000000001,
#  49.173120000000004,
#  9.615549999999999,
#  15.54785,
#  49.390589999999996,
#  49.38511,
#  4.55109,
#  16.029690000000002,
#  182.42709,
#  8.64308,
#  4.37299,
#  62.59933,
#  3.87637,
#  38.096419999999995,
#  13.85726,
#  2.1559899999999996,
#  22.68284,
#  38.239160000000005,
#  35.13258999999999,
#  76.28338000000001,
#  8.324219999999999,
#  86.09903999999999,
#  43.28834,
#  3.3202399999999996,
#  84.48149000000001,
#  18.95995,
#  20.885930000000002,
#  6.77827,
#  6.67091,
#  46.8945,
#  6.72571,
#  101.34657000000001,
#  73.40927,
#  2.12805,
#  2.23345,
#  15.1601,
#  3.81876,
#  73.30266,
#  33.858230000000006,
#  12.81264,
#  16.29684,
#  3.02908,
#  2.54161,
#  102.4538,
#  2.18606,
#  158.78269,
#  9.65619,
#  52.67391000000001,
#  21.66041,
#  93.03922,
#  29.23226,
#  60.30864,
#  18.98815,
#  301.20934,
#  3.30977,
#  66.16375,
#  2.48548,
#  6.4102,
#  20.90203,
#  7.586399999999999,
#  50.80158,
#  4.5759300000000005,
#  73.28988000000001,
#  25.12021,
#  35.72645,
#  120.41507,
#  23.43413,
#  2.0393,
#  40.40932,
#  25.24627,
#  10.24747,
#  27.13913,
#  125.39927,
#  2.12434,
#  34.909819999999996,
#  34.54023,
#  14.47081,
#  21.96673,
#  16.385330000000003,
#  355.22631,
#  38.39074,
#  48.58215,
#  37.689440000000005,
#  46.24086,
#  11.27497,
#  279.98391,
#  9.22196,
#  1.97195,
#  46.98977,
#  135.25242,
#  31.55949,
#  30.751810000000003,
#  10.13617,
#  19.57016,
#  14.662180000000001,
#  33.45934,
#  2.04089,
#  14.952770000000001,
#  3.54083,
#  2.1660399999999997,
#  28.96503,
#  13.71136,
#  31.865099999999998,
#  10.35003,
#  70.54202000000001,
#  2.0645700000000002,
#  3.4422800000000002,
#  18.815360000000002,
#  31.758869999999998,
#  43.209360000000004,
#  82.32539,
#  38.53514,
#  301.30388,
#  52.02812,
#  4.51404,
#  9.36741,
#  17.50761,
#  5.48643,
#  40.080709999999996,
#  153.43391,
#  83.4775,
#  96.43044,
#  3.3136,
#  34.60173,
#  45.74218,
#  53.67686,
#  31.311709999999998,
#  27.00306,
#  91.11725,
#  31.96848,
#  2.70489,
#  54.31821,
#  52.25596,
#  5.06603,
#  10.83232,
#  4.52559,
#  2.1663,
#  12.26237,
#  85.87044,
#  25.64005,
#  85.89789,
#  3.87929,
#  12.8885,
#  257.99084,
#  19.71476,
#  14.456280000000001,
#  2.3443400000000003,
#  65.95338000000001,
#  2.17169,
#  6.39453,
#  28.18978,
#  63.35192,
#  11.595379999999999,
#  2.0393,
#  35.84335,
#  4.6701999999999995,
#  6.864199999999999,
#  121.55778,
#  184.10782999999998,
#  122.24333,
#  23.95292,
#  122.79872999999999,
#  38.186440000000005,
#  8.07471,
#  12.50605,
#  15.68605,
#  29.45797,
#  2.3901399999999997,
#  53.75178,
#  46.73444,
#  2.98448,
#  11.192440000000001,
#  5.28534,
#  122.40642,
#  40.53876,
#  14.57491,
#  10.08574,
#  23.845860000000002,
#  3.36148,
#  66.72032,
#  3.19556,
#  183.73406,
#  21.199180000000002,
#  5.23013,
#  11.44625,
#  45.39185,
#  36.20505,
#  3.22742,
#  53.29764,
#  78.87087,
#  87.20523,
#  5.78483,
#  9.903120000000001,
#  63.48637,
#  62.83461,
#  152.14016,
#  2.20175,
#  44.6871,
#  14.470040000000001,
#  6.4429,
#  35.980669999999996,
#  32.28479,
#  26.64387,
#  18.808490000000003,
#  22.20297,
#  31.91448,
#  24.26448,
#  2.1663,
#  22.54255,
#  60.16682,
#  10.590959999999999,
#  27.65382,
#  1.29068,
#  2.00639,
#  40.066660000000006,
#  28.86999,
#  44.45502,
#  116.34543,
#  5.32663,
#  16.17721,
#  13.09308,
#  89.25856,
#  86.49055,
#  244.0015,
#  2.18992,
#  30.8815,
#  18.36254,
#  14.0215,
#  17.411759999999997,
#  5.91963,
#  8.283479999999999,
#  33.1849,
#  43.12608,
#  91.43714,
#  2.9111100000000003,
#  21.06807,
#  40.92863,
#  38.08283,
#  2.3619299999999996,
#  32.06982,
#  9.951469999999999,
#  5.8598,
#  16.9136,
#  30.545630000000003,
#  8.59264,
#  33.052099999999996,
#  47.46772,
#  11.9804,
#  38.355599999999995,
#  113.24896000000001,
#  17.36366,
#  33.92131,
#  545.4725,
#  40.70485,
#  6.5150500000000005,
#  6.63435,
#  122.45773,
#  26.618209999999998,
#  20.724349999999998,
#  15.3485,
#  112.26109,
#  13.15244,
#  24.68134,
#  43.80801,
#  71.07388,
#  5.48643,
#  51.895089999999996,
#  3.35023,
#  86.45635,
#  10.72171,
#  20.96698,
#  1.5906099999999999,
#  314.262,
#  4.27839,
#  153.46836,
#  22.45667,
#  32.56809,
#  21.74148,
#  105.62966,
#  21.33209,
#  2.04089,
#  34.18162,
#  48.438480000000006,
#  8.871129999999999,
#  27.741889999999998,
#  542.7705,
#  1.83348,
#  31.01886,
#  33.221650000000004,
#  11.85555,
#  43.982,
#  1.35227,
#  2.1663,
#  101.85355,
#  78.59384,
#  1.76169,
#  4.201899999999999,
#  4.69189,
#  10.47258,
#  25.6554,
#  23.40202,
#  55.33486,
#  15.176459999999999,
#  1.9934,
#  94.72887,
#  15.77975,
#  29.032799999999998,
#  4.37038,
#  25.557560000000002,
#  6.13057,
#  20.727990000000002,
#  4.43637,
#  27.51623,
#  43.54487,
#  7.4552,
#  54.06918,
#  4.15494,
#  32.394439999999996,
#  15.11926,
#  1.72316,
#  46.11565,
#  9.427290000000001,
#  85.39934,
#  25.62339,
#  98.6137,
#  7.55307,
#  46.48319,
#  23.57161,
#  37.868790000000004,
#  97.94069999999999,
#  113.55694,
#  10.6056,
#  18.8917,
#  79.60155999999999,
#  7.28396,
#  3.01008,
#  100.87188,
#  20.58684,
#  54.394709999999996,
#  3.25532,
#  22.38216,
#  9.76605,
#  21.06121,
#  19.889919999999996,
#  12.642719999999999,
#  42.41914,
#  64.2659,
#  153.54139,
#  27.81614,
#  54.39924,
#  11.06126,
#  12.805579999999999,
#  33.30907,
#  13.904290000000001,
#  54.763940000000005,
#  157.36104999999998,
#  80.26835000000001,
#  29.09855,
#  7.76351,
#  37.87088,
#  113.84277,
#  77.88297,
#  26.68028,
#  113.82588,
#  144.50925,
#  122.83138000000001,
#  23.90868,
#  5.9653599999999996,
#  5.37454,
#  14.05494,
#  49.53982,
#  102.20639,
#  6.97019,
#  7.34003,
#  13.5622,
#  21.463459999999998,
#  11.09234,
#  102.68502000000001,
#  11.717889999999999,
#  41.060379999999995,
#  10.0349,
#  153.23685999999998,
#  46.614779999999996,
#  20.156869999999998,
#  12.296940000000001,
#  151.15688,
#  46.34131,
#  4.05047,
#  48.09683999999999,
#  9.24273,
#  30.760900000000003,
#  3.5291900000000003,
#  14.073690000000001,
#  80.12638000000001,
#  2.4888600000000003,
#  2.56681,
#  8.59264,
#  151.18054999999998,
#  41.27111,
#  97.53247999999999,
#  11.5911,
#  184.70144,
#  19.87396,
#  55.50221,
#  4.24542,
#  38.104510000000005,
#  40.90993,
#  10.67382,
#  26.188029999999998,
#  26.641509999999997,
#  217.47379999999998,
#  121.07722,
#  54.33323,
#  16.05755,
#  13.590200000000001,
#  116.21555000000001,
#  1.93099,
#  7.595260000000001,
#  1.49176,
#  34.07729,
#  38.21586,
#  542.9905600000001,
#  69.36966000000001,
#  21.581889999999998,
#  6.2005799999999995,
#  10.024,
#  35.37026,
#  2.30851,
#  80.2993,
#  173.30509,
#  64.72789,
#  90.46558,
#  3.7258,
#  4.2878,
#  13.23375,
#  11.41426,
#  2.1877600000000004,
#  18.591060000000002,
#  16.10141,
#  3.02103,
#  12.23513,
#  16.28424,
#  28.87086,
#  41.652,
#  40.89845,
#  153.75152,
#  17.462220000000002,
#  20.085639999999998,
#  22.25693,
#  ...]

# %%
import openrouteservice
import time
import numpy as np

# Initialize OpenRouteService client with your API key
api_key = '5b3ce3597851110001cf62483425e548d4ed4c2ca4a6b5814be96094'
client = openrouteservice.Client(key=api_key)

# Function to get batch distances using ORS Matrix API
def get_batch_distances(df, batch_size=50):
    all_distances = []
    
    for i in range(0, len(df), batch_size):
        batch = df.iloc[i:i + batch_size]
        
        # Prepare coordinates: first half are properties, second half are stations
        coords = [[row['longitude_left'], row['latitude_left']] for _, row in batch.iterrows()] + \
                 [[row['longitude_right'], row['latitude_right']] for _, row in batch.iterrows()]
        
        try:
            # ORS Matrix API request for driving distances
            matrix = client.distance_matrix(
                locations=coords, 
                profile='driving-car',
                metrics=['distance'],
                sources=list(range(len(batch))),  # Property indices
                destinations=list(range(len(batch), len(batch)*2))  # Station indices
            )
            
            # Get driving distances and append
            for j in range(len(batch)):
                distance = matrix['distances'][j][j]  # Property to station distance
                all_distances.append(distance / 1000)  # Convert from meters to kilometers
        except Exception as e:
            print(f"Error occurred: {e}")
            all_distances.extend([None] * len(batch))  # Append None for failed API calls

        # Respect the rate limit by adding a delay between batches
        time.sleep(2)  
    
    return all_distances

# Apply batch distance calculation to the DataFrame
batch_size = 50  # Adjust batch size according to your preference
test_dist = get_batch_distances(joined_gdf.iloc[:1000], batch_size=batch_size)
